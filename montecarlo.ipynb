# %%
import copy
import sys
sys.path.append("src")

import data
import gs
import test_stability
from count_potential_rogues import count_potential_rogues

# %%
sections = data.section_JSON_to_dict("scraping/classes.json")
print(len(sections))
student_dict = data.generate_students_weighted(sections, 3000)
for key in student_dict:
    student_dict[key].find_conflicts(sections)
print(count_potential_rogues(student_dict))
# Out:
# 601
# 45 90166
# 101 90325
# 159 90266
# 170 90179
# 212 90469
# 213 90299
# 213 90279
# 231 90472
# 274 90308
# 357 90173
# 414 90528
# 429 90123
# 429 90754
# 434 90472
# 453 90826
# 463 90108
# 560 90281
# 604 90583
# 620 90584
# 634 90324
# 638 90280
# 674 90448
# 682 90078
# 702 90472
# 732 90150
# 739 90674
# 807 90232
# 817 90156
# 900 90260
# 904 90639
# 926 90238
# 940 90463
# 955 90472
# 959 90092
# 1026 90253
# 1038 90295
# 1053 90288
# 1100 90471
# 1124 90494
# 1137 90173
# 1193 90600
# 1221 90673
# 1256 90566
# 1331 90109
# 1352 90472
# 1369 90107
# 1417 90301
# 1430 90123
# 1438 90254
# 1540 90469
# 1553 90472
# 1562 90303
# 1575 90306
# 1575 90497
# 1635 90321
# 1644 90826
# 1659 90331
# 1686 90232
# 1781 90173
# 1809 90352
# 1821 90796
# 1845 90166
# 1846 90181
# 1853 90173
# 1875 90288
# 1892 90177
# 1921 90142
# 2004 90332
# 2010 90563
# 2054 90216
# 2142 90318
# 2215 90321
# 2218 90322
# 2302 90237
# 2332 90217
# 2353 90318
# 2371 90279
# 2405 90269
# 2437 90673
# 2519 90217
# 2564 90299
# 2580 90119
# 2580 90253
# 2680 90278
# 2686 90523
# 2697 90353
# 2698 90173
# 2717 90776
# 2747 90557
# 2747 90156
# 2832 90123
# 2856 90015
# 2863 90254
# 2922 90012
# 2959 90776
# 95

# %%
def monte_carlo_gs(student_dict: dict, section_dict: dict, iteration_limit: int = 500) -> int:
    best = float("inf")
    seeds = [i for i in range(1, iteration_limit + 2)]
    i = 0
    while i < iteration_limit:
        i += 1
        
        new_student_dict = copy.deepcopy(student_dict)
        new_section_dict = copy.deepcopy(section_dict)
        new_matching = gs.gale_shapley_match(new_student_dict, new_section_dict, shuffle = True, seed = seeds[i])
        
        rogues = test_stability.is_weakly_stable(new_matching[0], new_matching[1])[1]
        
        if rogues < best:
            best = rogues
            
    return int(best)

# %%
monte_carlo_gs(student_dict, sections, 10)
# Out:
# counter: 4
# counter: 5
# counter: 2
# counter: 3
# counter: 3
# counter: 4
# counter: 4
# counter: 2
# counter: 6
# counter: 3
# 2

# %%
matched_students, matched_sections = gs.gale_shapley_match(copy.deepcopy(student_dict), copy.deepcopy(sections))
for id, s in matched_students.items():
    if len(s.enrolled_in) > 0:
        print(s)
# Out:
# student0(GEO2):
# id: 0
# base_score: 200
# section ranking: [90034, 90550, 90669, 90092, 90484]
# schedule: {90484, 90092, 90669, 90550}
# sections enrolled: 4
#
# student1(IS4):
# id: 1
# base_score: 400
# section ranking: [90374, 90573, 90571, 90014, 90135]
# schedule: {90571, 90573, 90374, 90135}
# sections enrolled: 4
#
# student2(ARC2):
# id: 2
# base_score: 200
# section ranking: [90034, 90152, 90642, 90010, 90037]
# schedule: {90642}
# sections enrolled: 1
#
# student3(ASL5):
# id: 3
# base_score: 500
# section ranking: [90649, 90259, 90778, 90055, 90622]
# schedule: {90649, 90778, 90259, 90055}
# sections enrolled: 4
#
# student4(HIS2):
# id: 4
# base_score: 200
# section ranking: [90618, 90023, 90123, 90577, 90629]
# schedule: {90618, 90123, 90629, 90023}
# sections enrolled: 4
#
# student5(GER1):
# id: 5
# base_score: 100
# section ranking: [90494, 90017, 90502, 90566, 90503]
# schedule: {90017}
# sections enrolled: 1
#
# student6(EDU4):
# id: 6
# base_score: 400
# section ranking: [90243, 90245, 90242, 90367, 90246]
# schedule: {90242, 90243, 90245, 90367}
# sections enrolled: 4
#
# student7(NEU3):
# id: 7
# base_score: 300
# section ranking: [90790, 90288, 90302, 90182, 90287]
# schedule: {90288, 90182, 90790, 90287}
# sections enrolled: 4
#
# student8(SLA4):
# id: 8
# base_score: 400
# section ranking: [90320, 90276, 90617, 90680, 90102]
# schedule: {90320, 90617, 90680, 90276}
# sections enrolled: 4
#
# student9(HBR2):
# id: 9
# base_score: 200
# section ranking: [90467, 90609, 90600, 90528, 90544]
# schedule: {90528, 90609, 90467, 90544}
# sections enrolled: 4
#
# student10(BIO3):
# id: 10
# base_score: 300
# section ranking: [90092, 90266, 90087, 90486, 90071]
# schedule: {90071, 90092, 90486, 90087}
# sections enrolled: 4
#
# student11(BIO1):
# id: 11
# base_score: 100
# section ranking: [90141, 90058, 90074, 90481, 90071]
# schedule: {90481, 90074, 90141}
# sections enrolled: 3
#
# student12(MSM4):
# id: 12
# base_score: 400
# section ranking: [90214, 90014, 90316, 90771, 90813]
# schedule: {90771, 90316, 90813, 90214}
# sections enrolled: 4
#
# student13(ANT3):
# id: 13
# base_score: 300
# section ranking: [90267, 90616, 90509, 90389, 90019]
# schedule: {90616, 90019, 90267, 90389}
# sections enrolled: 4
#
# student14(GER3):
# id: 14
# base_score: 300
# section ranking: [90566, 90503, 90487, 90502, 90494]
# schedule: {90494, 90566, 90487}
# sections enrolled: 3
#
# student15(ECO2):
# id: 15
# base_score: 200
# section ranking: [90695, 90236, 90027, 90073, 90237]
# schedule: {90073, 90236, 90237, 90695}
# sections enrolled: 4
#
# student16(FDP3):
# id: 16
# base_score: 300
# section ranking: [90206, 90578, 90087, 90294, 90128]
# schedule: {90578, 90206, 90087}
# sections enrolled: 3
#
# student17(MSM1):
# id: 17
# base_score: 100
# section ranking: [90111, 90014, 90630, 90249, 90222]
# schedule: {90249, 90222, 90630, 90111}
# sections enrolled: 4
#
# student18(BOT4):
# id: 18
# base_score: 400
# section ranking: [90349, 90623, 90096, 90819, 90093]
# schedule: {90819, 90093, 90623}
# sections enrolled: 3
#
# student19(DAT5):
# id: 19
# base_score: 500
# section ranking: [90218, 90659, 90076, 90137, 90352]
# schedule: {90137, 90218, 90659}
# sections enrolled: 3
#
# student20(MSM3):
# id: 20
# base_score: 300
# section ranking: [90014, 90509, 90546, 90792, 90386]
# schedule: {90792, 90546, 90386, 90509}
# sections enrolled: 4
#
# student21(AT4):
# id: 21
# base_score: 400
# section ranking: [90615, 90060, 90149, 90181, 90059]
# schedule: {90060, 90181, 90615}
# sections enrolled: 3
#
# student22(BIO5):
# id: 22
# base_score: 500
# section ranking: [90797, 90324, 90081, 90674, 90676]
# schedule: {90324, 90797, 90676}
# sections enrolled: 3
#
# student23(EAS2):
# id: 23
# base_score: 200
# section ranking: [90765, 90645, 90638, 90633, 90855]
# schedule: {90765, 90638, 90855}
# sections enrolled: 3
#
# student24(LIN3):
# id: 24
# base_score: 300
# section ranking: [90139, 90121, 90267, 90640, 90669]
# schedule: {90640, 90121, 90139, 90267}
# sections enrolled: 4
#
# student25(PHY4):
# id: 25
# base_score: 400
# section ranking: [90521, 90337, 90171, 90330, 90292]
# schedule: {90521, 90330, 90171, 90337}
# sections enrolled: 4
#
# student26(AT4):
# id: 26
# base_score: 400
# section ranking: [90246, 90817, 90372, 90598, 90214]
# schedule: {90817, 90372, 90246, 90598}
# sections enrolled: 4
#
# student27(EAS2):
# id: 27
# base_score: 200
# section ranking: [90219, 90823, 90220, 90633, 90252]
# schedule: {90219, 90252, 90823}
# sections enrolled: 3
#
# student28(FDP2):
# id: 28
# base_score: 200
# section ranking: [90166, 90798, 90141, 90294, 90139]
# schedule: {90139, 90798, 90166}
# sections enrolled: 3
#
# student29(GRK4):
# id: 29
# base_score: 400
# section ranking: [90682, 90580, 90577, 90575, 90354]
# schedule: {90682, 90580, 90575}
# sections enrolled: 3
#
# student30(FYS4):
# id: 30
# base_score: 400
# section ranking: [90238, 90767, 90484, 90467, 90821]
# schedule: {90467, 90484, 90238, 90767}
# sections enrolled: 4
#
# student31(LAT2):
# id: 31
# base_score: 200
# section ranking: [90131, 90683, 90519, 90517, 90518]
# schedule: {90683, 90131}
# sections enrolled: 2
#
# student32(AST2):
# id: 32
# base_score: 200
# section ranking: [90834, 90333, 90057, 90644, 90058]
# schedule: {90834, 90644}
# sections enrolled: 2
#
# student33(AHI4):
# id: 33
# base_score: 400
# section ranking: [90543, 90009, 90203, 90823, 90574]
# schedule: {90009, 90823, 90203, 90543}
# sections enrolled: 4
#
# student34(AMS1):
# id: 34
# base_score: 100
# section ranking: [90659, 90078, 90609, 90589, 90328]
# schedule: {90589, 90078}
# sections enrolled: 2
#
# student35(AMS2):
# id: 35
# base_score: 200
# section ranking: [90117, 90186, 90638, 90011, 90592]
# schedule: {90011, 90638}
# sections enrolled: 2
#
# student36(GOV3):
# id: 36
# base_score: 300
# section ranking: [90125, 90532, 90524, 90528, 90534]
# schedule: {90524, 90532, 90125, 90534}
# sections enrolled: 4
#
# student37(ARC3):
# id: 37
# base_score: 300
# section ranking: [90822, 90121, 90037, 90842, 90022]
# schedule: {90121, 90037, 90822}
# sections enrolled: 3
#
# student38(ACC4):
# id: 38
# base_score: 400
# section ranking: [90002, 90003, 90686, 90355, 90733]
# schedule: {90002, 90003, 90686}
# sections enrolled: 3
#
# student39(ENG4):
# id: 39
# base_score: 400
# section ranking: [90652, 90123, 90788, 90651, 90136]
# schedule: {90788, 90123, 90652}
# sections enrolled: 3
#
# student40(PHI3):
# id: 40
# base_score: 300
# section ranking: [90536, 90348, 90572, 90344, 90851]
# schedule: {90536, 90344, 90572, 90348}
# sections enrolled: 4
#
# student41(FRH2):
# id: 41
# base_score: 200
# section ranking: [90054, 90354, 90476, 90525, 90131]
# schedule: {90131, 90525, 90054}
# sections enrolled: 3
#
# student42(ENG1):
# id: 42
# base_score: 100
# section ranking: [90388, 90517, 90667, 90448, 90656]
# schedule: {90448, 90656, 90388}
# sections enrolled: 3
#
# student43(AHI4):
# id: 43
# base_score: 400
# section ranking: [90017, 90589, 90823, 90005, 90157]
# schedule: {90017, 90589, 90005, 90823}
# sections enrolled: 4
#
# student44(ACC1):
# id: 44
# base_score: 100
# section ranking: [90002, 90003, 90570, 90124, 90126]
# schedule: {90570, 90002, 90003, 90124}
# sections enrolled: 4
#
# student45(COM1):
# id: 45
# base_score: 100
# section ranking: [90142, 90140, 90166, 90139, 90511]
# schedule: {90139, 90140, 90142}
# sections enrolled: 3
#
# student46(ENG2):
# id: 46
# base_score: 200
# section ranking: [90656, 90668, 90664, 90566, 90121]
# schedule: {90656, 90121, 90566}
# sections enrolled: 3
#
# student47(MUS4):
# id: 47
# base_score: 400
# section ranking: [90467, 90387, 90465, 90058, 90464]
# schedule: {90387, 90465, 90467, 90464}
# sections enrolled: 4
#
# student48(GRK4):
# id: 48
# base_score: 400
# section ranking: [90614, 90682, 90827, 90580, 90577]
# schedule: {90580, 90614}
# sections enrolled: 2
#
# student49(STA5):
# id: 49
# base_score: 500
# section ranking: [90546, 90668, 90193, 90194, 90192]
# schedule: {90193, 90546, 90668, 90194}
# sections enrolled: 4
#
# student50(IS5):
# id: 50
# base_score: 500
# section ranking: [90775, 90266, 90253, 90573, 90075]
# schedule: {90573, 90266, 90253, 90775}
# sections enrolled: 4
#
# student51(LIN4):
# id: 51
# base_score: 400
# section ranking: [90516, 90086, 90226, 90647, 90215]
# schedule: {90226, 90516, 90086, 90647}
# sections enrolled: 4
#
# student52(FRH5):
# id: 52
# base_score: 500
# section ranking: [90009, 90258, 90512, 90599, 90114]
# schedule: {90512, 90009, 90258, 90599}
# sections enrolled: 4
#
# student53(PHY5):
# id: 53
# base_score: 500
# section ranking: [90332, 90215, 90329, 90815, 90331]
# schedule: {90332, 90215}
# sections enrolled: 2
#
# student54(PBH1):
# id: 54
# base_score: 100
# section ranking: [90376, 90375, 90663, 90541, 90510]
# schedule: {90510}
# sections enrolled: 1
#
# student55(ENG3):
# id: 55
# base_score: 300
# section ranking: [90663, 90648, 90662, 90191, 90656]
# schedule: {90648, 90656, 90191, 90663}
# sections enrolled: 4
#
# student56(RUS3):
# id: 56
# base_score: 300
# section ranking: [90329, 90279, 90546, 90280, 90500]
# schedule: {90329, 90279}
# sections enrolled: 2
#
# student57(RUS3):
# id: 57
# base_score: 300
# section ranking: [90274, 90102, 90279, 90532, 90624]
# schedule: {90624, 90274, 90102, 90279}
# sections enrolled: 4
#
# student58(ITL2):
# id: 58
# base_score: 200
# section ranking: [90558, 90565, 90588, 90560, 90620]
# schedule: {90588, 90565, 90558}
# sections enrolled: 3
#
# student59(ACC5):
# id: 59
# base_score: 500
# section ranking: [90544, 90295, 90100, 90799, 90142]
# schedule: {90544, 90799, 90100, 90295}
# sections enrolled: 4
#
# student60(ASL5):
# id: 60
# base_score: 500
# section ranking: [90055, 90778, 90590, 90582, 90593]
# schedule: {90778, 90582, 90590, 90055}
# sections enrolled: 4
#
# student61(MUS3):
# id: 61
# base_score: 300
# section ranking: [90649, 90609, 90465, 90826, 90449]
# schedule: {90649, 90826, 90609, 90465}
# sections enrolled: 4
#
# student62(EDU1):
# id: 62
# base_score: 100
# section ranking: [90242, 90823, 90570, 90243, 90478]
# schedule: {90570, 90823}
# sections enrolled: 2
#
# student63(GWS5):
# id: 63
# base_score: 500
# section ranking: [90033, 90268, 90594, 90803, 90650]
# schedule: {90033, 90594, 90650, 90268}
# sections enrolled: 4
#
# student64(CHI4):
# id: 64
# base_score: 400
# section ranking: [90109, 90260, 90055, 90108, 90107]
# schedule: {90107, 90260, 90109, 90108}
# sections enrolled: 4
#
# student65(JPN1):
# id: 65
# base_score: 100
# section ranking: [90553, 90344, 90555, 90552, 90487]
# schedule: {90344}
# sections enrolled: 1
#
# student66(FRH2):
# id: 66
# base_score: 200
# section ranking: [90474, 90824, 90646, 90478, 90477]
# schedule: {90824, 90477, 90646}
# sections enrolled: 3
#
# student67(MSM3):
# id: 67
# base_score: 300
# section ranking: [90047, 90014, 90475, 90464, 90670]
# schedule: {90464, 90670, 90047}
# sections enrolled: 3
#
# student68(EAS4):
# id: 68
# base_score: 400
# section ranking: [90220, 90186, 90633, 90647, 90563]
# schedule: {90633, 90186, 90220, 90647}
# sections enrolled: 4
#
# student69(HIS2):
# id: 69
# base_score: 200
# section ranking: [90621, 90673, 90170, 90616, 90607]
# schedule: {90616, 90170, 90621}
# sections enrolled: 3
#
# student70(AT4):
# id: 70
# base_score: 400
# section ranking: [90451, 90320, 90016, 90232, 90059]
# schedule: {90320, 90451, 90232, 90016}
# sections enrolled: 4
#
# student71(HMD5):
# id: 71
# base_score: 500
# section ranking: [90587, 90581, 90583, 90772, 90576]
# schedule: {90576, 90587, 90772, 90581}
# sections enrolled: 4
#
# student72(FRH5):
# id: 72
# base_score: 500
# section ranking: [90477, 90474, 90633, 90036, 90471]
# schedule: {90633, 90474, 90036, 90477}
# sections enrolled: 4
#
# student73(FLM5):
# id: 73
# base_score: 500
# section ranking: [90295, 90316, 90572, 90696, 90060]
# schedule: {90572, 90316, 90060, 90295}
# sections enrolled: 4
#
# student74(BIO4):
# id: 74
# base_score: 400
# section ranking: [90074, 90077, 90827, 90345, 90822]
# schedule: {90074, 90827, 90077, 90822}
# sections enrolled: 4
#
# student75(SLA4):
# id: 75
# base_score: 400
# section ranking: [90821, 90680, 90343, 90617, 90588]
# schedule: {90680, 90617, 90821, 90343}
# sections enrolled: 4
#
# student76(MUS3):
# id: 76
# base_score: 300
# section ranking: [90387, 90468, 90449, 90491, 90469]
# schedule: {90449, 90387, 90468}
# sections enrolled: 3
#
# student77(SOC3):
# id: 77
# base_score: 300
# section ranking: [90198, 90273, 90014, 90119, 90271]
# schedule: {90198, 90271}
# sections enrolled: 2
#
# student78(AFR3):
# id: 78
# base_score: 300
# section ranking: [90592, 90837, 90187, 90824, 90297]
# schedule: {90592, 90297, 90837, 90824}
# sections enrolled: 4
#
# student79(GIS2):
# id: 79
# base_score: 200
# section ranking: [90688, 90620, 90792, 90269, 90105]
# schedule: {90688, 90620, 90792}
# sections enrolled: 3
#
# student80(EAS1):
# id: 80
# base_score: 100
# section ranking: [90355, 90347, 90272, 90633, 90220]
# schedule: {90272, 90347}
# sections enrolled: 2
#
# student81(PHI3):
# id: 81
# base_score: 300
# section ranking: [90315, 90501, 90344, 90223, 90347]
# schedule: {90344, 90315, 90501, 90223}
# sections enrolled: 4
#
# student82(GC5):
# id: 82
# base_score: 500
# section ranking: [90488, 90259, 90130, 90754, 90303]
# schedule: {90488, 90259, 90303}
# sections enrolled: 3
#
# student83(CRE5):
# id: 83
# base_score: 500
# section ranking: [90182, 90636, 90023, 90275, 90593]
# schedule: {90593, 90275, 90636, 90182}
# sections enrolled: 4
#
# student84(PAX4):
# id: 84
# base_score: 400
# section ranking: [90522, 90386, 90374, 90187, 90713]
# schedule: {90187, 90522, 90386, 90374}
# sections enrolled: 4
#
# student85(MUS3):
# id: 85
# base_score: 300
# section ranking: [90387, 90388, 90390, 90540, 90305]
# schedule: {90540, 90387, 90388, 90390}
# sections enrolled: 4
#
# student86(STA1):
# id: 86
# base_score: 100
# section ranking: [90765, 90775, 90195, 90618, 90193]
# schedule: {90195, 90775}
# sections enrolled: 2
#
# student87(ARA5):
# id: 87
# base_score: 500
# section ranking: [90466, 90032, 90227, 90033, 90800]
# schedule: {90032, 90033, 90466, 90227}
# sections enrolled: 4
#
# student88(GER3):
# id: 88
# base_score: 300
# section ranking: [90566, 90336, 90502, 90503, 90077]
# schedule: {90336, 90077, 90566}
# sections enrolled: 3
#
# student89(CRT3):
# id: 89
# base_score: 300
# section ranking: [90168, 90621, 90376, 90791, 90660]
# schedule: {90660, 90621, 90791}
# sections enrolled: 3
#
# student90(CHM1):
# id: 90
# base_score: 100
# section ranking: [90123, 90243, 90592, 90670, 90127]
# schedule: {90123, 90127}
# sections enrolled: 2
#
# student91(ENG4):
# id: 91
# base_score: 400
# section ranking: [90192, 90658, 90791, 90649, 90180]
# schedule: {90192, 90649, 90658}
# sections enrolled: 3
#
# student92(GOV3):
# id: 92
# base_score: 300
# section ranking: [90530, 90525, 90684, 90034, 90287]
# schedule: {90530, 90684, 90525}
# sections enrolled: 3
#
# student93(CRE3):
# id: 93
# base_score: 300
# section ranking: [90610, 90574, 90193, 90599, 90157]
# schedule: {90193, 90610, 90574, 90599}
# sections enrolled: 4
#
# student94(GOV3):
# id: 94
# base_score: 300
# section ranking: [90523, 90521, 90009, 90522, 90813]
# schedule: {90521, 90009, 90523, 90522}
# sections enrolled: 4
#
# student95(PKP5):
# id: 95
# base_score: 500
# section ranking: [90035, 90327, 90188, 90266, 90642]
# schedule: {90266, 90035, 90188, 90327}
# sections enrolled: 4
#
# student96(ITL2):
# id: 96
# base_score: 200
# section ranking: [90818, 90487, 90774, 90563, 90078]
# schedule: {90818, 90774, 90487}
# sections enrolled: 3
#
# student97(FRH5):
# id: 97
# base_score: 500
# section ranking: [90471, 90646, 90528, 90031, 90170]
# schedule: {90528, 90031, 90646, 90471}
# sections enrolled: 4
#
# student98(HBR2):
# id: 98
# base_score: 200
# section ranking: [90020, 90600, 90036, 90321, 90324]
# schedule: {90020}
# sections enrolled: 1
#
# student99(MRC4):
# id: 99
# base_score: 400
# section ranking: [90491, 90295, 90135, 90196, 90599]
# schedule: {90491, 90135, 90196, 90295}
# sections enrolled: 4
#
# student100(GIS1):
# id: 100
# base_score: 100
# section ranking: [90003, 90667, 90535, 90269, 90126]
# schedule: {90667, 90003}
# sections enrolled: 2
#
# student101(FLM4):
# id: 101
# base_score: 400
# section ranking: [90316, 90165, 90296, 90325, 90696]
# schedule: {90696, 90316, 90165}
# sections enrolled: 3
#
# student102(SLA3):
# id: 102
# base_score: 300
# section ranking: [90486, 90617, 90276, 90054, 90680]
# schedule: {90617, 90276, 90054, 90486}
# sections enrolled: 4
#
# student103(ECO2):
# id: 103
# base_score: 200
# section ranking: [90617, 90693, 90386, 90237, 90229]
# schedule: {90237, 90693}
# sections enrolled: 2
#
# student104(CHI2):
# id: 104
# base_score: 200
# section ranking: [90688, 90268, 90108, 90107, 90670]
# schedule: {90688}
# sections enrolled: 1
#
# student105(ENG2):
# id: 105
# base_score: 200
# section ranking: [90087, 90288, 90268, 90664, 90833]
# schedule: {90288}
# sections enrolled: 1
#
# student106(SLA1):
# id: 106
# base_score: 100
# section ranking: [90276, 90149, 90016, 90617, 90181]
# schedule: {90016, 90181}
# sections enrolled: 2
#
# student107(ASL3):
# id: 107
# base_score: 300
# section ranking: [90055, 90056, 90778, 90264, 90619]
# schedule: {90056, 90619, 90264}
# sections enrolled: 3
#
# student108(CRT3):
# id: 108
# base_score: 300
# section ranking: [90168, 90289, 90318, 90015, 90181]
# schedule: {90318, 90015}
# sections enrolled: 2
#
# student109(DAT4):
# id: 109
# base_score: 400
# section ranking: [90218, 90317, 90146, 90355, 90114]
# schedule: {90218, 90355, 90146, 90317}
# sections enrolled: 4
#
# student110(PBH1):
# id: 110
# base_score: 100
# section ranking: [90375, 90215, 90376, 90374, 90765]
# schedule: {90765}
# sections enrolled: 1
#
# student111(FYS3):
# id: 111
# base_score: 300
# section ranking: [90764, 90467, 90311, 90288, 90767]
# schedule: {90288, 90467, 90764, 90311}
# sections enrolled: 4
#
# student112(FDP1):
# id: 112
# base_score: 100
# section ranking: [90294, 90116, 90002, 90082, 90353]
# schedule: {90002, 90116}
# sections enrolled: 2
#
# student113(GIS4):
# id: 113
# base_score: 400
# section ranking: [90542, 90535, 90246, 90627, 90301]
# schedule: {90627, 90246, 90542, 90535}
# sections enrolled: 4
#
# student114(MRC3):
# id: 114
# base_score: 300
# section ranking: [90491, 90547, 90081, 90097, 90048]
# schedule: {90081, 90547}
# sections enrolled: 2
#
# student115(PHI1):
# id: 115
# base_score: 100
# section ranking: [90023, 90199, 90046, 90106, 90306]
# schedule: {90199, 90023}
# sections enrolled: 2
#
# student116(MAT4):
# id: 116
# base_score: 400
# section ranking: [90501, 90509, 90656, 90167, 90024]
# schedule: {90024, 90501, 90509, 90167}
# sections enrolled: 4
#
# student117(CHM5):
# id: 117
# base_score: 500
# section ranking: [90040, 90126, 90130, 90773, 90121]
# schedule: {90040, 90130, 90773, 90126}
# sections enrolled: 4
#
# student118(LAT2):
# id: 118
# base_score: 200
# section ranking: [90299, 90193, 90519, 90101, 90517]
# schedule: {90193, 90299, 90101}
# sections enrolled: 3
#
# student119(ENG5):
# id: 119
# base_score: 500
# section ranking: [90791, 90499, 90652, 90789, 90647]
# schedule: {90499, 90652, 90789, 90791}
# sections enrolled: 4
#
# student120(MRC1):
# id: 120
# base_score: 100
# section ranking: [90102, 90170, 90126, 90589, 90321]
# schedule: {90170, 90589}
# sections enrolled: 2
#
# student122(HIS1):
# id: 122
# base_score: 100
# section ranking: [90146, 90321, 90343, 90672, 90024]
# schedule: {90024, 90321, 90343}
# sections enrolled: 3
#
# student123(MSM4):
# id: 123
# base_score: 400
# section ranking: [90014, 90039, 90364, 90652, 90788]
# schedule: {90788, 90364, 90652, 90039}
# sections enrolled: 4
#
# student124(GIS2):
# id: 124
# base_score: 200
# section ranking: [90620, 90269, 90535, 90034, 90289]
# schedule: {90620}
# sections enrolled: 1
#
# student125(CRT1):
# id: 125
# base_score: 100
# section ranking: [90168, 90386, 90013, 90307, 90588]
# schedule: {90307}
# sections enrolled: 1
#
# student126(PAX5):
# id: 126
# base_score: 500
# section ranking: [90590, 90374, 90156, 90112, 90817]
# schedule: {90112, 90156, 90590, 90374}
# sections enrolled: 4
#
# student127(DAT3):
# id: 127
# base_score: 300
# section ranking: [90218, 90641, 90797, 90324, 90046]
# schedule: {90641, 90324, 90797, 90046}
# sections enrolled: 4
#
# student128(THE1):
# id: 128
# base_score: 100
# section ranking: [90150, 90060, 90528, 90152, 90245]
# schedule: {90528, 90245}
# sections enrolled: 2
#
# student129(GEO3):
# id: 129
# base_score: 300
# section ranking: [90252, 90254, 90289, 90260, 90836]
# schedule: {90836, 90252}
# sections enrolled: 2
#
# student130(ANT3):
# id: 130
# base_score: 300
# section ranking: [90622, 90555, 90258, 90028, 90597]
# schedule: {90258, 90028, 90597, 90622}
# sections enrolled: 4
#
# student131(BIO2):
# id: 131
# base_score: 200
# section ranking: [90087, 90301, 90088, 90010, 90075]
# schedule: {90010, 90075, 90301}
# sections enrolled: 3
#
# student132(CHI1):
# id: 132
# base_score: 100
# section ranking: [90032, 90291, 90045, 90795, 90150]
# schedule: {90291, 90795}
# sections enrolled: 2
#
# student133(RUS5):
# id: 133
# base_score: 500
# section ranking: [90366, 90280, 90278, 90141, 90279]
# schedule: {90280, 90278, 90141, 90366}
# sections enrolled: 4
#
# student134(GER4):
# id: 134
# base_score: 400
# section ranking: [90117, 90698, 90502, 90791, 90126]
# schedule: {90698, 90117, 90126, 90791}
# sections enrolled: 4
#
# student135(ITL3):
# id: 135
# base_score: 300
# section ranking: [90563, 90584, 90562, 90558, 90555]
# schedule: {90584, 90562, 90563, 90558}
# sections enrolled: 4
#
# student136(GWS1):
# id: 136
# base_score: 100
# section ranking: [90648, 90829, 90679, 90661, 90059]
# schedule: {90829}
# sections enrolled: 1
#
# student137(GOV2):
# id: 137
# base_score: 200
# section ranking: [90568, 90521, 90269, 90525, 90775]
# schedule: {90568, 90521, 90525, 90775}
# sections enrolled: 4
#
# student138(PKP2):
# id: 138
# base_score: 200
# section ranking: [90327, 90598, 90326, 90599, 90103]
# schedule: {90326, 90598}
# sections enrolled: 2
#
# student139(PSY4):
# id: 139
# base_score: 400
# section ranking: [90756, 90775, 90311, 90788, 90549]
# schedule: {90311, 90788, 90756, 90775}
# sections enrolled: 4
#
# student140(ANT3):
# id: 140
# base_score: 300
# section ranking: [90055, 90099, 90258, 90660, 90528]
# schedule: {90528, 90258, 90099}
# sections enrolled: 3
#
# student141(SLA5):
# id: 141
# base_score: 500
# section ranking: [90276, 90680, 90477, 90185, 90673]
# schedule: {90680, 90185, 90276, 90477}
# sections enrolled: 4
#
# student142(AT4):
# id: 142
# base_score: 400
# section ranking: [90048, 90149, 90207, 90801, 90051]
# schedule: {90048, 90801, 90149, 90207}
# sections enrolled: 4
#
# student143(PKP4):
# id: 143
# base_score: 400
# section ranking: [90327, 90465, 90179, 90229, 90058]
# schedule: {90465, 90179, 90229, 90327}
# sections enrolled: 4
#
# student144(ANT3):
# id: 144
# base_score: 300
# section ranking: [90018, 90772, 90826, 90309, 90169]
# schedule: {90826, 90018, 90772, 90309}
# sections enrolled: 4
#
# student145(AMS5):
# id: 145
# base_score: 500
# section ranking: [90654, 90659, 90082, 90623, 90572]
# schedule: {90082, 90659, 90654, 90623}
# sections enrolled: 4
#
# student146(MAT5):
# id: 146
# base_score: 500
# section ranking: [90129, 90215, 90500, 90465, 90513]
# schedule: {90129, 90513, 90500, 90215}
# sections enrolled: 4
#
# student147(AHI4):
# id: 147
# base_score: 400
# section ranking: [90005, 90237, 90638, 90697, 90634]
# schedule: {90697, 90634, 90005}
# sections enrolled: 3
#
# student148(GER1):
# id: 148
# base_score: 100
# section ranking: [90226, 90503, 90566, 90598, 90502]
# schedule: {90226, 90598}
# sections enrolled: 2
#
# student149(PKP2):
# id: 149
# base_score: 200
# section ranking: [90261, 90205, 90327, 90653, 90451]
# schedule: {90653, 90261}
# sections enrolled: 2
#
# student150(ITL2):
# id: 150
# base_score: 200
# section ranking: [90569, 90448, 90774, 90120, 90562]
# schedule: {90448, 90569, 90774, 90120}
# sections enrolled: 4
#
# student151(LAT5):
# id: 151
# base_score: 500
# section ranking: [90518, 90517, 90683, 90306, 90800]
# schedule: {90683, 90517, 90518}
# sections enrolled: 3
#
# student152(JPN5):
# id: 152
# base_score: 500
# section ranking: [90073, 90552, 90790, 90679, 90183]
# schedule: {90552, 90073, 90790, 90679}
# sections enrolled: 4
#
# student153(LIN5):
# id: 153
# base_score: 500
# section ranking: [90227, 90795, 90684, 90516, 90337]
# schedule: {90516, 90227, 90684, 90795}
# sections enrolled: 4
#
# student154(HBR3):
# id: 154
# base_score: 300
# section ranking: [90600, 90076, 90186, 90214, 90511]
# schedule: {90186, 90076, 90511}
# sections enrolled: 3
#
# student155(GWS1):
# id: 155
# base_score: 100
# section ranking: [90792, 90519, 90681, 90820, 90594]
# schedule: {90792, 90681, 90594, 90820}
# sections enrolled: 4
#
# student156(PSY5):
# id: 156
# base_score: 500
# section ranking: [90825, 90109, 90317, 90298, 90569]
# schedule: {90317, 90825, 90298, 90109}
# sections enrolled: 4
#
# student157(SOC5):
# id: 157
# base_score: 500
# section ranking: [90261, 90591, 90096, 90736, 90508]
# schedule: {90736, 90508, 90261, 90591}
# sections enrolled: 4
#
# student158(CHI4):
# id: 158
# base_score: 400
# section ranking: [90291, 90222, 90107, 90180, 90109]
# schedule: {90291, 90109, 90222, 90107}
# sections enrolled: 4
#
# student159(ACC1):
# id: 159
# base_score: 100
# section ranking: [90003, 90076, 90002, 90266, 90713]
# schedule: {90002, 90003}
# sections enrolled: 2
#
# student160(FRH5):
# id: 160
# base_score: 500
# section ranking: [90473, 90474, 90132, 90031, 90475]
# schedule: {90473, 90474, 90475}
# sections enrolled: 3
#
# student161(AHI3):
# id: 161
# base_score: 300
# section ranking: [90548, 90157, 90005, 90015, 90664]
# schedule: {90548, 90157, 90005, 90015}
# sections enrolled: 4
#
# student162(PHI4):
# id: 162
# base_score: 400
# section ranking: [90572, 90341, 90347, 90196, 90342]
# schedule: {90347, 90572, 90342, 90196}
# sections enrolled: 4
#
# student163(ACC1):
# id: 163
# base_score: 100
# section ranking: [90002, 90630, 90003, 90150, 90683]
# schedule: {90002, 90003, 90630}
# sections enrolled: 3
#
# student164(CHM5):
# id: 164
# base_score: 500
# section ranking: [90125, 90111, 90676, 90023, 90479]
# schedule: {90023, 90676, 90125, 90111}
# sections enrolled: 4
#
# student165(BOT2):
# id: 165
# base_score: 200
# section ranking: [90347, 90096, 90733, 90023, 90017]
# schedule: {90017, 90347}
# sections enrolled: 2
#
# student166(HBR4):
# id: 166
# base_score: 400
# section ranking: [90560, 90600, 90087, 90524, 90244]
# schedule: {90560, 90244, 90087}
# sections enrolled: 3
#
# student167(GEO5):
# id: 167
# base_score: 500
# section ranking: [90134, 90280, 90260, 90289, 90252]
# schedule: {90280, 90252, 90260, 90134}
# sections enrolled: 4
#
# student168(NEU1):
# id: 168
# base_score: 100
# section ranking: [90206, 90308, 90790, 90359, 90618]
# schedule: {90618, 90308, 90206}
# sections enrolled: 3
#
# student169(ARC4):
# id: 169
# base_score: 400
# section ranking: [90557, 90822, 90183, 90010, 90037]
# schedule: {90557, 90822, 90183}
# sections enrolled: 3
#
# student170(ES4):
# id: 170
# base_score: 400
# section ranking: [90259, 90179, 90573, 90257, 90011]
# schedule: {90257, 90259, 90011, 90573}
# sections enrolled: 4
#
# student171(LAT2):
# id: 171
# base_score: 200
# section ranking: [90517, 90519, 90683, 90280, 90682]
# schedule: {90683}
# sections enrolled: 1
#
# student172(NEU1):
# id: 172
# base_score: 100
# section ranking: [90302, 90798, 90499, 90795, 90308]
# schedule: {90499, 90308, 90795, 90798}
# sections enrolled: 4
#
# student174(CLA4):
# id: 174
# base_score: 400
# section ranking: [90138, 90112, 90639, 90137, 90171]
# schedule: {90112, 90137, 90138, 90639}
# sections enrolled: 4
#
# student175(PAX2):
# id: 175
# base_score: 200
# section ranking: [90633, 90675, 90374, 90815, 90375]
# schedule: {90675, 90815}
# sections enrolled: 2
#
# student176(PHY4):
# id: 176
# base_score: 400
# section ranking: [90485, 90337, 90329, 90289, 90494]
# schedule: {90337, 90329, 90485}
# sections enrolled: 3
#
# student177(HMD4):
# id: 177
# base_score: 400
# section ranking: [90576, 90583, 90688, 90574, 90535]
# schedule: {90576, 90688, 90574, 90583}
# sections enrolled: 4
#
# student178(AT4):
# id: 178
# base_score: 400
# section ranking: [90667, 90386, 90451, 90048, 90131]
# schedule: {90131, 90386, 90667}
# sections enrolled: 3
#
# student179(BOT3):
# id: 179
# base_score: 300
# section ranking: [90800, 90098, 90621, 90691, 90106]
# schedule: {90800, 90106, 90691, 90621}
# sections enrolled: 4
#
# student180(PAX5):
# id: 180
# base_score: 500
# section ranking: [90374, 90310, 90058, 90599, 90273]
# schedule: {90058, 90310, 90374, 90599}
# sections enrolled: 4
#
# student181(FDP4):
# id: 181
# base_score: 400
# section ranking: [90294, 90141, 90149, 90631, 90565]
# schedule: {90565, 90149, 90141}
# sections enrolled: 3
#
# student182(DAT5):
# id: 182
# base_score: 500
# section ranking: [90776, 90795, 90624, 90218, 90251]
# schedule: {90776, 90624, 90218, 90795}
# sections enrolled: 4
#
# student183(CRE5):
# id: 183
# base_score: 500
# section ranking: [90487, 90182, 90636, 90275, 90593]
# schedule: {90275, 90636, 90182, 90487}
# sections enrolled: 4
#
# student184(ES4):
# id: 184
# base_score: 400
# section ranking: [90166, 90142, 90592, 90290, 90257]
# schedule: {90592, 90290, 90166, 90142}
# sections enrolled: 4
#
# student185(AT5):
# id: 185
# base_score: 500
# section ranking: [90130, 90837, 90048, 90734, 90817]
# schedule: {90817, 90130, 90837, 90734}
# sections enrolled: 4
#
# student186(GOV1):
# id: 186
# base_score: 100
# section ranking: [90648, 90112, 90681, 90523, 90086]
# schedule: {90112, 90681, 90086}
# sections enrolled: 3
#
# student187(ENG3):
# id: 187
# base_score: 300
# section ranking: [90652, 90559, 90649, 90333, 90651]
# schedule: {90649, 90652, 90559}
# sections enrolled: 3
#
# student188(LAT3):
# id: 188
# base_score: 300
# section ranking: [90518, 90519, 90683, 90183, 90517]
# schedule: {90683, 90518}
# sections enrolled: 2
#
# student189(ES5):
# id: 189
# base_score: 500
# section ranking: [90648, 90450, 90295, 90318, 90300]
# schedule: {90648, 90450, 90295}
# sections enrolled: 3
#
# student190(DAT2):
# id: 190
# base_score: 200
# section ranking: [90218, 90800, 90010, 90084, 90855]
# schedule: {90800, 90010, 90084, 90855}
# sections enrolled: 4
#
# student191(ENG5):
# id: 191
# base_score: 500
# section ranking: [90198, 90658, 90704, 90651, 90667]
# schedule: {90667, 90658, 90651, 90198}
# sections enrolled: 4
#
# student192(ECO2):
# id: 192
# base_score: 200
# section ranking: [90238, 90352, 90653, 90134, 90364]
# schedule: {90364, 90653, 90238}
# sections enrolled: 3
#
# student193(HBR5):
# id: 193
# base_score: 500
# section ranking: [90600, 90789, 90624, 90049, 90289]
# schedule: {90600, 90624, 90049, 90789}
# sections enrolled: 4
#
# student194(BIO4):
# id: 194
# base_score: 400
# section ranking: [90306, 90141, 90073, 90086, 90083]
# schedule: {90306, 90141, 90086}
# sections enrolled: 3
#
# student195(PHE2):
# id: 195
# base_score: 200
# section ranking: [90358, 90371, 90767, 90175, 90275]
# schedule: {90275, 90175}
# sections enrolled: 2
#
# student196(DAT1):
# id: 196
# base_score: 100
# section ranking: [90218, 90464, 90295, 90793, 90564]
# schedule: {90464, 90793, 90564, 90295}
# sections enrolled: 4
#
# student197(PHY1):
# id: 197
# base_score: 100
# section ranking: [90337, 90333, 90132, 90330, 90331]
# schedule: {90337, 90132}
# sections enrolled: 2
#
# student198(CHI4):
# id: 198
# base_score: 400
# section ranking: [90108, 90673, 90109, 90107, 90775]
# schedule: {90673, 90107, 90108, 90775}
# sections enrolled: 4
#
# student199(HIS5):
# id: 199
# base_score: 500
# section ranking: [90542, 90641, 90657, 90228, 90622]
# schedule: {90641, 90622, 90542, 90657}
# sections enrolled: 4
#
# student200(CRT4):
# id: 200
# base_score: 400
# section ranking: [90168, 90137, 90468, 90053, 90693]
# schedule: {90168, 90137, 90468, 90053}
# sections enrolled: 4
#
# student201(AST4):
# id: 201
# base_score: 400
# section ranking: [90266, 90058, 90057, 90056, 90767]
# schedule: {90058, 90266, 90057, 90767}
# sections enrolled: 4
#
# student202(PHY3):
# id: 202
# base_score: 300
# section ranking: [90331, 90330, 90215, 90333, 90733]
# schedule: {90330, 90331}
# sections enrolled: 2
#
# student203(ARC3):
# id: 203
# base_score: 300
# section ranking: [90075, 90034, 90842, 90016, 90312]
# schedule: {90016, 90075, 90312}
# sections enrolled: 3
#
# student204(PBH5):
# id: 204
# base_score: 500
# section ranking: [90376, 90375, 90632, 90471, 90285]
# schedule: {90376, 90632, 90285, 90375}
# sections enrolled: 4
#
# student205(AT5):
# id: 205
# base_score: 500
# section ranking: [90023, 90367, 90306, 90012, 90584]
# schedule: {90367, 90012, 90023}
# sections enrolled: 3
#
# student206(RUS5):
# id: 206
# base_score: 500
# section ranking: [90278, 90279, 90257, 90280, 90229]
# schedule: {90257, 90278, 90279}
# sections enrolled: 3
#
# student207(CHM5):
# id: 207
# base_score: 500
# section ranking: [90126, 90681, 90684, 90469, 90359]
# schedule: {90681, 90469, 90126, 90359}
# sections enrolled: 4
#
# student208(PKP1):
# id: 208
# base_score: 100
# section ranking: [90825, 90327, 90662, 90236, 90638]
# schedule: {90825, 90236, 90638}
# sections enrolled: 3
#
# student209(MRC2):
# id: 209
# base_score: 200
# section ranking: [90353, 90491, 90049, 90047, 90014]
# schedule: {90049}
# sections enrolled: 1
#
# student210(GER3):
# id: 210
# base_score: 300
# section ranking: [90502, 90704, 90057, 90494, 90566]
# schedule: {90704, 90494, 90502}
# sections enrolled: 3
#
# student211(ENT2):
# id: 211
# base_score: 200
# section ranking: [90247, 90248, 90285, 90484, 90596]
# schedule: {90484, 90285}
# sections enrolled: 2
#
# student212(MUS5):
# id: 212
# base_score: 500
# section ranking: [90244, 90469, 90032, 90024, 90343]
# schedule: {90032, 90244, 90024, 90343}
# sections enrolled: 4
#
# student213(RUS2):
# id: 213
# base_score: 200
# section ranking: [90278, 90299, 90279, 90280, 90143]
# schedule: {90299}
# sections enrolled: 1
#
# student214(PKP3):
# id: 214
# base_score: 300
# section ranking: [90554, 90595, 90123, 90051, 90327]
# schedule: {90123, 90595}
# sections enrolled: 2
#
# student215(HBR4):
# id: 215
# base_score: 400
# section ranking: [90269, 90600, 90671, 90557, 90015]
# schedule: {90269, 90671}
# sections enrolled: 2
#
# student216(COM3):
# id: 216
# base_score: 300
# section ranking: [90148, 90145, 90515, 90558, 90220]
# schedule: {90220, 90145, 90515, 90148}
# sections enrolled: 4
#
# student217(COM3):
# id: 217
# base_score: 300
# section ranking: [90146, 90695, 90816, 90167, 90199]
# schedule: {90816, 90146, 90167, 90695}
# sections enrolled: 4
#
# student218(MUS3):
# id: 218
# base_score: 300
# section ranking: [90773, 90449, 90386, 90044, 90387]
# schedule: {90449, 90386, 90387, 90773}
# sections enrolled: 4
#
# student219(LA5):
# id: 219
# base_score: 500
# section ranking: [90501, 90537, 90653, 90788, 90544]
# schedule: {90537, 90653, 90788, 90501}
# sections enrolled: 4
#
# student220(HMD5):
# id: 220
# base_score: 500
# section ranking: [90590, 90581, 90578, 90583, 90637]
# schedule: {90637, 90581, 90590}
# sections enrolled: 3
#
# student221(ANT2):
# id: 221
# base_score: 200
# section ranking: [90018, 90562, 90598, 90076, 90643]
# schedule: {90562, 90018, 90598}
# sections enrolled: 3
#
# student222(CHI4):
# id: 222
# base_score: 400
# section ranking: [90586, 90473, 90756, 90469, 90107]
# schedule: {90473, 90586, 90756, 90469}
# sections enrolled: 4
#
# student223(EAS5):
# id: 223
# base_score: 500
# section ranking: [90772, 90220, 90538, 90491, 90290]
# schedule: {90220, 90290, 90491, 90772}
# sections enrolled: 4
#
# student224(GRK1):
# id: 224
# base_score: 100
# section ranking: [90561, 90570, 90580, 90590, 90804]
# schedule: {90561, 90570, 90804}
# sections enrolled: 3
#
# student225(GC3):
# id: 225
# base_score: 300
# section ranking: [90488, 90046, 90093, 90819, 90050]
# schedule: {90050, 90819, 90046}
# sections enrolled: 3
#
# student226(PAX1):
# id: 226
# base_score: 100
# section ranking: [90046, 90374, 90516, 90479, 90513]
# schedule: {90513, 90479}
# sections enrolled: 2
#
# student227(SOC1):
# id: 227
# base_score: 100
# section ranking: [90271, 90272, 90591, 90160, 90791]
# schedule: {90272}
# sections enrolled: 1
#
# student228(GC3):
# id: 228
# base_score: 300
# section ranking: [90337, 90096, 90488, 90319, 90555]
# schedule: {90337, 90319}
# sections enrolled: 2
#
# student229(ITL5):
# id: 229
# base_score: 500
# section ranking: [90619, 90126, 90035, 90625, 90562]
# schedule: {90625, 90562, 90619, 90126}
# sections enrolled: 4
#
# student230(SJS3):
# id: 230
# base_score: 300
# section ranking: [90277, 90684, 90663, 90078, 90084]
# schedule: {90684, 90277, 90078}
# sections enrolled: 3
#
# student231(ARC1):
# id: 231
# base_score: 100
# section ranking: [90037, 90822, 90756, 90472, 90774]
# schedule: {90472, 90756}
# sections enrolled: 2
#
# student232(ANT3):
# id: 232
# base_score: 300
# section ranking: [90702, 90822, 90018, 90389, 90040]
# schedule: {90040, 90018, 90822, 90702}
# sections enrolled: 4
#
# student233(PAX2):
# id: 233
# base_score: 200
# section ranking: [90374, 90497, 90611, 90577, 90700]
# schedule: {90497, 90611}
# sections enrolled: 2
#
# student234(JS5):
# id: 234
# base_score: 500
# section ranking: [90551, 90513, 90345, 90326, 90642]
# schedule: {90513, 90642, 90345, 90551}
# sections enrolled: 4
#
# student235(DAT1):
# id: 235
# base_score: 100
# section ranking: [90218, 90017, 90500, 90643, 90645]
# schedule: {90017, 90643, 90500}
# sections enrolled: 3
#
# student236(LIN3):
# id: 236
# base_score: 300
# section ranking: [90114, 90516, 90273, 90764, 90684]
# schedule: {90273, 90114, 90516, 90764}
# sections enrolled: 4
#
# student237(ANT1):
# id: 237
# base_score: 100
# section ranking: [90025, 90020, 90610, 90181, 90386]
# schedule: {90025, 90610, 90020}
# sections enrolled: 3
#
# student238(DAN2):
# id: 238
# base_score: 200
# section ranking: [90040, 90790, 90768, 90271, 90177]
# schedule: {90177, 90768, 90271}
# sections enrolled: 3
#
# student239(GOV2):
# id: 239
# base_score: 200
# section ranking: [90562, 90531, 90086, 90812, 90532]
# schedule: {90562, 90531, 90812, 90086}
# sections enrolled: 4
#
# student240(DAN3):
# id: 240
# base_score: 300
# section ranking: [90701, 90448, 90600, 90699, 90191]
# schedule: {90448, 90699, 90701}
# sections enrolled: 3
#
# student241(HIS5):
# id: 241
# base_score: 500
# section ranking: [90188, 90548, 90207, 90690, 90813]
# schedule: {90690, 90188, 90813, 90207}
# sections enrolled: 4
#
# student242(SJS2):
# id: 242
# base_score: 200
# section ranking: [90277, 90301, 90449, 90823, 90237]
# schedule: {90237, 90301, 90823}
# sections enrolled: 3
#
# student243(CRE2):
# id: 243
# base_score: 200
# section ranking: [90275, 90800, 90664, 90637, 90776]
# schedule: {90800, 90664, 90275, 90637}
# sections enrolled: 4
#
# student244(EDU5):
# id: 244
# base_score: 500
# section ranking: [90244, 90241, 90246, 90242, 90156]
# schedule: {90241, 90242, 90244, 90156}
# sections enrolled: 4
#
# student245(MSM1):
# id: 245
# base_score: 100
# section ranking: [90257, 90332, 90014, 90131, 90188]
# schedule: {90257, 90188}
# sections enrolled: 2
#
# student246(PKP2):
# id: 246
# base_score: 200
# section ranking: [90682, 90539, 90327, 90521, 90811]
# schedule: {90521, 90682, 90539, 90811}
# sections enrolled: 4
#
# student248(DAT5):
# id: 248
# base_score: 500
# section ranking: [90160, 90636, 90753, 90073, 90218]
# schedule: {90160, 90753, 90636, 90073}
# sections enrolled: 4
#
# student249(GC3):
# id: 249
# base_score: 300
# section ranking: [90789, 90273, 90488, 90171, 90552]
# schedule: {90552, 90273, 90789}
# sections enrolled: 3
#
# student250(GWS5):
# id: 250
# base_score: 500
# section ranking: [90704, 90829, 90565, 90589, 90268]
# schedule: {90704, 90565, 90829, 90589}
# sections enrolled: 4
#
# student251(GER5):
# id: 251
# base_score: 500
# section ranking: [90494, 90516, 90292, 90096, 90503]
# schedule: {90292, 90516, 90494, 90503}
# sections enrolled: 4
#
# student252(PHE3):
# id: 252
# base_score: 300
# section ranking: [90371, 90354, 90686, 90359, 90364]
# schedule: {90371, 90364, 90686, 90359}
# sections enrolled: 4
#
# student253(MUS3):
# id: 253
# base_score: 300
# section ranking: [90462, 90386, 90449, 90084, 90316]
# schedule: {90449, 90386, 90316, 90462}
# sections enrolled: 4
#
# student254(GC5):
# id: 254
# base_score: 500
# section ranking: [90144, 90558, 90321, 90488, 90020]
# schedule: {90144, 90321, 90558}
# sections enrolled: 3
#
# student255(ART5):
# id: 255
# base_score: 500
# section ranking: [90320, 90811, 90045, 90046, 90054]
# schedule: {90320, 90811, 90045, 90046}
# sections enrolled: 4
#
# student256(PHE2):
# id: 256
# base_score: 200
# section ranking: [90354, 90358, 90055, 90365, 90147]
# schedule: {90365}
# sections enrolled: 1
#
# student257(SPA1):
# id: 257
# base_score: 100
# section ranking: [90208, 90005, 90205, 90651, 90804]
# schedule: {90651, 90804, 90005}
# sections enrolled: 3
#
# student258(GEO1):
# id: 258
# base_score: 100
# section ranking: [90581, 90776, 90260, 90252, 90254]
# schedule: {90581}
# sections enrolled: 1
#
# student259(JPN5):
# id: 259
# base_score: 500
# section ranking: [90553, 90245, 90449, 90511, 90555]
# schedule: {90553, 90555, 90245, 90511}
# sections enrolled: 4
#
# student260(MUS2):
# id: 260
# base_score: 200
# section ranking: [90630, 90469, 90388, 90550, 90467]
# schedule: {90467, 90388, 90469, 90630}
# sections enrolled: 4
#
# student261(ANT1):
# id: 261
# base_score: 100
# section ranking: [90267, 90018, 90052, 90663, 90152]
# schedule: {90018, 90267}
# sections enrolled: 2
#
# student262(DAN5):
# id: 262
# base_score: 500
# section ranking: [90693, 90466, 90548, 90197, 90186]
# schedule: {90466, 90197, 90548, 90693}
# sections enrolled: 4
#
# student263(ITL5):
# id: 263
# base_score: 500
# section ranking: [90567, 90315, 90696, 90138, 90774]
# schedule: {90696, 90138, 90315, 90567}
# sections enrolled: 4
#
# student264(BIO3):
# id: 264
# base_score: 300
# section ranking: [90642, 90005, 90075, 90077, 90305]
# schedule: {90305, 90642, 90075, 90005}
# sections enrolled: 4
#
# student265(PHE4):
# id: 265
# base_score: 400
# section ranking: [90352, 90355, 90551, 90482, 90098]
# schedule: {90352, 90098, 90355, 90551}
# sections enrolled: 4
#
# student266(BIO2):
# id: 266
# base_score: 200
# section ranking: [90675, 90087, 90086, 90090, 90536]
# schedule: {90536, 90090, 90675}
# sections enrolled: 3
#
# student267(HMD5):
# id: 267
# base_score: 500
# section ranking: [90583, 90578, 90009, 90574, 90520]
# schedule: {90009, 90578, 90574, 90583}
# sections enrolled: 4
#
# student268(FDP4):
# id: 268
# base_score: 400
# section ranking: [90303, 90294, 90131, 90208, 90145]
# schedule: {90208, 90145, 90131, 90303}
# sections enrolled: 4
#
# student269(PKP5):
# id: 269
# base_score: 500
# section ranking: [90589, 90327, 90578, 90583, 90097]
# schedule: {90578, 90583, 90589, 90327}
# sections enrolled: 4
#
# student270(ES1):
# id: 270
# base_score: 100
# section ranking: [90013, 90107, 90293, 90257, 90143]
# schedule: {90257, 90293}
# sections enrolled: 2
#
# student271(MRC2):
# id: 271
# base_score: 200
# section ranking: [90597, 90645, 90491, 90358, 90482]
# schedule: {90645, 90597}
# sections enrolled: 2
#
# student272(MRC5):
# id: 272
# base_score: 500
# section ranking: [90491, 90657, 90253, 90390, 90281]
# schedule: {90657, 90491, 90253}
# sections enrolled: 3
#
# student273(ART1):
# id: 273
# base_score: 100
# section ranking: [90050, 90044, 90598, 90285, 90039]
# schedule: {90044, 90598}
# sections enrolled: 2
#
# student274(NEU3):
# id: 274
# base_score: 300
# section ranking: [90581, 90097, 90125, 90308, 90302]
# schedule: {90125, 90581}
# sections enrolled: 2
#
# student275(HBR2):
# id: 275
# base_score: 200
# section ranking: [90600, 90583, 90387, 90669, 90499]
# schedule: {90387, 90499, 90583}
# sections enrolled: 3
#
# student277(ECO3):
# id: 277
# base_score: 300
# section ranking: [90695, 90225, 90608, 90640, 90257]
# schedule: {90640, 90225, 90257, 90695}
# sections enrolled: 4
#
# student278(CLA3):
# id: 278
# base_score: 300
# section ranking: [90634, 90285, 90138, 90137, 90262]
# schedule: {90137, 90634, 90138, 90285}
# sections enrolled: 4
#
# student279(ENT1):
# id: 279
# base_score: 100
# section ranking: [90248, 90247, 90694, 90075, 90281]
# schedule: {90281, 90694}
# sections enrolled: 2
#
# student280(FDP2):
# id: 280
# base_score: 200
# section ranking: [90551, 90294, 90595, 90842, 90635]
# schedule: {90635, 90595, 90551}
# sections enrolled: 3
#
# student281(ARA5):
# id: 281
# base_score: 500
# section ranking: [90032, 90059, 90033, 90571, 90222]
# schedule: {90032, 90033, 90059, 90571}
# sections enrolled: 4
#
# student282(MUS5):
# id: 282
# base_score: 500
# section ranking: [90132, 90208, 90006, 90463, 90277]
# schedule: {90208, 90132, 90463}
# sections enrolled: 3
#
# student283(MAT1):
# id: 283
# base_score: 100
# section ranking: [90224, 90638, 90499, 90500, 90308]
# schedule: {90224, 90499, 90500, 90638}
# sections enrolled: 4
#
# student284(FYS3):
# id: 284
# base_score: 300
# section ranking: [90342, 90487, 90447, 90336, 90484]
# schedule: {90336, 90447, 90342, 90487}
# sections enrolled: 4
#
# student285(CHI5):
# id: 285
# base_score: 500
# section ranking: [90673, 90116, 90109, 90057, 90011]
# schedule: {90673, 90011, 90116, 90057}
# sections enrolled: 4
#
# student286(PKP2):
# id: 286
# base_score: 200
# section ranking: [90122, 90327, 90796, 90333, 90646]
# schedule: {90122, 90796, 90646}
# sections enrolled: 3
#
# student287(ENT5):
# id: 287
# base_score: 500
# section ranking: [90192, 90247, 90235, 90315, 90131]
# schedule: {90192, 90235, 90315, 90247}
# sections enrolled: 4
#
# student288(IS1):
# id: 288
# base_score: 100
# section ranking: [90571, 90478, 90573, 90591, 90625]
# schedule: {90625}
# sections enrolled: 1
#
# student289(STA3):
# id: 289
# base_score: 300
# section ranking: [90193, 90194, 90195, 90192, 90196]
# schedule: {90192, 90193, 90194, 90195}
# sections enrolled: 4
#
# student290(FLM5):
# id: 290
# base_score: 500
# section ranking: [90829, 90296, 90268, 90103, 90316]
# schedule: {90296, 90268, 90829}
# sections enrolled: 3
#
# student291(AHI3):
# id: 291
# base_score: 300
# section ranking: [90005, 90618, 90015, 90634, 90017]
# schedule: {90017, 90618, 90005}
# sections enrolled: 3
#
# student292(AFR5):
# id: 292
# base_score: 500
# section ranking: [90266, 90012, 90656, 90765, 90592]
# schedule: {90592, 90266, 90765}
# sections enrolled: 3
#
# student293(CHM3):
# id: 293
# base_score: 300
# section ranking: [90286, 90121, 90482, 90355, 90670]
# schedule: {90121, 90482, 90355, 90286}
# sections enrolled: 4
#
# student294(GC5):
# id: 294
# base_score: 500
# section ranking: [90488, 90499, 90573, 90182, 90792]
# schedule: {90488, 90499, 90182, 90792}
# sections enrolled: 4
#
# student295(PHI2):
# id: 295
# base_score: 200
# section ranking: [90342, 90341, 90059, 90591, 90106]
# schedule: {90341, 90342, 90591}
# sections enrolled: 3
#
# student296(RUS4):
# id: 296
# base_score: 400
# section ranking: [90278, 90280, 90257, 90447, 90680]
# schedule: {90280, 90257, 90278, 90447}
# sections enrolled: 4
#
# student297(PSY4):
# id: 297
# base_score: 400
# section ranking: [90300, 90319, 90643, 90223, 90320]
# schedule: {90643, 90300, 90319}
# sections enrolled: 3
#
# student298(HIS1):
# id: 298
# base_score: 100
# section ranking: [90247, 90776, 90641, 90090, 90593]
# schedule: {90776, 90641, 90090}
# sections enrolled: 3
#
# student299(SLA5):
# id: 299
# base_score: 500
# section ranking: [90349, 90617, 90276, 90680, 90473]
# schedule: {90680, 90617, 90276, 90349}
# sections enrolled: 4
#
# student300(GWS5):
# id: 300
# base_score: 500
# section ranking: [90834, 90594, 90655, 90589, 90349]
# schedule: {90834, 90594, 90589, 90655}
# sections enrolled: 4
#
# student301(GOV2):
# id: 301
# base_score: 200
# section ranking: [90557, 90580, 90592, 90644, 90564]
# schedule: {90592, 90564, 90644, 90557}
# sections enrolled: 4
#
# student302(MRC4):
# id: 302
# base_score: 400
# section ranking: [90491, 90648, 90313, 90776, 90834]
# schedule: {90648, 90313, 90834, 90491}
# sections enrolled: 4
#
# student303(FYS4):
# id: 303
# base_score: 400
# section ranking: [90113, 90480, 90544, 90688, 90629]
# schedule: {90480, 90113, 90688, 90544}
# sections enrolled: 4
#
# student304(HIS5):
# id: 304
# base_score: 500
# section ranking: [90261, 90616, 90450, 90626, 90619]
# schedule: {90616, 90450, 90626, 90261}
# sections enrolled: 4
#
# student305(GIS3):
# id: 305
# base_score: 300
# section ranking: [90269, 90127, 90023, 90367, 90535]
# schedule: {90535, 90367, 90127}
# sections enrolled: 3
#
# student306(ART1):
# id: 306
# base_score: 100
# section ranking: [90047, 90248, 90044, 90301, 90046]
# schedule: {90044, 90301}
# sections enrolled: 2
#
# student307(GEO2):
# id: 307
# base_score: 200
# section ranking: [90252, 90477, 90289, 90254, 90550]
# schedule: {90252, 90477, 90550}
# sections enrolled: 3
#
# student308(HBR2):
# id: 308
# base_score: 200
# section ranking: [90122, 90600, 90152, 90474, 90485]
# schedule: {90122, 90485}
# sections enrolled: 2
#
# student309(AHI3):
# id: 309
# base_score: 300
# section ranking: [90579, 90634, 90157, 90019, 90108]
# schedule: {90019, 90634, 90579, 90157}
# sections enrolled: 4
#
# student310(GIS4):
# id: 310
# base_score: 400
# section ranking: [90535, 90643, 90215, 90269, 90618]
# schedule: {90618, 90643, 90215, 90535}
# sections enrolled: 4
#
# student311(MAT3):
# id: 311
# base_score: 300
# section ranking: [90497, 90512, 90515, 90511, 90510]
# schedule: {90512, 90497, 90515, 90511}
# sections enrolled: 4
#
# student312(AHI1):
# id: 312
# base_score: 100
# section ranking: [90555, 90157, 90540, 90466, 90004]
# schedule: {90466, 90004, 90157}
# sections enrolled: 3
#
# student313(MRC5):
# id: 313
# base_score: 500
# section ranking: [90542, 90491, 90289, 90151, 90592]
# schedule: {90289, 90491, 90542, 90151}
# sections enrolled: 4
#
# student314(PHY3):
# id: 314
# base_score: 300
# section ranking: [90232, 90291, 90336, 90188, 90329]
# schedule: {90232, 90336, 90291, 90188}
# sections enrolled: 4
#
# student315(JPN5):
# id: 315
# base_score: 500
# section ranking: [90151, 90552, 90554, 90294, 90667]
# schedule: {90552, 90554, 90294, 90151}
# sections enrolled: 4
#
# student316(CHI2):
# id: 316
# base_score: 200
# section ranking: [90108, 90673, 90109, 90040, 90107]
# schedule: {90040}
# sections enrolled: 1
#
# student317(BIO1):
# id: 317
# base_score: 100
# section ranking: [90075, 90259, 90789, 90086, 90167]
# schedule: {90789, 90086, 90259, 90167}
# sections enrolled: 4
#
# student318(ENG2):
# id: 318
# base_score: 200
# section ranking: [90802, 90482, 90791, 90649, 90218]
# schedule: {90649, 90802, 90482}
# sections enrolled: 3
#
# student319(LA1):
# id: 319
# base_score: 100
# section ranking: [90822, 90544, 90281, 90542, 90558]
# schedule: {90281, 90558}
# sections enrolled: 2
#
# student320(AHI2):
# id: 320
# base_score: 200
# section ranking: [90475, 90638, 90004, 90013, 90595]
# schedule: {90595, 90004, 90638}
# sections enrolled: 3
#
# student321(ART3):
# id: 321
# base_score: 300
# section ranking: [90140, 90036, 90044, 90032, 90040]
# schedule: {90036, 90140, 90044}
# sections enrolled: 3
#
# student322(RUS5):
# id: 322
# base_score: 500
# section ranking: [90047, 90607, 90280, 90679, 90783]
# schedule: {90280, 90607, 90047}
# sections enrolled: 3
#
# student323(FRH5):
# id: 323
# base_score: 500
# section ranking: [90476, 90474, 90475, 90477, 90794]
# schedule: {90474, 90475, 90476, 90477}
# sections enrolled: 4
#
# student324(CHI5):
# id: 324
# base_score: 500
# ...
#
# student2895(AT1):
# id: 2895
# base_score: 100
# section ranking: [90029, 90281, 90817, 90060, 90012]
# schedule: {90281, 90029}
# sections enrolled: 2
#
# student2896(ARA3):
# id: 2896
# base_score: 300
# section ranking: [90829, 90033, 90032, 90579, 90223]
# schedule: {90829}
# sections enrolled: 1
#
# student2897(LA5):
# id: 2897
# base_score: 500
# section ranking: [90215, 90163, 90550, 90699, 90543]
# schedule: {90699, 90163, 90550, 90215}
# sections enrolled: 4
#
# student2898(DAN5):
# id: 2898
# base_score: 500
# section ranking: [90012, 90447, 90184, 90644, 90183]
# schedule: {90184, 90012, 90644, 90183}
# sections enrolled: 4
#
# student2899(ENT2):
# id: 2899
# base_score: 200
# section ranking: [90247, 90509, 90248, 90568, 90184]
# schedule: {90248, 90568, 90509, 90247}
# sections enrolled: 4
#
# student2900(PHI3):
# id: 2900
# base_score: 300
# section ranking: [90193, 90341, 90348, 90342, 90572]
# schedule: {90193, 90348, 90341, 90342}
# sections enrolled: 4
#
# student2901(PKP5):
# id: 2901
# base_score: 500
# section ranking: [90013, 90511, 90157, 90327, 90292]
# schedule: {90327, 90292, 90013, 90511}
# sections enrolled: 4
#
# student2902(AT4):
# id: 2902
# base_score: 400
# section ranking: [90295, 90060, 90507, 90149, 90484]
# schedule: {90484, 90507, 90060, 90295}
# sections enrolled: 4
#
# student2903(LA4):
# id: 2903
# base_score: 400
# section ranking: [90836, 90640, 90549, 90591, 90536]
# schedule: {90640, 90836, 90549, 90591}
# sections enrolled: 4
#
# student2904(AHI5):
# id: 2904
# base_score: 500
# section ranking: [90015, 90013, 90545, 90485, 90157]
# schedule: {90545, 90485, 90013, 90015}
# sections enrolled: 4
#
# student2905(LAT1):
# id: 2905
# base_score: 100
# section ranking: [90518, 90509, 90566, 90644, 90519]
# schedule: {90644, 90566, 90509}
# sections enrolled: 3
#
# student2906(PBH1):
# id: 2906
# base_score: 100
# section ranking: [90375, 90376, 90206, 90280, 90600]
# schedule: {90206}
# sections enrolled: 1
#
# student2907(EDU5):
# id: 2907
# base_score: 500
# section ranking: [90243, 90836, 90244, 90242, 90681]
# schedule: {90244, 90242, 90243, 90836}
# sections enrolled: 4
#
# student2908(ASL2):
# id: 2908
# base_score: 200
# section ranking: [90595, 90778, 90055, 90582, 90656]
# schedule: {90656, 90595, 90582}
# sections enrolled: 3
#
# student2909(ARC3):
# id: 2909
# base_score: 300
# section ranking: [90693, 90594, 90010, 90822, 90134]
# schedule: {90594, 90693, 90822, 90010}
# sections enrolled: 4
#
# student2910(ART2):
# id: 2910
# base_score: 200
# section ranking: [90242, 90811, 90590, 90050, 90203]
# schedule: {90242, 90203, 90811, 90590}
# sections enrolled: 4
#
# student2911(PHY1):
# id: 2911
# base_score: 100
# section ranking: [90232, 90332, 90302, 90099, 90333]
# schedule: {90099, 90332}
# sections enrolled: 2
#
# student2912(HIS4):
# id: 2912
# base_score: 400
# section ranking: [90619, 90060, 90621, 90612, 90672]
# schedule: {90612, 90619, 90060, 90621}
# sections enrolled: 4
#
# student2913(LIN4):
# id: 2913
# base_score: 400
# section ranking: [90597, 90684, 90516, 90138, 90143]
# schedule: {90516, 90138, 90684, 90597}
# sections enrolled: 4
#
# student2914(HIS5):
# id: 2914
# base_score: 500
# section ranking: [90608, 90555, 90607, 90612, 90702]
# schedule: {90608, 90555, 90612, 90607}
# sections enrolled: 4
#
# student2915(PHE1):
# id: 2915
# base_score: 100
# section ranking: [90105, 90652, 90058, 90352, 90666]
# schedule: {90352, 90666, 90652}
# sections enrolled: 3
#
# student2916(CHI5):
# id: 2916
# base_score: 500
# section ranking: [90587, 90673, 90468, 90107, 90109]
# schedule: {90673, 90587, 90468, 90107}
# sections enrolled: 4
#
# student2917(HMD4):
# id: 2917
# base_score: 400
# section ranking: [90770, 90635, 90041, 90090, 90790]
# schedule: {90041, 90770, 90635, 90090}
# sections enrolled: 4
#
# student2918(GWS5):
# id: 2918
# base_score: 500
# section ranking: [90319, 90792, 90240, 90842, 90309]
# schedule: {90240, 90842, 90319}
# sections enrolled: 3
#
# student2919(PAX4):
# id: 2919
# base_score: 400
# section ranking: [90702, 90827, 90374, 90326, 90285]
# schedule: {90827, 90285, 90702, 90374}
# sections enrolled: 4
#
# student2920(CHI2):
# id: 2920
# base_score: 200
# section ranking: [90107, 90303, 90260, 90168, 90500]
# schedule: {90500, 90303}
# sections enrolled: 2
#
# student2921(PHY1):
# id: 2921
# base_score: 100
# section ranking: [90078, 90819, 90328, 90015, 90331]
# schedule: {90328, 90819, 90078, 90015}
# sections enrolled: 4
#
# student2922(THE2):
# id: 2922
# base_score: 200
# section ranking: [90022, 90150, 90156, 90012, 90160]
# schedule: {90150, 90156, 90022}
# sections enrolled: 3
#
# student2923(HIS2):
# id: 2923
# base_score: 200
# section ranking: [90621, 90560, 90103, 90525, 90612]
# schedule: {90560, 90621, 90525, 90103}
# sections enrolled: 4
#
# student2924(DAT1):
# id: 2924
# base_score: 100
# section ranking: [90218, 90045, 90701, 90044, 90280]
# schedule: {90701, 90044, 90045}
# sections enrolled: 3
#
# student2925(ARC3):
# id: 2925
# base_score: 300
# section ranking: [90823, 90842, 90031, 90010, 90553]
# schedule: {90823, 90031, 90553, 90010}
# sections enrolled: 4
#
# student2926(FYS2):
# id: 2926
# base_score: 200
# section ranking: [90076, 90766, 90483, 90767, 90739]
# schedule: {90483, 90766}
# sections enrolled: 2
#
# student2927(GIS1):
# id: 2927
# base_score: 100
# section ranking: [90251, 90689, 90022, 90620, 90269]
# schedule: {90689, 90251, 90022}
# sections enrolled: 3
#
# student2928(ACC3):
# id: 2928
# base_score: 300
# section ranking: [90003, 90291, 90002, 90244, 90264]
# schedule: {90002, 90003, 90244, 90291}
# sections enrolled: 4
#
# student2929(GOV5):
# id: 2929
# base_score: 500
# section ranking: [90795, 90478, 90522, 90533, 90264]
# schedule: {90795, 90533, 90478}
# sections enrolled: 3
#
# student2930(BIO4):
# id: 2930
# base_score: 400
# section ranking: [90084, 90078, 90073, 90082, 90141]
# schedule: {90073, 90084, 90078}
# sections enrolled: 3
#
# student2931(FYS1):
# id: 2931
# base_score: 100
# section ranking: [90588, 90235, 90039, 90694, 90486]
# schedule: {90235, 90588, 90694, 90039}
# sections enrolled: 4
#
# student2932(FLM1):
# id: 2932
# base_score: 100
# section ranking: [90296, 90316, 90308, 90696, 90295]
# schedule: {90296, 90308}
# sections enrolled: 2
#
# student2933(BIO4):
# id: 2933
# base_score: 400
# section ranking: [90083, 90074, 90090, 90571, 90499]
# schedule: {90074, 90083, 90090, 90571}
# sections enrolled: 4
#
# student2934(LA2):
# id: 2934
# base_score: 200
# section ranking: [90651, 90817, 90820, 90532, 90544]
# schedule: {90817, 90532, 90651, 90820}
# sections enrolled: 4
#
# student2935(PHI3):
# id: 2935
# base_score: 300
# section ranking: [90338, 90625, 90572, 90347, 90204]
# schedule: {90625, 90338, 90347, 90572}
# sections enrolled: 4
#
# student2936(GEO3):
# id: 2936
# base_score: 300
# section ranking: [90822, 90254, 90260, 90515, 90343]
# schedule: {90254, 90260, 90822, 90343}
# sections enrolled: 4
#
# student2937(DAN3):
# id: 2937
# base_score: 300
# section ranking: [90699, 90538, 90183, 90143, 90171]
# schedule: {90538, 90699, 90143}
# sections enrolled: 3
#
# student2938(ANT2):
# id: 2938
# base_score: 200
# section ranking: [90150, 90017, 90562, 90333, 90545]
# schedule: {90017, 90562, 90150, 90545}
# sections enrolled: 4
#
# student2939(JS4):
# id: 2939
# base_score: 400
# section ranking: [90551, 90591, 90508, 90345, 90319]
# schedule: {90345, 90591, 90508, 90551}
# sections enrolled: 4
#
# student2940(AHI5):
# id: 2940
# base_score: 500
# section ranking: [90634, 90009, 90027, 90005, 90590]
# schedule: {90009, 90634, 90027, 90590}
# sections enrolled: 4
#
# student2941(GOV5):
# id: 2941
# base_score: 500
# section ranking: [90524, 90525, 90643, 90598, 90549]
# schedule: {90643, 90524, 90525, 90549}
# sections enrolled: 4
#
# student2943(AFR3):
# id: 2943
# base_score: 300
# section ranking: [90266, 90825, 90718, 90713, 90086]
# schedule: {90825, 90266}
# sections enrolled: 2
#
# student2944(ART5):
# id: 2944
# base_score: 500
# section ranking: [90166, 90046, 90217, 90816, 90590]
# schedule: {90816, 90217, 90046, 90166}
# sections enrolled: 4
#
# student2945(HIS5):
# id: 2945
# base_score: 500
# section ranking: [90689, 90621, 90486, 90081, 90281]
# schedule: {90081, 90689, 90621, 90486}
# sections enrolled: 4
#
# student2946(PHY1):
# id: 2946
# base_score: 100
# section ranking: [90332, 90669, 90627, 90330, 90218]
# schedule: {90330, 90332, 90669}
# sections enrolled: 3
#
# student2947(ITL4):
# id: 2947
# base_score: 400
# section ranking: [90165, 90697, 90561, 90451, 90651]
# schedule: {90697, 90451, 90561, 90165}
# sections enrolled: 4
#
# student2948(MRC1):
# id: 2948
# base_score: 100
# section ranking: [90491, 90803, 90851, 90220, 90517]
# schedule: {90803, 90851}
# sections enrolled: 2
#
# student2949(FRH5):
# id: 2949
# base_score: 500
# section ranking: [90472, 90475, 90478, 90477, 90031]
# schedule: {90472, 90475, 90477, 90478}
# sections enrolled: 4
#
# student2950(ANT2):
# id: 2950
# base_score: 200
# section ranking: [90598, 90614, 90134, 90026, 90018]
# schedule: {90018, 90026, 90598, 90614}
# sections enrolled: 4
#
# student2951(PSY1):
# id: 2951
# base_score: 100
# section ranking: [90321, 90216, 90242, 90098, 90564]
# schedule: {90321, 90564, 90216}
# sections enrolled: 3
#
# student2952(LAT2):
# id: 2952
# base_score: 200
# section ranking: [90308, 90518, 90276, 90519, 90683]
# schedule: {90308, 90518}
# sections enrolled: 2
#
# student2953(DAN3):
# id: 2953
# base_score: 300
# section ranking: [90673, 90651, 90184, 90536, 90701]
# schedule: {90184, 90673, 90651, 90536}
# sections enrolled: 4
#
# student2954(NEU5):
# id: 2954
# base_score: 500
# section ranking: [90531, 90851, 90280, 90302, 90287]
# schedule: {90280, 90287, 90531, 90851}
# sections enrolled: 4
#
# student2955(GWS3):
# id: 2955
# base_score: 300
# section ranking: [90595, 90812, 90584, 90661, 90576]
# schedule: {90576, 90595, 90812}
# sections enrolled: 3
#
# student2956(PHE2):
# id: 2956
# base_score: 200
# section ranking: [90555, 90656, 90128, 90257, 90366]
# schedule: {90656, 90257}
# sections enrolled: 2
#
# student2957(PHI4):
# id: 2957
# base_score: 400
# section ranking: [90113, 90341, 90344, 90222, 90338]
# schedule: {90344, 90113, 90341, 90222}
# sections enrolled: 4
#
# student2958(GIS1):
# id: 2958
# base_score: 100
# section ranking: [90535, 90247, 90107, 90827, 90620]
# schedule: {90827}
# sections enrolled: 1
#
# student2959(SOC4):
# id: 2959
# base_score: 400
# section ranking: [90630, 90635, 90776, 90833, 90195]
# schedule: {90195, 90635, 90630}
# sections enrolled: 3
#
# student2960(JS3):
# id: 2960
# base_score: 300
# section ranking: [90551, 90021, 90642, 90074, 90592]
# schedule: {90074, 90642, 90021, 90551}
# sections enrolled: 4
#
# student2961(CRE3):
# id: 2961
# base_score: 300
# section ranking: [90289, 90610, 90096, 90615, 90023]
# schedule: {90096, 90610, 90615}
# sections enrolled: 3
#
# student2962(SLA3):
# id: 2962
# base_score: 300
# section ranking: [90276, 90328, 90222, 90658, 90617]
# schedule: {90328, 90617, 90276}
# sections enrolled: 3
#
# student2963(MUS3):
# id: 2963
# base_score: 300
# section ranking: [90387, 90462, 90774, 90563, 90503]
# schedule: {90774, 90387, 90462, 90563}
# sections enrolled: 4
#
# student2964(HMD4):
# id: 2964
# base_score: 400
# section ranking: [90679, 90587, 90803, 90578, 90574]
# schedule: {90587, 90803, 90679}
# sections enrolled: 3
#
# student2965(SLA4):
# id: 2965
# base_score: 400
# section ranking: [90817, 90666, 90306, 90617, 90092]
# schedule: {90817, 90666, 90617, 90306}
# sections enrolled: 4
#
# student2966(EDU3):
# id: 2966
# base_score: 300
# section ranking: [90006, 90244, 90242, 90517, 90027]
# schedule: {90242, 90244, 90517, 90006}
# sections enrolled: 4
#
# student2967(EAS5):
# id: 2967
# base_score: 500
# section ranking: [90267, 90655, 90633, 90220, 90017]
# schedule: {90633, 90267, 90017, 90655}
# sections enrolled: 4
#
# student2968(EDU1):
# id: 2968
# base_score: 100
# section ranking: [90330, 90671, 90323, 90266, 90448]
# schedule: {90330, 90323, 90671}
# sections enrolled: 3
#
# student2969(PHI1):
# id: 2969
# base_score: 100
# section ranking: [90346, 90572, 90487, 90515, 90146]
# schedule: {90146, 90515, 90572}
# sections enrolled: 3
#
# student2970(BIO2):
# id: 2970
# base_score: 200
# section ranking: [90087, 90531, 90559, 90082, 90009]
# schedule: {90559, 90082, 90531, 90087}
# sections enrolled: 4
#
# student2971(GEO2):
# id: 2971
# base_score: 200
# section ranking: [90252, 90260, 90031, 90254, 90289]
# schedule: {90252, 90031}
# sections enrolled: 2
#
# student2972(MRC1):
# id: 2972
# base_score: 100
# section ranking: [90491, 90450, 90837, 90559, 90228]
# schedule: {90450, 90837}
# sections enrolled: 2
#
# student2973(PHY4):
# id: 2973
# base_score: 400
# section ranking: [90645, 90471, 90288, 90332, 90520]
# schedule: {90288, 90520, 90645, 90471}
# sections enrolled: 4
#
# student2974(ART2):
# id: 2974
# base_score: 200
# section ranking: [90816, 90039, 90036, 90241, 90342]
# schedule: {90816, 90241, 90036, 90039}
# sections enrolled: 4
#
# student2975(PAX1):
# id: 2975
# base_score: 100
# section ranking: [90646, 90374, 90196, 90163, 90626]
# schedule: {90626, 90646}
# sections enrolled: 2
#
# student2976(EDU4):
# id: 2976
# base_score: 400
# section ranking: [90242, 90244, 90026, 90002, 90243]
# schedule: {90026, 90242, 90244, 90002}
# sections enrolled: 4
#
# student2977(GER3):
# id: 2977
# base_score: 300
# section ranking: [90198, 90648, 90502, 90503, 90644]
# schedule: {90502, 90644, 90198}
# sections enrolled: 3
#
# student2978(ANT2):
# id: 2978
# base_score: 200
# section ranking: [90028, 90118, 90793, 90598, 90027]
# schedule: {90793, 90118, 90598}
# sections enrolled: 3
#
# student2979(LAT5):
# id: 2979
# base_score: 500
# section ranking: [90683, 90518, 90106, 90519, 90246]
# schedule: {90106, 90683, 90518, 90519}
# sections enrolled: 4
#
# student2980(DAN1):
# id: 2980
# base_score: 100
# section ranking: [90058, 90171, 90175, 90186, 90045]
# schedule: {90045, 90171, 90175}
# sections enrolled: 3
#
# student2981(PKP4):
# id: 2981
# base_score: 400
# section ranking: [90265, 90327, 90681, 90120, 90491]
# schedule: {90120, 90265, 90681, 90327}
# sections enrolled: 4
#
# student2982(MSM3):
# id: 2982
# base_score: 300
# section ranking: [90600, 90014, 90736, 90590, 90718]
# schedule: {90736, 90718, 90590}
# sections enrolled: 3
#
# student2983(CRT3):
# id: 2983
# base_score: 300
# section ranking: [90168, 90821, 90684, 90530, 90485]
# schedule: {90168, 90530, 90684, 90485}
# sections enrolled: 4
#
# student2984(AST2):
# id: 2984
# base_score: 200
# section ranking: [90058, 90057, 90056, 90321, 90535]
# schedule: {90056, 90321}
# sections enrolled: 2
#
# student2985(ARA3):
# id: 2985
# base_score: 300
# section ranking: [90033, 90266, 90045, 90800, 90032]
# schedule: {90800, 90266, 90045}
# sections enrolled: 3
#
# student2986(ANT2):
# id: 2986
# base_score: 200
# section ranking: [90207, 90319, 90616, 90188, 90598]
# schedule: {90616, 90319, 90188, 90207}
# sections enrolled: 4
#
# student2987(IS2):
# id: 2987
# base_score: 200
# section ranking: [90099, 90532, 90573, 90571, 90358]
# schedule: {90099, 90532, 90573, 90358}
# sections enrolled: 4
#
# student2988(ES1):
# id: 2988
# base_score: 100
# section ranking: [90026, 90251, 90292, 90694, 90182]
# schedule: {90026, 90251, 90292, 90694}
# sections enrolled: 4
#
# student2989(CRE1):
# id: 2989
# base_score: 100
# section ranking: [90484, 90189, 90299, 90182, 90599]
# schedule: {90484, 90189, 90182, 90599}
# sections enrolled: 4
#
# student2990(HIS1):
# id: 2990
# base_score: 100
# section ranking: [90622, 90672, 90641, 90626, 90595]
# schedule: {90626, 90595, 90641, 90622}
# sections enrolled: 4
#
# student2991(LIN4):
# id: 2991
# base_score: 400
# section ranking: [90144, 90644, 90684, 90503, 90516]
# schedule: {90144, 90516, 90644, 90684}
# sections enrolled: 4
#
# student2992(DAN3):
# id: 2992
# base_score: 300
# section ranking: [90701, 90834, 90206, 90096, 90170]
# schedule: {90834, 90170, 90701, 90206}
# sections enrolled: 4
#
# student2993(LIN2):
# id: 2993
# base_score: 200
# section ranking: [90516, 90821, 90803, 90242, 90684]
# schedule: {90242, 90803, 90516, 90821}
# sections enrolled: 4
#
# student2994(SLA2):
# id: 2994
# base_score: 200
# section ranking: [90156, 90287, 90125, 90617, 90135]
# schedule: {90617, 90156, 90125}
# sections enrolled: 3
#
# student2995(FDP5):
# id: 2995
# base_score: 500
# section ranking: [90130, 90562, 90294, 90522, 90815]
# schedule: {90562, 90130, 90294, 90522}
# sections enrolled: 4
#
# student2996(MAT2):
# id: 2996
# base_score: 200
# section ranking: [90511, 90163, 90376, 90700, 90513]
# schedule: {90700, 90511, 90513, 90163}
# sections enrolled: 4
#
# student2997(ART2):
# id: 2997
# base_score: 200
# section ranking: [90354, 90811, 90040, 90041, 90047]
# schedule: {90041, 90354, 90811}
# sections enrolled: 3
#
# student2998(ENG1):
# id: 2998
# base_score: 100
# section ranking: [90700, 90684, 90481, 90207, 90649]
# schedule: {90481, 90700, 90649, 90207}
# sections enrolled: 4
#
# student2999(FYS2):
# id: 2999
# base_score: 200
# section ranking: [90688, 90697, 90689, 90482, 90483]
# schedule: {90688, 90697, 90689}
# sections enrolled: 3

# %%
to_pop = []
for id, section in sections.items():
    if section.dept != "COM":
        to_pop.append(id)
for id in to_pop:
    sections.pop(id)
student_dict = data.generate_students_weighted(sections, 60)
for key in student_dict:
    student_dict[key].find_conflicts(sections)
    print(student_dict[key].conflicts_dict)
# Out:
# {90144: set(), 90166: set(), 90139: set(), 90142: set(), 90163: set()}
# {90165: set(), 90139: {90145}, 90145: {90139}, 90166: set(), 90164: set()}
# {90145: set(), 90142: set(), 90146: set(), 90164: set(), 90148: set()}
# {90145: set(), 90143: set(), 90146: set(), 90334: set(), 90167: set()}
# {90334: set(), 90139: set(), 90163: set(), 90146: set(), 90142: set()}
# {90164: set(), 90146: set(), 90163: set(), 90148: set(), 90139: set()}
# {90145: set(), 90140: set(), 90143: set(), 90146: set(), 90163: set()}
# {90146: set(), 90142: set(), 90754: set(), 90147: set(), 90334: set()}
# {90165: set(), 90140: {90166}, 90146: set(), 90166: {90140}, 90145: set()}
# {90147: {90143}, 90140: set(), 90334: set(), 90143: {90147}, 90167: set()}
# {90165: set(), 90147: {90143}, 90143: {90147}, 90163: set(), 90164: set()}
# {90140: set(), 90147: set(), 90139: {90145}, 90145: {90139}, 90165: set()}
# {90164: set(), 90142: set(), 90139: set(), 90146: set(), 90754: set()}
# {90144: set(), 90147: set(), 90145: set(), 90164: set(), 90334: set()}
# {90164: set(), 90148: set(), 90142: set(), 90145: set(), 90334: set()}
# {90166: set(), 90164: set(), 90146: set(), 90148: set(), 90139: set()}
# {90144: set(), 90145: {90139}, 90139: {90145}, 90147: set(), 90146: set()}
# {90143: {90147}, 90146: set(), 90140: set(), 90164: set(), 90147: {90143}}
# {90163: set(), 90165: set(), 90334: set(), 90754: set(), 90142: set()}
# {90139: set(), 90148: set(), 90166: set(), 90167: set(), 90142: set()}
# {90145: set(), 90166: set(), 90167: set(), 90147: set(), 90148: set()}
# {90166: set(), 90139: {90145}, 90143: set(), 90754: set(), 90145: {90139}}
# {90334: set(), 90165: set(), 90139: set(), 90166: set(), 90146: set()}
# {90334: set(), 90145: set(), 90144: set(), 90164: set(), 90140: set()}
# {90163: set(), 90754: set(), 90143: set(), 90146: set(), 90140: set()}
# {90146: set(), 90754: set(), 90167: set(), 90140: set(), 90148: set()}
# {90139: set(), 90144: set(), 90334: set(), 90165: set(), 90143: set()}
# {90140: set(), 90139: set(), 90143: set(), 90146: set(), 90142: set()}
# {90334: set(), 90146: set(), 90164: set(), 90147: set(), 90167: set()}
# {90147: set(), 90164: set(), 90146: set(), 90148: set(), 90754: set()}
# {90754: set(), 90334: set(), 90145: {90139}, 90139: {90145}, 90167: set()}
# {90140: {90166}, 90166: {90140}, 90148: set(), 90146: set(), 90144: set()}
# {90167: set(), 90163: set(), 90147: set(), 90166: set(), 90334: set()}
# {90147: {90143}, 90146: set(), 90166: set(), 90143: {90147}, 90165: set()}
# {90165: set(), 90144: set(), 90164: set(), 90143: set(), 90146: set()}
# {90146: set(), 90140: set(), 90167: set(), 90165: set(), 90145: set()}
# {90164: set(), 90144: set(), 90163: set(), 90146: set(), 90334: set()}
# {90143: set(), 90148: set(), 90164: set(), 90166: set(), 90145: set()}
# {90163: set(), 90166: set(), 90754: set(), 90146: set(), 90142: set()}
# {90144: set(), 90165: set(), 90143: set(), 90139: set(), 90142: set()}
# {90140: set(), 90165: set(), 90754: set(), 90144: set(), 90334: set()}
# {90139: set(), 90754: set(), 90164: set(), 90144: set(), 90166: set()}
# {90167: set(), 90334: set(), 90163: set(), 90147: set(), 90165: set()}
# {90165: set(), 90143: set(), 90167: set(), 90334: set(), 90166: set()}
# {90165: set(), 90163: set(), 90140: set(), 90147: set(), 90754: set()}
# {90164: set(), 90147: {90143}, 90143: {90147}, 90146: set(), 90148: set()}
# {90139: {90145}, 90146: set(), 90148: set(), 90145: {90139}, 90142: set()}
# {90334: set(), 90146: set(), 90145: set(), 90163: set(), 90165: set()}
# {90163: set(), 90139: {90145}, 90165: set(), 90145: {90139}, 90147: set()}
# {90166: {90140}, 90754: set(), 90140: {90166}, 90144: set(), 90164: set()}
# {90142: set(), 90139: set(), 90334: set(), 90167: set(), 90163: set()}
# {90334: set(), 90164: set(), 90143: set(), 90166: set(), 90165: set()}
# {90142: set(), 90167: set(), 90146: set(), 90164: set(), 90334: set()}
# {90140: {90166}, 90139: set(), 90334: set(), 90166: {90140}, 90754: set()}
# {90164: set(), 90163: set(), 90166: set(), 90165: set(), 90146: set()}
# {90140: set(), 90164: set(), 90145: set(), 90167: set(), 90142: set()}
# {90143: set(), 90754: set(), 90148: set(), 90139: set(), 90164: set()}
# {90143: set(), 90146: set(), 90164: set(), 90148: set(), 90167: set()}
# {90147: {90143}, 90143: {90147}, 90167: set(), 90140: set(), 90144: set()}
# {90166: set(), 90167: set(), 90165: set(), 90145: set(), 90142: set()}

# %%
monte_carlo_gs(student_dict, sections, 10)
# Out:
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# 0

# %%
gs.gale_shapley_match(student_dict, sections)
for id, student in student_dict.items():
    if len(student.enrolled_in) > 3:
        print(student)
# Out:
# student0(COM3):
# id: 0
# base_score: 300
# section ranking: [90144, 90166, 90139, 90142, 90163]
# schedule: {90144, 90139, 90166, 90142}
# sections enrolled: 4
#
# student2(COM3):
# id: 2
# base_score: 300
# section ranking: [90145, 90142, 90146, 90164, 90148]
# schedule: {90145, 90146, 90148, 90142}
# sections enrolled: 4
#
# student6(COM4):
# id: 6
# base_score: 400
# section ranking: [90145, 90140, 90143, 90146, 90163]
# schedule: {90145, 90146, 90140, 90143}
# sections enrolled: 4
#
# student9(COM5):
# id: 9
# base_score: 500
# section ranking: [90147, 90140, 90334, 90143, 90167]
# schedule: {90147, 90140, 90334, 90167}
# sections enrolled: 4
#
# student10(COM5):
# id: 10
# base_score: 500
# section ranking: [90165, 90147, 90143, 90163, 90164]
# schedule: {90163, 90147, 90164, 90165}
# sections enrolled: 4
#
# student11(COM5):
# id: 11
# base_score: 500
# section ranking: [90140, 90147, 90139, 90145, 90165]
# schedule: {90139, 90147, 90140, 90165}
# sections enrolled: 4
#
# student12(COM5):
# id: 12
# base_score: 500
# section ranking: [90164, 90142, 90139, 90146, 90754]
# schedule: {90146, 90139, 90164, 90142}
# sections enrolled: 4
#
# student13(COM4):
# id: 13
# base_score: 400
# section ranking: [90144, 90147, 90145, 90164, 90334]
# schedule: {90144, 90145, 90147, 90164}
# sections enrolled: 4
#
# student14(COM5):
# id: 14
# base_score: 500
# section ranking: [90164, 90148, 90142, 90145, 90334]
# schedule: {90145, 90164, 90148, 90142}
# sections enrolled: 4
#
# student17(COM5):
# id: 17
# base_score: 500
# section ranking: [90143, 90146, 90140, 90164, 90147]
# schedule: {90146, 90140, 90164, 90143}
# sections enrolled: 4
#
# student18(COM3):
# id: 18
# base_score: 300
# section ranking: [90163, 90165, 90334, 90754, 90142]
# schedule: {90754, 90163, 90165, 90142}
# sections enrolled: 4
#
# student19(COM1):
# id: 19
# base_score: 100
# section ranking: [90139, 90148, 90166, 90167, 90142]
# schedule: {90139, 90148, 90166, 90167}
# sections enrolled: 4
#
# student20(COM3):
# id: 20
# base_score: 300
# section ranking: [90145, 90166, 90167, 90147, 90148]
# schedule: {90145, 90147, 90166, 90167}
# sections enrolled: 4
#
# student21(COM1):
# id: 21
# base_score: 100
# section ranking: [90166, 90139, 90143, 90754, 90145]
# schedule: {90754, 90139, 90166, 90143}
# sections enrolled: 4
#
# student22(COM5):
# id: 22
# base_score: 500
# section ranking: [90334, 90165, 90139, 90166, 90146]
# schedule: {90166, 90139, 90165, 90334}
# sections enrolled: 4
#
# student23(COM3):
# id: 23
# base_score: 300
# section ranking: [90334, 90145, 90144, 90164, 90140]
# schedule: {90144, 90145, 90140, 90334}
# sections enrolled: 4
#
# student24(COM1):
# id: 24
# base_score: 100
# section ranking: [90163, 90754, 90143, 90146, 90140]
# schedule: {90754, 90163, 90140, 90143}
# sections enrolled: 4
#
# student25(COM3):
# id: 25
# base_score: 300
# section ranking: [90146, 90754, 90167, 90140, 90148]
# schedule: {90146, 90140, 90167, 90754}
# sections enrolled: 4
#
# student26(COM4):
# id: 26
# base_score: 400
# section ranking: [90139, 90144, 90334, 90165, 90143]
# schedule: {90144, 90139, 90165, 90334}
# sections enrolled: 4
#
# student27(COM5):
# id: 27
# base_score: 500
# section ranking: [90140, 90139, 90143, 90146, 90142]
# schedule: {90146, 90139, 90140, 90143}
# sections enrolled: 4
#
# student28(COM5):
# id: 28
# base_score: 500
# section ranking: [90334, 90146, 90164, 90147, 90167]
# schedule: {90146, 90147, 90164, 90334}
# sections enrolled: 4
#
# student29(COM5):
# id: 29
# base_score: 500
# section ranking: [90147, 90164, 90146, 90148, 90754]
# schedule: {90146, 90147, 90164, 90148}
# sections enrolled: 4
#
# student30(COM4):
# id: 30
# base_score: 400
# section ranking: [90754, 90334, 90145, 90139, 90167]
# schedule: {90145, 90754, 90334, 90167}
# sections enrolled: 4
#
# student31(COM5):
# id: 31
# base_score: 500
# section ranking: [90140, 90166, 90148, 90146, 90144]
# schedule: {90144, 90146, 90140, 90148}
# sections enrolled: 4
#
# student32(COM4):
# id: 32
# base_score: 400
# section ranking: [90167, 90163, 90147, 90166, 90334]
# schedule: {90147, 90163, 90166, 90167}
# sections enrolled: 4
#
# student33(COM4):
# id: 33
# base_score: 400
# section ranking: [90147, 90146, 90166, 90143, 90165]
# schedule: {90146, 90147, 90165, 90166}
# sections enrolled: 4
#
# student34(COM5):
# id: 34
# base_score: 500
# section ranking: [90165, 90144, 90164, 90143, 90146]
# schedule: {90144, 90164, 90165, 90143}
# sections enrolled: 4
#
# student35(COM2):
# id: 35
# base_score: 200
# section ranking: [90146, 90140, 90167, 90165, 90145]
# schedule: {90146, 90140, 90165, 90167}
# sections enrolled: 4
#
# student37(COM4):
# id: 37
# base_score: 400
# section ranking: [90143, 90148, 90164, 90166, 90145]
# schedule: {90166, 90148, 90164, 90143}
# sections enrolled: 4
#
# student38(COM3):
# id: 38
# base_score: 300
# section ranking: [90163, 90166, 90754, 90146, 90142]
# schedule: {90754, 90163, 90146, 90166}
# sections enrolled: 4
#
# student39(COM3):
# id: 39
# base_score: 300
# section ranking: [90144, 90165, 90143, 90139, 90142]
# schedule: {90144, 90139, 90165, 90143}
# sections enrolled: 4
#
# student41(COM3):
# id: 41
# base_score: 300
# section ranking: [90139, 90754, 90164, 90144, 90166]
# schedule: {90144, 90754, 90166, 90139}
# sections enrolled: 4
#
# student42(COM5):
# id: 42
# base_score: 500
# section ranking: [90167, 90334, 90163, 90147, 90165]
# schedule: {90147, 90163, 90334, 90167}
# sections enrolled: 4
#
# student43(COM3):
# id: 43
# base_score: 300
# section ranking: [90165, 90143, 90167, 90334, 90166]
# schedule: {90167, 90165, 90334, 90143}
# sections enrolled: 4
#
# student44(COM5):
# id: 44
# base_score: 500
# section ranking: [90165, 90163, 90140, 90147, 90754]
# schedule: {90147, 90163, 90140, 90165}
# sections enrolled: 4
#
# student45(COM5):
# id: 45
# base_score: 500
# section ranking: [90164, 90147, 90143, 90146, 90148]
# schedule: {90146, 90147, 90164, 90148}
# sections enrolled: 4
#
# student47(COM2):
# id: 47
# base_score: 200
# section ranking: [90334, 90146, 90145, 90163, 90165]
# schedule: {90145, 90146, 90163, 90165}
# sections enrolled: 4
#
# student48(COM5):
# id: 48
# base_score: 500
# section ranking: [90163, 90139, 90165, 90145, 90147]
# schedule: {90139, 90147, 90163, 90165}
# sections enrolled: 4
#
# student49(COM5):
# id: 49
# base_score: 500
# section ranking: [90166, 90754, 90140, 90144, 90164]
# schedule: {90144, 90754, 90164, 90166}
# sections enrolled: 4
#
# student50(COM4):
# id: 50
# base_score: 400
# section ranking: [90142, 90139, 90334, 90167, 90163]
# schedule: {90139, 90334, 90142, 90167}
# sections enrolled: 4
#
# student51(COM5):
# id: 51
# base_score: 500
# section ranking: [90334, 90164, 90143, 90166, 90165]
# schedule: {90166, 90164, 90334, 90143}
# sections enrolled: 4
#
# student52(COM5):
# id: 52
# base_score: 500
# section ranking: [90142, 90167, 90146, 90164, 90334]
# schedule: {90146, 90164, 90142, 90167}
# sections enrolled: 4
#
# student54(COM2):
# id: 54
# base_score: 200
# section ranking: [90164, 90163, 90166, 90165, 90146]
# schedule: {90146, 90163, 90165, 90166}
# sections enrolled: 4
#
# student55(COM3):
# id: 55
# base_score: 300
# section ranking: [90140, 90164, 90145, 90167, 90142]
# schedule: {90145, 90140, 90164, 90167}
# sections enrolled: 4
#
# student56(COM3):
# id: 56
# base_score: 300
# section ranking: [90143, 90754, 90148, 90139, 90164]
# schedule: {90754, 90139, 90148, 90143}
# sections enrolled: 4
#
# student57(COM5):
# id: 57
# base_score: 500
# section ranking: [90143, 90146, 90164, 90148, 90167]
# schedule: {90146, 90164, 90148, 90143}
# sections enrolled: 4
#
# student58(COM5):
# id: 58
# base_score: 500
# section ranking: [90147, 90143, 90167, 90140, 90144]
# schedule: {90144, 90147, 90140, 90167}
# sections enrolled: 4
#
# student59(COM2):
# id: 59
# base_score: 200
# section ranking: [90166, 90167, 90165, 90145, 90142]
# schedule: {90145, 90165, 90166, 90167}
# sections enrolled: 4
