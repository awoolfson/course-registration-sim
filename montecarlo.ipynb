# %%
import copy
import sys
sys.path.append("src")

import data
import gs
import test_stability
from count_potential_rogues import count_potential_rogues

# %%
sections = data.section_JSON_to_dict("scraping/classes.json")
print(len(sections))
student_dict = data.generate_students_weighted(sections, 3000)
for key in student_dict:
    student_dict[key].find_conflicts(sections)
print(count_potential_rogues(student_dict))
# Out:
# 601

# %%
def monte_carlo_gs(student_dict: dict, section_dict: dict, iteration_limit: int = 500) -> int:
    best = float("inf")
    seeds = [i for i in range(1, iteration_limit + 2)]
    i = 0
    while i < iteration_limit:
        i += 1
        
        new_student_dict = copy.deepcopy(student_dict)
        new_section_dict = copy.deepcopy(section_dict)
        new_matching = gs.gale_shapley_match(new_student_dict, new_section_dict, shuffle = True, seed = seeds[i])
        
        rogues = test_stability.is_weakly_stable(new_matching[0], new_matching[1])[1]
        
        if rogues < best:
            best = rogues
            
    return int(best)

# %%
monte_carlo_gs(student_dict, sections, 10)
# Out:
# counter: 2
# counter: 3
# counter: 3
# counter: 3
# counter: 4
# counter: 3
# counter: 3
# counter: 4
# counter: 4
# counter: 2
# 2

# %%
matched_students, matched_sections = gs.gale_shapley_match(copy.deepcopy(student_dict), copy.deepcopy(sections))
for id, s in matched_students.items():
    if len(s.enrolled_in) > 0:
        print(s)
# Out:
# student0(ANT4):
# id: 0
# base_score: 400
# section ranking: [90027, 90028, 90733, 90789, 90006]
# schedule: {90027, 90733, 90789}
# sections enrolled: 3
#
# student1(HMD2):
# id: 1
# base_score: 200
# section ranking: [90581, 90576, 90463, 90563, 90242]
# schedule: {90576, 90242, 90563, 90581}
# sections enrolled: 4
#
# student2(COM2):
# id: 2
# base_score: 200
# section ranking: [90165, 90144, 90167, 90143, 90531]
# schedule: {90144, 90143, 90165, 90167}
# sections enrolled: 4
#
# student3(CRT3):
# id: 3
# base_score: 300
# section ranking: [90090, 90451, 90629, 90168, 90582]
# schedule: {90090, 90451, 90629}
# sections enrolled: 3
#
# student4(MSM4):
# id: 4
# base_score: 400
# section ranking: [90014, 90311, 90480, 90488, 90816]
# schedule: {90480, 90816, 90311}
# sections enrolled: 3
#
# student5(MRC2):
# id: 5
# base_score: 200
# section ranking: [90152, 90543, 90491, 90018, 90168]
# schedule: {90018, 90543}
# sections enrolled: 2
#
# student6(GWS3):
# id: 6
# base_score: 300
# section ranking: [90679, 90055, 90146, 90246, 90588]
# schedule: {90146, 90588, 90246, 90679}
# sections enrolled: 4
#
# student7(BOT5):
# id: 7
# base_score: 500
# section ranking: [90776, 90095, 90094, 90104, 90098]
# schedule: {90776, 90104, 90094, 90095}
# sections enrolled: 4
#
# student8(GC4):
# id: 8
# base_score: 400
# section ranking: [90789, 90488, 90222, 90802, 90667]
# schedule: {90802, 90667, 90789, 90222}
# sections enrolled: 4
#
# student9(BOT4):
# id: 9
# base_score: 400
# section ranking: [90330, 90336, 90097, 90096, 90662]
# schedule: {90336, 90097}
# sections enrolled: 2
#
# student10(JS2):
# id: 10
# base_score: 200
# section ranking: [90189, 90011, 90642, 90006, 90497]
# schedule: {90497, 90011, 90189}
# sections enrolled: 3
#
# student11(CHM4):
# id: 11
# base_score: 400
# section ranking: [90112, 90124, 90131, 90272, 90121]
# schedule: {90112, 90131, 90124, 90272}
# sections enrolled: 4
#
# student12(SJS2):
# id: 12
# base_score: 200
# section ranking: [90223, 90215, 90097, 90277, 90803]
# schedule: {90803, 90215, 90223}
# sections enrolled: 3
#
# student13(ES3):
# id: 13
# base_score: 300
# section ranking: [90264, 90531, 90754, 90257, 90293]
# schedule: {90264, 90754, 90531}
# sections enrolled: 3
#
# student14(ASL3):
# id: 14
# base_score: 300
# section ranking: [90778, 90013, 90285, 90055, 90691]
# schedule: {90691, 90013, 90285}
# sections enrolled: 3
#
# student15(JS3):
# id: 15
# base_score: 300
# section ranking: [90551, 90473, 90324, 90345, 90265]
# schedule: {90473, 90551}
# sections enrolled: 2
#
# student16(CHI1):
# id: 16
# base_score: 100
# section ranking: [90224, 90107, 90181, 90109, 90608]
# schedule: {90224, 90181}
# sections enrolled: 2
#
# student17(AHI1):
# id: 17
# base_score: 100
# section ranking: [90005, 90823, 90026, 90474, 90136]
# schedule: {90026, 90005, 90823}
# sections enrolled: 3
#
# student18(FDP5):
# id: 18
# base_score: 500
# section ranking: [90679, 90294, 90092, 90475, 90523]
# schedule: {90475, 90092, 90294, 90679}
# sections enrolled: 4
#
# student19(AHI5):
# id: 19
# base_score: 500
# section ranking: [90266, 90634, 90823, 90148, 90157]
# schedule: {90266, 90634, 90148, 90823}
# sections enrolled: 4
#
# student20(MRC4):
# id: 20
# base_score: 400
# section ranking: [90491, 90754, 90622, 90053, 90477]
# schedule: {90754, 90491, 90053, 90622}
# sections enrolled: 4
#
# student21(LA2):
# id: 21
# base_score: 200
# section ranking: [90542, 90549, 90153, 90537, 90237]
# schedule: {90153, 90537, 90237, 90542}
# sections enrolled: 4
#
# student22(BIO2):
# id: 22
# base_score: 200
# section ranking: [90074, 90045, 90083, 90141, 90774]
# schedule: {90141, 90074, 90083, 90045}
# sections enrolled: 4
#
# student24(ES5):
# id: 24
# base_score: 500
# section ranking: [90125, 90076, 90259, 90100, 90250]
# schedule: {90250, 90076, 90125, 90100}
# sections enrolled: 4
#
# student25(PBH5):
# id: 25
# base_score: 500
# section ranking: [90375, 90259, 90376, 90547, 90501]
# schedule: {90376, 90259, 90375}
# sections enrolled: 3
#
# student26(GIS3):
# id: 26
# base_score: 300
# section ranking: [90157, 90834, 90269, 90343, 90320]
# schedule: {90320, 90834, 90157, 90343}
# sections enrolled: 4
#
# student27(PHI3):
# id: 27
# base_score: 300
# section ranking: [90090, 90524, 90348, 90184, 90328]
# schedule: {90328, 90090, 90524, 90348}
# sections enrolled: 4
#
# student28(PHE4):
# id: 28
# base_score: 400
# section ranking: [90353, 90120, 90365, 90355, 90371]
# schedule: {90120, 90353, 90355, 90365}
# sections enrolled: 4
#
# student29(SLA1):
# id: 29
# base_score: 100
# section ranking: [90630, 90654, 90276, 90617, 90680]
# schedule: {90630, 90654}
# sections enrolled: 2
#
# student30(MRC3):
# id: 30
# base_score: 300
# section ranking: [90491, 90016, 90020, 90543, 90312]
# schedule: {90016, 90020, 90312, 90543}
# sections enrolled: 4
#
# student31(MRC4):
# id: 31
# base_score: 400
# section ranking: [90129, 90630, 90112, 90491, 90034]
# schedule: {90112, 90129, 90491, 90630}
# sections enrolled: 4
#
# student32(PHY5):
# id: 32
# base_score: 500
# section ranking: [90329, 90330, 90336, 90333, 90276]
# schedule: {90336, 90329, 90330, 90333}
# sections enrolled: 4
#
# student33(MUS1):
# id: 33
# base_score: 100
# section ranking: [90075, 90639, 90467, 90713, 90680]
# schedule: {90467}
# sections enrolled: 1
#
# student34(CLA3):
# id: 34
# base_score: 300
# section ranking: [90106, 90214, 90639, 90608, 90135]
# schedule: {90106, 90135, 90214, 90639}
# sections enrolled: 4
#
# student35(PHE1):
# id: 35
# base_score: 100
# section ranking: [90513, 90364, 90119, 90365, 90088]
# schedule: {90513, 90364, 90365}
# sections enrolled: 3
#
# student36(EDU5):
# id: 36
# base_score: 500
# section ranking: [90244, 90243, 90582, 90242, 90631]
# schedule: {90242, 90243, 90244, 90582}
# sections enrolled: 4
#
# student37(AST2):
# id: 37
# base_score: 200
# section ranking: [90683, 90181, 90574, 90582, 90287]
# schedule: {90582, 90683, 90181, 90574}
# sections enrolled: 4
#
# student38(BIO2):
# id: 38
# base_score: 200
# section ranking: [90141, 90572, 90673, 90306, 90558]
# schedule: {90306, 90572, 90141}
# sections enrolled: 3
#
# student39(RUS4):
# id: 39
# base_score: 400
# section ranking: [90280, 90587, 90279, 90811, 90820]
# schedule: {90280, 90811, 90820}
# sections enrolled: 3
#
# student40(ASL5):
# id: 40
# base_score: 500
# section ranking: [90778, 90533, 90597, 90055, 90600]
# schedule: {90597, 90778, 90533, 90055}
# sections enrolled: 4
#
# student41(LIN3):
# id: 41
# base_score: 300
# section ranking: [90516, 90754, 90684, 90277, 90539]
# schedule: {90539, 90516, 90277}
# sections enrolled: 3
#
# student42(NEU1):
# id: 42
# base_score: 100
# section ranking: [90704, 90287, 90308, 90011, 90302]
# schedule: {90308}
# sections enrolled: 1
#
# student43(PHE3):
# id: 43
# base_score: 300
# section ranking: [90465, 90676, 90701, 90349, 90267]
# schedule: {90465, 90267, 90676}
# sections enrolled: 3
#
# student44(GWS3):
# id: 44
# base_score: 300
# section ranking: [90343, 90655, 90108, 90584, 90594]
# schedule: {90584, 90594, 90655, 90343}
# sections enrolled: 4
#
# student45(NEU1):
# id: 45
# base_score: 100
# section ranking: [90308, 90669, 90562, 90798, 90500]
# schedule: {90500, 90562, 90308, 90669}
# sections enrolled: 4
#
# student46(DAT1):
# id: 46
# base_score: 100
# section ranking: [90218, 90097, 90107, 90179, 90626]
# schedule: {90179}
# sections enrolled: 1
#
# student47(BOT4):
# id: 47
# base_score: 400
# section ranking: [90142, 90105, 90147, 90097, 90269]
# schedule: {90147, 90142}
# sections enrolled: 2
#
# student49(MAT4):
# id: 49
# base_score: 400
# section ranking: [90792, 90855, 90501, 90509, 90515]
# schedule: {90792, 90501, 90509, 90855}
# sections enrolled: 4
#
# student50(ENG4):
# id: 50
# base_score: 400
# section ranking: [90666, 90657, 90652, 90670, 90321]
# schedule: {90657, 90666, 90652, 90670}
# sections enrolled: 4
#
# student51(GC3):
# id: 51
# base_score: 300
# section ranking: [90488, 90544, 90267, 90084, 90584]
# schedule: {90544, 90267, 90084, 90584}
# sections enrolled: 4
#
# student52(LAT5):
# id: 52
# base_score: 500
# section ranking: [90288, 90127, 90518, 90517, 90798]
# schedule: {90288, 90798, 90517, 90518}
# sections enrolled: 4
#
# student53(FLM4):
# id: 53
# base_score: 400
# section ranking: [90316, 90295, 90194, 90251, 90296]
# schedule: {90194, 90251, 90316, 90295}
# sections enrolled: 4
#
# student54(AFR2):
# id: 54
# base_score: 200
# section ranking: [90698, 90297, 90700, 90187, 90523]
# schedule: {90297, 90698, 90187}
# sections enrolled: 3
#
# student55(CRT1):
# id: 55
# base_score: 100
# section ranking: [90168, 90810, 90323, 90098, 90033]
# schedule: {90810}
# sections enrolled: 1
#
# student56(GIS3):
# id: 56
# base_score: 300
# section ranking: [90269, 90113, 90770, 90620, 90596]
# schedule: {90113, 90770, 90596}
# sections enrolled: 3
#
# student57(ECO3):
# id: 57
# base_score: 300
# section ranking: [90233, 90688, 90693, 90228, 90797]
# schedule: {90688, 90233, 90228, 90693}
# sections enrolled: 4
#
# student58(FRH1):
# id: 58
# base_score: 100
# section ranking: [90814, 90245, 90474, 90472, 90088]
# schedule: {90472, 90814}
# sections enrolled: 2
#
# student59(ARC2):
# id: 59
# base_score: 200
# section ranking: [90610, 90109, 90037, 90016, 90587]
# schedule: {90016, 90610}
# sections enrolled: 2
#
# student60(IS2):
# id: 60
# base_score: 200
# section ranking: [90571, 90168, 90573, 90274, 90189]
# schedule: {90274, 90189, 90573}
# sections enrolled: 3
#
# student61(HIS5):
# id: 61
# base_score: 500
# section ranking: [90626, 90608, 90713, 90036, 90139]
# schedule: {90608, 90713, 90626, 90139}
# sections enrolled: 4
#
# student62(RUS3):
# id: 62
# base_score: 300
# section ranking: [90186, 90713, 90002, 90278, 90564]
# schedule: {90713, 90186, 90564, 90002}
# sections enrolled: 4
#
# student63(GC2):
# id: 63
# base_score: 200
# section ranking: [90509, 90488, 90322, 90538, 90736]
# schedule: {90538, 90322, 90736, 90509}
# sections enrolled: 4
#
# student64(LAT3):
# id: 64
# base_score: 300
# section ranking: [90251, 90266, 90683, 90517, 90518]
# schedule: {90683, 90266, 90251}
# sections enrolled: 3
#
# student65(SOC2):
# id: 65
# base_score: 200
# section ranking: [90232, 90265, 90387, 90631, 90039]
# schedule: {90232, 90039, 90387, 90631}
# sections enrolled: 4
#
# student66(ART2):
# id: 66
# base_score: 200
# section ranking: [90045, 90582, 90537, 90039, 90556]
# schedule: {90556, 90045, 90582, 90039}
# sections enrolled: 4
#
# student67(MRC2):
# id: 67
# base_score: 200
# section ranking: [90545, 90491, 90018, 90681, 90549]
# schedule: {90681, 90018, 90549}
# sections enrolled: 3
#
# student68(GER1):
# id: 68
# base_score: 100
# section ranking: [90258, 90671, 90471, 90502, 90179]
# schedule: {90258, 90179, 90471}
# sections enrolled: 3
#
# student69(AT3):
# id: 69
# base_score: 300
# section ranking: [90294, 90451, 90734, 90334, 90094]
# schedule: {90451, 90734}
# sections enrolled: 2
#
# student70(PHY2):
# id: 70
# base_score: 200
# section ranking: [90333, 90837, 90336, 90332, 90328]
# schedule: {90328, 90837}
# sections enrolled: 2
#
# student71(EAS1):
# id: 71
# base_score: 100
# section ranking: [90633, 90199, 90219, 90220, 90516]
# schedule: {90219, 90199}
# sections enrolled: 2
#
# student72(IS5):
# id: 72
# base_score: 500
# section ranking: [90184, 90571, 90573, 90346, 90052]
# schedule: {90184, 90346, 90571, 90573}
# sections enrolled: 4
#
# student73(FYS2):
# id: 73
# base_score: 200
# section ranking: [90274, 90772, 90766, 90642, 90229]
# schedule: {90274, 90772, 90229}
# sections enrolled: 3
#
# student74(AHI3):
# id: 74
# base_score: 300
# section ranking: [90488, 90823, 90634, 90017, 90522]
# schedule: {90017, 90634, 90522, 90823}
# sections enrolled: 4
#
# student75(MRC2):
# id: 75
# base_score: 200
# section ranking: [90491, 90290, 90646, 90218, 90294]
# schedule: {90290}
# sections enrolled: 1
#
# student76(FYS5):
# id: 76
# base_score: 500
# section ranking: [90767, 90005, 90739, 90676, 90770]
# schedule: {90739, 90676, 90005, 90767}
# sections enrolled: 4
#
# student77(HMD1):
# id: 77
# base_score: 100
# section ranking: [90590, 90114, 90596, 90574, 90031]
# schedule: {90114, 90574, 90590, 90031}
# sections enrolled: 4
#
# student78(GOV3):
# id: 78
# base_score: 300
# section ranking: [90520, 90842, 90521, 90529, 90596]
# schedule: {90520, 90521, 90529}
# sections enrolled: 3
#
# student79(CRE3):
# id: 79
# base_score: 300
# section ranking: [90275, 90615, 90586, 90623, 90299]
# schedule: {90623, 90586, 90275, 90615}
# sections enrolled: 4
#
# student80(GIS2):
# id: 80
# base_score: 200
# section ranking: [90652, 90620, 90051, 90698, 90535]
# schedule: {90698, 90652}
# sections enrolled: 2
#
# student81(FYS5):
# id: 81
# base_score: 500
# section ranking: [90319, 90796, 90669, 90484, 90771]
# schedule: {90484, 90796, 90669, 90319}
# sections enrolled: 4
#
# student82(CHI5):
# id: 82
# base_score: 500
# section ranking: [90673, 90818, 90108, 90107, 90109]
# schedule: {90673, 90818, 90107, 90108}
# sections enrolled: 4
#
# student83(ANT1):
# id: 83
# base_score: 100
# section ranking: [90288, 90191, 90030, 90028, 90033]
# schedule: {90030, 90191}
# sections enrolled: 2
#
# student84(AST3):
# id: 84
# base_score: 300
# section ranking: [90031, 90058, 90057, 90488, 90346]
# schedule: {90058, 90346, 90031}
# sections enrolled: 3
#
# student85(ENG2):
# id: 85
# base_score: 200
# section ranking: [90121, 90650, 90355, 90837, 90651]
# schedule: {90121, 90650, 90355, 90837}
# sections enrolled: 4
#
# student86(FDP4):
# id: 86
# base_score: 400
# section ranking: [90294, 90367, 90269, 90295, 90101]
# schedule: {90295, 90269, 90367}
# sections enrolled: 3
#
# student87(GER1):
# id: 87
# base_score: 100
# section ranking: [90503, 90494, 90238, 90075, 90233]
# schedule: {90233, 90238}
# sections enrolled: 2
#
# student88(GWS5):
# id: 88
# base_score: 500
# section ranking: [90309, 90633, 90600, 90654, 90312]
# schedule: {90600, 90633, 90309, 90654}
# sections enrolled: 4
#
# student89(FRH1):
# id: 89
# base_score: 100
# section ranking: [90627, 90472, 90478, 90571, 90578]
# schedule: {90472, 90578, 90627}
# sections enrolled: 3
#
# student90(ART1):
# id: 90
# base_score: 100
# section ranking: [90073, 90052, 90551, 90560, 90040]
# schedule: {90560, 90073}
# sections enrolled: 2
#
# student91(ENT2):
# id: 91
# base_score: 200
# section ranking: [90487, 90247, 90694, 90248, 90319]
# schedule: {90694, 90487}
# sections enrolled: 2
#
# student92(ART1):
# id: 92
# base_score: 100
# section ranking: [90531, 90045, 90054, 90040, 90582]
# schedule: {90040, 90531, 90582, 90054}
# sections enrolled: 4
#
# student93(ART3):
# id: 93
# base_score: 300
# section ranking: [90052, 90039, 90372, 90633, 90041]
# schedule: {90041, 90052, 90372, 90039}
# sections enrolled: 4
#
# student94(EAS3):
# id: 94
# base_score: 300
# section ranking: [90219, 90633, 90220, 90547, 90567]
# schedule: {90633, 90219, 90220}
# sections enrolled: 3
#
# student95(STA3):
# id: 95
# base_score: 300
# section ranking: [90196, 90270, 90192, 90195, 90194]
# schedule: {90192, 90194, 90196, 90270}
# sections enrolled: 4
#
# student96(GEO3):
# id: 96
# base_score: 300
# section ranking: [90029, 90851, 90252, 90289, 90260]
# schedule: {90289, 90851, 90252, 90029}
# sections enrolled: 4
#
# student97(THE3):
# id: 97
# base_score: 300
# section ranking: [90751, 90123, 90637, 90173, 90180]
# schedule: {90123, 90173, 90751}
# sections enrolled: 3
#
# student98(SJS1):
# id: 98
# base_score: 100
# section ranking: [90098, 90376, 90531, 90549, 90277]
# schedule: {90531}
# sections enrolled: 1
#
# student99(HBR3):
# id: 99
# base_score: 300
# section ranking: [90600, 90451, 90259, 90030, 90109]
# schedule: {90451, 90030}
# sections enrolled: 2
#
# student100(AFR1):
# id: 100
# base_score: 100
# section ranking: [90187, 90363, 90624, 90824, 90614]
# schedule: {90624, 90187, 90824, 90363}
# sections enrolled: 4
#
# student101(JPN2):
# id: 101
# base_score: 200
# section ranking: [90554, 90552, 90471, 90501, 90555]
# schedule: {90471}
# sections enrolled: 1
#
# student102(DAN2):
# id: 102
# base_score: 200
# section ranking: [90198, 90471, 90657, 90170, 90674]
# schedule: {90657, 90170, 90198, 90471}
# sections enrolled: 4
#
# student103(ES1):
# id: 103
# base_score: 100
# section ranking: [90475, 90517, 90292, 90127, 90026]
# schedule: {90026}
# sections enrolled: 1
#
# student104(CRT5):
# id: 104
# base_score: 500
# section ranking: [90191, 90168, 90358, 90812, 90522]
# schedule: {90168, 90812, 90358, 90191}
# sections enrolled: 4
#
# student105(JS2):
# id: 105
# base_score: 200
# section ranking: [90551, 90345, 90530, 90642, 90329]
# schedule: {90530}
# sections enrolled: 1
#
# student106(BIO2):
# id: 106
# base_score: 200
# section ranking: [90676, 90462, 90141, 90582, 90086]
# schedule: {90086, 90676, 90582, 90462}
# sections enrolled: 4
#
# student107(SOC5):
# id: 107
# base_score: 500
# section ranking: [90348, 90371, 90272, 90046, 90270]
# schedule: {90272, 90371, 90348, 90046}
# sections enrolled: 4
#
# student108(AFR5):
# id: 108
# base_score: 500
# section ranking: [90825, 90563, 90836, 90097, 90306]
# schedule: {90825, 90563, 90836, 90097}
# sections enrolled: 4
#
# student109(FLM5):
# id: 109
# base_score: 500
# section ranking: [90295, 90696, 90296, 90017, 90558]
# schedule: {90296, 90017, 90558, 90295}
# sections enrolled: 4
#
# student110(LIN1):
# id: 110
# base_score: 100
# section ranking: [90836, 90090, 90516, 90684, 90789]
# schedule: {90090, 90836}
# sections enrolled: 2
#
# student111(ANT3):
# id: 111
# base_score: 300
# section ranking: [90095, 90462, 90024, 90235, 90027]
# schedule: {90024, 90235, 90462, 90095}
# sections enrolled: 4
#
# student112(THE2):
# id: 112
# base_score: 200
# section ranking: [90175, 90034, 90651, 90173, 90474]
# schedule: {90651, 90175}
# sections enrolled: 2
#
# student113(ACC1):
# id: 113
# base_score: 100
# section ranking: [90003, 90002, 90674, 90299, 90333]
# schedule: {90002, 90003, 90674, 90299}
# sections enrolled: 4
#
# student114(ARA2):
# id: 114
# base_score: 200
# section ranking: [90294, 90033, 90551, 90032, 90079]
# schedule: {90079}
# sections enrolled: 1
#
# student115(IS4):
# id: 115
# base_score: 400
# section ranking: [90571, 90032, 90573, 90556, 90228]
# schedule: {90228, 90571, 90556, 90573}
# sections enrolled: 4
#
# student116(GRK2):
# id: 116
# base_score: 200
# section ranking: [90623, 90662, 90100, 90164, 90551]
# schedule: {90100, 90164, 90662, 90623}
# sections enrolled: 4
#
# student117(EAS4):
# id: 117
# base_score: 400
# section ranking: [90529, 90513, 90185, 90219, 90033]
# schedule: {90529, 90513, 90219, 90033}
# sections enrolled: 4
#
# student118(PAX2):
# id: 118
# base_score: 200
# section ranking: [90173, 90374, 90288, 90228, 90630]
# schedule: {90288, 90228, 90374}
# sections enrolled: 3
#
# student119(MAT1):
# id: 119
# base_score: 100
# section ranking: [90093, 90770, 90510, 90546, 90557]
# schedule: {90546, 90093, 90510}
# sections enrolled: 3
#
# student120(JPN1):
# id: 120
# base_score: 100
# section ranking: [90244, 90552, 90555, 90554, 90553]
# schedule: {90244}
# sections enrolled: 1
#
# student121(PBH2):
# id: 121
# base_score: 200
# section ranking: [90324, 90376, 90375, 90235, 90507]
# schedule: {90235, 90324}
# sections enrolled: 2
#
# student122(BIO3):
# id: 122
# base_score: 300
# section ranking: [90676, 90306, 90081, 90083, 90322]
# schedule: {90306, 90676}
# sections enrolled: 2
#
# student123(HMD4):
# id: 123
# base_score: 400
# section ranking: [90081, 90581, 90475, 90579, 90583]
# schedule: {90081, 90475}
# sections enrolled: 2
#
# student124(SOC1):
# id: 124
# base_score: 100
# section ranking: [90776, 90265, 90591, 90261, 90003]
# schedule: {90261, 90591}
# sections enrolled: 2
#
# student126(MUS3):
# id: 126
# base_score: 300
# section ranking: [90463, 90253, 90203, 90591, 90469]
# schedule: {90591, 90203, 90469, 90463}
# sections enrolled: 4
#
# student127(AFR2):
# id: 127
# base_score: 200
# section ranking: [90535, 90040, 90637, 90653, 90718]
# schedule: {90040, 90653, 90718}
# sections enrolled: 3
#
# student128(CRE1):
# id: 128
# base_score: 100
# section ranking: [90126, 90204, 90203, 90275, 90510]
# schedule: {90275, 90204}
# sections enrolled: 2
#
# student129(PHE1):
# id: 129
# base_score: 100
# section ranking: [90071, 90355, 90372, 90367, 90364]
# schedule: {90355, 90372, 90364}
# sections enrolled: 3
#
# student130(AHI2):
# id: 130
# base_score: 200
# section ranking: [90634, 90694, 90004, 90524, 90009]
# schedule: {90009, 90634, 90004, 90694}
# sections enrolled: 4
#
# student131(FRH3):
# id: 131
# base_score: 300
# section ranking: [90476, 90477, 90475, 90144, 90570]
# schedule: {90144, 90570, 90476, 90477}
# sections enrolled: 4
#
# student132(ARA5):
# id: 132
# base_score: 500
# section ranking: [90817, 90032, 90186, 90033, 90536]
# schedule: {90032, 90817, 90186, 90033}
# sections enrolled: 4
#
# student133(DAT4):
# id: 133
# base_score: 400
# section ranking: [90659, 90165, 90170, 90083, 90270]
# schedule: {90170, 90659, 90165, 90270}
# sections enrolled: 4
#
# student134(LIN3):
# id: 134
# base_score: 300
# section ranking: [90516, 90684, 90097, 90799, 90485]
# schedule: {90516, 90485, 90684, 90799}
# sections enrolled: 4
#
# student135(FYS4):
# id: 135
# base_score: 400
# section ranking: [90646, 90669, 90799, 90485, 90587]
# schedule: {90587, 90485, 90646}
# sections enrolled: 3
#
# student136(LAT2):
# id: 136
# base_score: 200
# section ranking: [90583, 90686, 90175, 90518, 90799]
# schedule: {90175, 90686, 90583}
# sections enrolled: 3
#
# student137(NEU5):
# id: 137
# base_score: 500
# section ranking: [90488, 90302, 90287, 90695, 90289]
# schedule: {90488, 90695, 90302, 90287}
# sections enrolled: 4
#
# student138(ENT2):
# id: 138
# base_score: 200
# section ranking: [90248, 90535, 90223, 90308, 90114]
# schedule: {90114, 90223}
# sections enrolled: 2
#
# student139(ENG5):
# id: 139
# base_score: 500
# section ranking: [90540, 90666, 90309, 90658, 90663]
# schedule: {90666, 90658, 90540, 90309}
# sections enrolled: 4
#
# student140(HIS3):
# id: 140
# base_score: 300
# section ranking: [90310, 90618, 90220, 90641, 90607]
# schedule: {90641, 90618, 90310, 90607}
# sections enrolled: 4
#
# student141(ARA2):
# id: 141
# base_score: 200
# section ranking: [90032, 90088, 90033, 90364, 90344]
# schedule: {90364}
# sections enrolled: 1
#
# student142(ITL3):
# id: 142
# base_score: 300
# section ranking: [90569, 90016, 90588, 90106, 90301]
# schedule: {90016, 90569, 90106}
# sections enrolled: 3
#
# student143(LA4):
# id: 143
# base_score: 400
# section ranking: [90537, 90820, 90541, 90523, 90152]
# schedule: {90537, 90523, 90820, 90541}
# sections enrolled: 4
#
# student144(ART3):
# id: 144
# base_score: 300
# section ranking: [90226, 90044, 90051, 90816, 90038]
# schedule: {90226, 90051, 90044}
# sections enrolled: 3
#
# student145(AMS4):
# id: 145
# base_score: 400
# section ranking: [90837, 90196, 90654, 90151, 90054]
# schedule: {90196, 90837, 90054, 90151}
# sections enrolled: 4
#
# student146(PSY2):
# id: 146
# base_score: 200
# section ranking: [90641, 90813, 90326, 90298, 90320]
# schedule: {90320, 90641, 90813, 90326}
# sections enrolled: 4
#
# student147(HMD1):
# id: 147
# base_score: 100
# section ranking: [90265, 90511, 90578, 90587, 90599]
# schedule: {90578, 90599, 90511}
# sections enrolled: 3
#
# student148(AT4):
# id: 148
# base_score: 400
# section ranking: [90048, 90249, 90012, 90548, 90656]
# schedule: {90048, 90249, 90548}
# sections enrolled: 3
#
# student149(CRT4):
# id: 149
# base_score: 400
# section ranking: [90531, 90595, 90116, 90653, 90517]
# schedule: {90531, 90116, 90653, 90595}
# sections enrolled: 4
#
# student150(EDU1):
# id: 150
# base_score: 100
# section ranking: [90245, 90645, 90246, 90243, 90052]
# schedule: {90645, 90243, 90245, 90246}
# sections enrolled: 4
#
# student151(PBH5):
# id: 151
# base_score: 500
# section ranking: [90793, 90592, 90513, 90104, 90375]
# schedule: {90592, 90793, 90513, 90375}
# sections enrolled: 4
#
# student152(BIO3):
# id: 152
# base_score: 300
# section ranking: [90547, 90078, 90131, 90071, 90083]
# schedule: {90131, 90083, 90547, 90071}
# sections enrolled: 4
#
# student153(ARA2):
# id: 153
# base_score: 200
# section ranking: [90033, 90032, 90053, 90669, 90117]
# schedule: {90669, 90053}
# sections enrolled: 2
#
# student154(ASL4):
# id: 154
# base_score: 400
# section ranking: [90778, 90218, 90055, 90149, 90389]
# schedule: {90778, 90149, 90218, 90055}
# sections enrolled: 4
#
# student155(FRH4):
# id: 155
# base_score: 400
# section ranking: [90582, 90057, 90474, 90477, 90471]
# schedule: {90057, 90474, 90477, 90582}
# sections enrolled: 4
#
# student156(MRC5):
# id: 156
# base_score: 500
# section ranking: [90570, 90491, 90681, 90058, 90582]
# schedule: {90681, 90570, 90491, 90582}
# sections enrolled: 4
#
# student157(SJS3):
# id: 157
# base_score: 300
# section ranking: [90277, 90052, 90837, 90545, 90332]
# schedule: {90837, 90545, 90277}
# sections enrolled: 3
#
# student158(MSM5):
# id: 158
# base_score: 500
# section ranking: [90014, 90296, 90659, 90034, 90011]
# schedule: {90296, 90034, 90659, 90014}
# sections enrolled: 4
#
# student159(COM4):
# id: 159
# base_score: 400
# section ranking: [90568, 90143, 90147, 90164, 90754]
# schedule: {90568, 90754, 90164, 90143}
# sections enrolled: 4
#
# student160(RUS2):
# id: 160
# base_score: 200
# section ranking: [90651, 90541, 90836, 90813, 90278]
# schedule: {90651, 90813}
# sections enrolled: 2
#
# student161(BIO4):
# id: 161
# base_score: 400
# section ranking: [90480, 90545, 90074, 90092, 90765]
# schedule: {90480, 90545, 90074, 90092}
# sections enrolled: 4
#
# student163(GRK5):
# id: 163
# base_score: 500
# section ranking: [90682, 90580, 90577, 90451, 90767]
# schedule: {90682, 90451, 90580, 90767}
# sections enrolled: 4
#
# student164(ENT2):
# id: 164
# base_score: 200
# section ranking: [90248, 90247, 90160, 90266, 90298]
# schedule: {90298, 90266}
# sections enrolled: 2
#
# student165(ENT1):
# id: 165
# base_score: 100
# section ranking: [90247, 90248, 90157, 90695, 90754]
# schedule: {90157}
# sections enrolled: 1
#
# student166(FDP5):
# id: 166
# base_score: 500
# section ranking: [90294, 90280, 90044, 90491, 90078]
# schedule: {90280, 90491, 90044, 90294}
# sections enrolled: 4
#
# student167(MUS1):
# id: 167
# base_score: 100
# section ranking: [90842, 90468, 90467, 90449, 90088]
# schedule: {90467, 90468}
# sections enrolled: 2
#
# student168(FYS4):
# id: 168
# base_score: 400
# section ranking: [90626, 90768, 90195, 90565, 90285]
# schedule: {90768, 90626, 90195, 90565}
# sections enrolled: 4
#
# student169(EAS2):
# id: 169
# base_score: 200
# section ranking: [90220, 90219, 90633, 90094, 90071]
# schedule: {90219}
# sections enrolled: 1
#
# student170(MSM5):
# id: 170
# base_score: 500
# section ranking: [90637, 90014, 90532, 90082, 90477]
# schedule: {90082, 90532, 90637, 90014}
# sections enrolled: 4
#
# student171(IS5):
# id: 171
# base_score: 500
# section ranking: [90262, 90573, 90799, 90571, 90822]
# schedule: {90571, 90573, 90262, 90799}
# sections enrolled: 4
#
# student172(NEU4):
# id: 172
# base_score: 400
# section ranking: [90824, 90790, 90116, 90302, 90500]
# schedule: {90824, 90500, 90302, 90790}
# sections enrolled: 4
#
# student173(STA5):
# id: 173
# base_score: 500
# section ranking: [90476, 90736, 90195, 90194, 90196]
# schedule: {90736, 90194, 90195, 90476}
# sections enrolled: 4
#
# student174(GWS5):
# id: 174
# base_score: 500
# section ranking: [90574, 90597, 90451, 90268, 90582]
# schedule: {90582, 90451, 90597, 90574}
# sections enrolled: 4
#
# student175(ASL2):
# id: 175
# base_score: 200
# section ranking: [90611, 90055, 90778, 90078, 90553]
# schedule: {90611}
# sections enrolled: 1
#
# student176(ANT1):
# id: 176
# base_score: 100
# section ranking: [90217, 90258, 90030, 90316, 90019]
# schedule: {90217, 90258, 90019}
# sections enrolled: 3
#
# student177(FRH5):
# id: 177
# base_score: 500
# section ranking: [90278, 90164, 90676, 90477, 90626]
# schedule: {90164, 90278}
# sections enrolled: 2
#
# student178(AT3):
# id: 178
# base_score: 300
# section ranking: [90048, 90734, 90582, 90817, 90581]
# schedule: {90048, 90582, 90734}
# sections enrolled: 3
#
# student179(GIS5):
# id: 179
# base_score: 500
# section ranking: [90269, 90620, 90240, 90125, 90669]
# schedule: {90240, 90125, 90620, 90269}
# sections enrolled: 4
#
# student180(JPN1):
# id: 180
# base_score: 100
# section ranking: [90555, 90553, 90107, 90022, 90034]
# schedule: {90022}
# sections enrolled: 1
#
# student181(HMD2):
# id: 181
# base_score: 200
# section ranking: [90583, 90581, 90768, 90574, 90576]
# schedule: {90576, 90574, 90583}
# sections enrolled: 3
#
# student182(HBR3):
# id: 182
# base_score: 300
# section ranking: [90290, 90600, 90367, 90688, 90132]
# schedule: {90688, 90290, 90132, 90367}
# sections enrolled: 4
#
# student183(HMD2):
# id: 183
# base_score: 200
# section ranking: [90087, 90367, 90004, 90576, 90574]
# schedule: {90576, 90367, 90087}
# sections enrolled: 3
#
# student184(MAT2):
# id: 184
# base_score: 200
# section ranking: [90522, 90497, 90618, 90322, 90500]
# schedule: {90497, 90522, 90618, 90500}
# sections enrolled: 4
#
# student185(MUS2):
# id: 185
# base_score: 200
# section ranking: [90463, 90624, 90664, 90249, 90661]
# schedule: {90624, 90249, 90463}
# sections enrolled: 3
#
# student186(EAS3):
# id: 186
# base_score: 300
# section ranking: [90220, 90756, 90058, 90633, 90218]
# schedule: {90756, 90218, 90220, 90633}
# sections enrolled: 4
#
# student187(LIN1):
# id: 187
# base_score: 100
# section ranking: [90300, 90648, 90509, 90684, 90018]
# schedule: {90648, 90018, 90509}
# sections enrolled: 3
#
# student188(SLA2):
# id: 188
# base_score: 200
# section ranking: [90680, 90855, 90617, 90566, 90276]
# schedule: {90617, 90276, 90855}
# sections enrolled: 3
#
# student189(IS2):
# id: 189
# base_score: 200
# section ranking: [90467, 90571, 90621, 90573, 90168]
# schedule: {90573, 90467, 90621}
# sections enrolled: 3
#
# student190(GIS3):
# id: 190
# base_score: 300
# section ranking: [90332, 90620, 90820, 90800, 90533]
# schedule: {90800, 90820, 90332}
# sections enrolled: 3
#
# student191(ARA4):
# id: 191
# base_score: 400
# section ranking: [90108, 90033, 90032, 90821, 90185]
# schedule: {90185, 90108, 90821}
# sections enrolled: 3
#
# student192(ES4):
# id: 192
# base_score: 400
# section ranking: [90592, 90170, 90100, 90622, 90341]
# schedule: {90592, 90170, 90100, 90622}
# sections enrolled: 4
#
# student193(MSM5):
# id: 193
# base_score: 500
# section ranking: [90014, 90170, 90321, 90054, 90811]
# schedule: {90321, 90170, 90054, 90014}
# sections enrolled: 4
#
# student194(GC3):
# id: 194
# base_score: 300
# section ranking: [90488, 90020, 90034, 90570, 90019]
# schedule: {90570, 90019, 90020}
# sections enrolled: 3
#
# student195(PKP3):
# id: 195
# base_score: 300
# section ranking: [90754, 90327, 90248, 90266, 90215]
# schedule: {90248, 90754, 90215, 90327}
# sections enrolled: 4
#
# student196(ARC5):
# id: 196
# base_score: 500
# section ranking: [90822, 90046, 90300, 90126, 90181]
# schedule: {90300, 90046, 90822, 90126}
# sections enrolled: 4
#
# student197(GWS4):
# id: 197
# base_score: 400
# section ranking: [90220, 90290, 90582, 90655, 90584]
# schedule: {90290, 90220, 90582, 90655}
# sections enrolled: 4
#
# student198(THE4):
# id: 198
# base_score: 400
# section ranking: [90532, 90608, 90792, 90150, 90810]
# schedule: {90608, 90810, 90532, 90792}
# sections enrolled: 4
#
# student199(EDU5):
# id: 199
# base_score: 500
# section ranking: [90244, 90365, 90825, 90681, 90246]
# schedule: {90825, 90244, 90681}
# sections enrolled: 3
#
# student200(ARA2):
# id: 200
# base_score: 200
# section ranking: [90011, 90103, 90739, 90658, 90032]
# schedule: {90739, 90011, 90103}
# sections enrolled: 3
#
# student201(GRK3):
# id: 201
# base_score: 300
# section ranking: [90575, 90682, 90577, 90580, 90608]
# schedule: {90608, 90577, 90682}
# sections enrolled: 3
#
# student202(DAN4):
# id: 202
# base_score: 400
# section ranking: [90699, 90183, 90697, 90146, 90469]
# schedule: {90146, 90699, 90469}
# sections enrolled: 3
#
# student203(ECO5):
# id: 203
# base_score: 500
# section ranking: [90241, 90223, 90597, 90240, 90561]
# schedule: {90241, 90561, 90597}
# sections enrolled: 3
#
# student204(PHI5):
# id: 204
# base_score: 500
# section ranking: [90192, 90230, 90817, 90365, 90630]
# schedule: {90192, 90230, 90630}
# sections enrolled: 3
#
# student205(STA1):
# id: 205
# base_score: 100
# section ranking: [90193, 90195, 90194, 90776, 90192]
# schedule: {90776}
# sections enrolled: 1
#
# student206(GER5):
# id: 206
# base_score: 500
# section ranking: [90503, 90295, 90502, 90566, 90621]
# schedule: {90621, 90503}
# sections enrolled: 2
#
# student207(SPA2):
# id: 207
# base_score: 200
# section ranking: [90802, 90851, 90801, 90294, 90215]
# schedule: {90801, 90802, 90851, 90215}
# sections enrolled: 4
#
# student208(MAT3):
# id: 208
# base_score: 300
# section ranking: [90513, 90510, 90511, 90512, 90751]
# schedule: {90513, 90510, 90511}
# sections enrolled: 3
#
# student209(MAT5):
# id: 209
# base_score: 500
# section ranking: [90244, 90520, 90019, 90341, 90224]
# schedule: {90520, 90244, 90341}
# sections enrolled: 3
#
# student210(AST4):
# id: 210
# base_score: 400
# section ranking: [90478, 90060, 90057, 90058, 90136]
# schedule: {90057, 90058, 90060, 90478}
# sections enrolled: 4
#
# student211(EDU1):
# id: 211
# base_score: 100
# section ranking: [90245, 90582, 90246, 90253, 90673]
# schedule: {90246, 90245, 90582}
# sections enrolled: 3
#
# student212(GWS4):
# id: 212
# base_score: 400
# section ranking: [90299, 90236, 90679, 90285, 90326]
# schedule: {90299, 90236, 90326}
# sections enrolled: 3
#
# student213(FLM1):
# id: 213
# base_score: 100
# section ranking: [90296, 90311, 90128, 90137, 90050]
# schedule: {90311}
# sections enrolled: 1
#
# student214(ARC5):
# id: 214
# base_score: 500
# section ranking: [90034, 90639, 90620, 90598, 90023]
# schedule: {90023, 90034, 90620, 90639}
# sections enrolled: 4
#
# student215(CHI1):
# id: 215
# base_score: 100
# section ranking: [90804, 90109, 90537, 90673, 90108]
# schedule: {90804}
# sections enrolled: 1
#
# student216(HMD1):
# id: 216
# base_score: 100
# section ranking: [90571, 90587, 90576, 90596, 90578]
# schedule: {90576, 90578}
# sections enrolled: 2
#
# student217(ACC3):
# id: 217
# base_score: 300
# section ranking: [90634, 90003, 90307, 90002, 90734]
# schedule: {90634, 90003, 90002}
# sections enrolled: 3
#
# student218(AST3):
# id: 218
# base_score: 300
# section ranking: [90057, 90058, 90520, 90824, 90564]
# schedule: {90520, 90058, 90564, 90824}
# sections enrolled: 4
#
# student219(CHI2):
# id: 219
# base_score: 200
# section ranking: [90109, 90674, 90052, 90107, 90108]
# schedule: {90674}
# sections enrolled: 1
#
# student220(GRK1):
# id: 220
# base_score: 100
# section ranking: [90818, 90736, 90278, 90237, 90682]
# schedule: {90736, 90818}
# sections enrolled: 2
#
# student221(MRC4):
# id: 221
# base_score: 400
# section ranking: [90491, 90250, 90797, 90127, 90355]
# schedule: {90250, 90491, 90355, 90127}
# sections enrolled: 4
#
# student222(HIS2):
# id: 222
# base_score: 200
# section ranking: [90619, 90219, 90136, 90472, 90621]
# schedule: {90219, 90619, 90621}
# sections enrolled: 3
#
# student223(LIN5):
# id: 223
# base_score: 500
# section ranking: [90796, 90684, 90516, 90261, 90586]
# schedule: {90586, 90796, 90261, 90684}
# sections enrolled: 4
#
# student224(ENG2):
# id: 224
# base_score: 200
# section ranking: [90647, 90666, 90663, 90097, 90344]
# schedule: {90344, 90666, 90663, 90647}
# sections enrolled: 4
#
# student225(HIS1):
# id: 225
# base_score: 100
# section ranking: [90641, 90686, 90544, 90675, 90616]
# schedule: {90544, 90641, 90675, 90686}
# sections enrolled: 4
#
# student226(LIN2):
# id: 226
# base_score: 200
# section ranking: [90684, 90516, 90734, 90797, 90534]
# schedule: {90797, 90534}
# sections enrolled: 2
#
# student227(AT4):
# id: 227
# base_score: 400
# section ranking: [90258, 90795, 90149, 90048, 90012]
# schedule: {90048, 90258, 90795}
# sections enrolled: 3
#
# student228(MRC3):
# id: 228
# base_score: 300
# section ranking: [90145, 90491, 90571, 90542, 90353]
# schedule: {90145, 90491, 90542, 90571}
# sections enrolled: 4
#
# student229(ENT3):
# id: 229
# base_score: 300
# section ranking: [90247, 90136, 90387, 90248, 90307]
# schedule: {90136, 90387, 90248, 90247}
# sections enrolled: 4
#
# student230(RUS3):
# id: 230
# base_score: 300
# section ranking: [90196, 90280, 90363, 90279, 90599]
# schedule: {90363, 90196, 90599}
# sections enrolled: 3
#
# student231(AST2):
# id: 231
# base_score: 200
# section ranking: [90057, 90056, 90058, 90533, 90570]
# schedule: {90056, 90570, 90533}
# sections enrolled: 3
#
# student232(JS5):
# id: 232
# base_score: 500
# section ranking: [90589, 90662, 90103, 90471, 90195]
# schedule: {90589, 90662, 90471}
# sections enrolled: 3
#
# student233(LIN4):
# id: 233
# base_score: 400
# section ranking: [90684, 90516, 90079, 90482, 90118]
# schedule: {90516, 90482, 90684, 90079}
# sections enrolled: 4
#
# student234(MSM5):
# id: 234
# base_score: 500
# section ranking: [90014, 90587, 90142, 90031, 90121]
# schedule: {90031, 90587, 90014, 90142}
# sections enrolled: 4
#
# student235(ARA4):
# id: 235
# base_score: 400
# section ranking: [90032, 90033, 90542, 90034, 90559]
# schedule: {90032, 90033, 90034, 90542}
# sections enrolled: 4
#
# student236(AST2):
# id: 236
# base_score: 200
# section ranking: [90631, 90057, 90328, 90656, 90219]
# schedule: {90656, 90631}
# sections enrolled: 2
#
# student237(GOV4):
# id: 237
# base_score: 400
# section ranking: [90365, 90557, 90531, 90528, 90570]
# schedule: {90531, 90365, 90557}
# sections enrolled: 3
#
# student238(PKP3):
# id: 238
# base_score: 300
# section ranking: [90531, 90041, 90327, 90776, 90834]
# schedule: {90041, 90834, 90531, 90327}
# sections enrolled: 4
#
# student239(GC4):
# id: 239
# base_score: 400
# section ranking: [90488, 90668, 90290, 90301, 90655]
# schedule: {90290, 90668, 90301, 90655}
# sections enrolled: 4
#
# student240(FLM5):
# id: 240
# base_score: 500
# section ranking: [90696, 90295, 90296, 90316, 90693]
# schedule: {90696, 90316, 90693, 90296}
# sections enrolled: 4
#
# student241(LAT5):
# id: 241
# base_score: 500
# section ranking: [90519, 90579, 90466, 90682, 90558]
# schedule: {90466, 90579, 90558, 90519}
# sections enrolled: 4
#
# student242(JPN2):
# id: 242
# base_score: 200
# section ranking: [90636, 90207, 90554, 90552, 90468]
# schedule: {90552, 90468, 90636, 90207}
# sections enrolled: 4
#
# student243(CRE1):
# id: 243
# base_score: 100
# section ranking: [90635, 90146, 90599, 90348, 90074]
# schedule: {90074, 90146, 90635}
# sections enrolled: 3
#
# student244(DAN1):
# id: 244
# base_score: 100
# section ranking: [90227, 90531, 90045, 90204, 90290]
# schedule: {90290, 90227, 90204, 90531}
# sections enrolled: 4
#
# student245(ARA3):
# id: 245
# base_score: 300
# section ranking: [90033, 90220, 90032, 90544, 90616]
# schedule: {90544, 90616, 90220}
# sections enrolled: 3
#
# student246(COM3):
# id: 246
# base_score: 300
# section ranking: [90317, 90815, 90825, 90334, 90639]
# schedule: {90825, 90317, 90334, 90815}
# sections enrolled: 4
#
# student247(LIN4):
# id: 247
# base_score: 400
# section ranking: [90516, 90684, 90508, 90371, 90810]
# schedule: {90508, 90371, 90516, 90684}
# sections enrolled: 4
#
# student248(EAS5):
# id: 248
# base_score: 500
# section ranking: [90336, 90633, 90219, 90220, 90082]
# schedule: {90336, 90633, 90219, 90220}
# sections enrolled: 4
#
# student249(LA3):
# id: 249
# base_score: 300
# section ranking: [90542, 90522, 90550, 90268, 90783]
# schedule: {90268, 90522, 90550, 90542}
# sections enrolled: 4
#
# student250(FRH5):
# id: 250
# base_score: 500
# section ranking: [90388, 90277, 90821, 90474, 90478]
# schedule: {90474, 90388, 90821, 90478}
# sections enrolled: 4
#
# student251(GIS5):
# id: 251
# base_score: 500
# section ranking: [90535, 90688, 90620, 90269, 90327]
# schedule: {90688, 90620, 90269, 90535}
# sections enrolled: 4
#
# student252(CHM3):
# id: 252
# base_score: 300
# section ranking: [90553, 90122, 90123, 90302, 90549]
# schedule: {90553, 90122, 90123, 90549}
# sections enrolled: 4
#
# student253(RUS3):
# id: 253
# base_score: 300
# section ranking: [90279, 90278, 90280, 90652, 90353]
# schedule: {90353, 90279}
# sections enrolled: 2
#
# student254(PKP1):
# id: 254
# base_score: 100
# section ranking: [90109, 90327, 90117, 90151, 90272]
# schedule: {90272, 90151}
# sections enrolled: 2
#
# student255(THE4):
# id: 255
# base_score: 400
# section ranking: [90751, 90156, 90567, 90146, 90128]
# schedule: {90567, 90156, 90146, 90751}
# sections enrolled: 4
#
# student256(MRC4):
# id: 256
# base_score: 400
# section ranking: [90565, 90512, 90804, 90491, 90098]
# schedule: {90512, 90491, 90804, 90565}
# sections enrolled: 4
#
# student257(GER1):
# id: 257
# base_score: 100
# section ranking: [90502, 90503, 90018, 90494, 90566]
# schedule: {90018}
# sections enrolled: 1
#
# student258(HBR4):
# id: 258
# base_score: 400
# section ranking: [90600, 90059, 90625, 90221, 90363]
# schedule: {90625, 90059, 90221, 90363}
# sections enrolled: 4
#
# student259(ASL1):
# id: 259
# base_score: 100
# section ranking: [90055, 90778, 90660, 90792, 90181]
# schedule: {90792, 90660, 90181}
# sections enrolled: 3
#
# student260(EAS5):
# id: 260
# base_score: 500
# section ranking: [90032, 90386, 90462, 90633, 90569]
# schedule: {90032, 90633, 90386, 90462}
# sections enrolled: 4
#
# student261(IS2):
# id: 261
# base_score: 200
# section ranking: [90348, 90571, 90342, 90630, 90593]
# schedule: {90593, 90342, 90630, 90348}
# sections enrolled: 4
#
# student262(GER4):
# id: 262
# base_score: 400
# section ranking: [90494, 90657, 90009, 90566, 90503]
# schedule: {90657, 90566, 90494}
# sections enrolled: 3
#
# student263(LA2):
# id: 263
# base_score: 200
# section ranking: [90547, 90539, 90538, 90513, 90590]
# schedule: {90538, 90547, 90539, 90590}
# sections enrolled: 4
#
# student264(BIO4):
# id: 264
# base_score: 400
# section ranking: [90092, 90073, 90539, 90071, 90789]
# schedule: {90073, 90092, 90789, 90071}
# sections enrolled: 4
#
# student265(LAT5):
# id: 265
# base_score: 500
# section ranking: [90518, 90081, 90517, 90683, 90472]
# schedule: {90081, 90517, 90518}
# sections enrolled: 3
#
# student266(CRT2):
# id: 266
# base_score: 200
# section ranking: [90168, 90557, 90117, 90205, 90612]
# schedule: {90612, 90205}
# sections enrolled: 2
#
# student267(JPN3):
# id: 267
# base_score: 300
# section ranking: [90289, 90553, 90552, 90116, 90075]
# schedule: {90552, 90289, 90553, 90116}
# sections enrolled: 4
#
# student268(CHI3):
# id: 268
# base_score: 300
# section ranking: [90109, 90107, 90734, 90447, 90673]
# schedule: {90109, 90447}
# sections enrolled: 2
#
# student269(ASL3):
# id: 269
# base_score: 300
# section ranking: [90778, 90055, 90111, 90639, 90152]
# schedule: {90152, 90639, 90111}
# sections enrolled: 3
#
# student270(AMS5):
# id: 270
# base_score: 500
# section ranking: [90768, 90028, 90153, 90659, 90693]
# schedule: {90768, 90153, 90659, 90028}
# sections enrolled: 4
#
# student271(HIS1):
# id: 271
# base_score: 100
# section ranking: [90136, 90813, 90672, 90251, 90474]
# schedule: {90136, 90251, 90813}
# sections enrolled: 3
#
# student272(ART1):
# id: 272
# base_score: 100
# section ranking: [90581, 90044, 90012, 90157, 90046]
# schedule: {90157, 90044, 90581}
# sections enrolled: 3
#
# student273(HIS5):
# id: 273
# base_score: 500
# section ranking: [90612, 90804, 90019, 90672, 90587]
# schedule: {90672, 90019, 90612, 90587}
# sections enrolled: 4
#
# student274(CHI5):
# id: 274
# base_score: 500
# section ranking: [90704, 90107, 90145, 90108, 90768]
# schedule: {90704, 90145, 90107, 90768}
# sections enrolled: 4
#
# student275(ART5):
# id: 275
# base_score: 500
# section ranking: [90816, 90052, 90053, 90047, 90300]
# schedule: {90816, 90052, 90053, 90047}
# sections enrolled: 4
#
# student276(AT3):
# id: 276
# base_score: 300
# section ranking: [90511, 90817, 90149, 90649, 90851]
# schedule: {90851, 90149, 90511}
# sections enrolled: 3
#
# student277(GC3):
# id: 277
# base_score: 300
# section ranking: [90629, 90311, 90359, 90499, 90248]
# schedule: {90359, 90499, 90629, 90311}
# sections enrolled: 4
#
# student278(PBH3):
# id: 278
# base_score: 300
# section ranking: [90323, 90193, 90166, 90240, 90467]
# schedule: {90240, 90467, 90323}
# sections enrolled: 3
#
# student279(HBR5):
# id: 279
# base_score: 500
# section ranking: [90021, 90032, 90600, 90480, 90475]
# schedule: {90032, 90600, 90480, 90021}
# sections enrolled: 4
#
# student280(CHI3):
# id: 280
# base_score: 300
# section ranking: [90109, 90223, 90107, 90673, 90108]
# schedule: {90109}
# sections enrolled: 1
#
# student281(ASL2):
# id: 281
# base_score: 200
# section ranking: [90055, 90754, 90571, 90666, 90778]
# schedule: {90754}
# sections enrolled: 1
#
# student282(EDU5):
# id: 282
# base_score: 500
# section ranking: [90045, 90375, 90374, 90681, 90245]
# schedule: {90245, 90045, 90374, 90375}
# sections enrolled: 4
#
# student283(ACC1):
# id: 283
# base_score: 100
# section ranking: [90511, 90002, 90003, 90658, 90083]
# schedule: {90083, 90002, 90003, 90511}
# sections enrolled: 4
#
# student284(SJS3):
# id: 284
# base_score: 300
# section ranking: [90277, 90800, 90574, 90316, 90324]
# schedule: {90800, 90316, 90277, 90574}
# sections enrolled: 4
#
# student285(CRT5):
# id: 285
# base_score: 500
# section ranking: [90659, 90168, 90817, 90464, 90534]
# schedule: {90168, 90817, 90659, 90464}
# sections enrolled: 4
#
# student286(ES2):
# id: 286
# base_score: 200
# section ranking: [90253, 90025, 90375, 90291, 90694]
# schedule: {90025, 90291, 90253}
# sections enrolled: 3
#
# student287(BOT1):
# id: 287
# base_score: 100
# section ranking: [90733, 90105, 90676, 90175, 90093]
# schedule: {90093, 90733}
# sections enrolled: 2
#
# student288(HMD3):
# id: 288
# base_score: 300
# section ranking: [90587, 90574, 90668, 90180, 90576]
# schedule: {90576, 90574}
# sections enrolled: 2
#
# student289(ARA2):
# id: 289
# base_score: 200
# section ranking: [90033, 90157, 90032, 90058, 90497]
# schedule: {90497, 90157}
# sections enrolled: 2
#
# student290(HMD5):
# id: 290
# base_score: 500
# section ranking: [90581, 90288, 90587, 90574, 90596]
# schedule: {90587, 90596, 90581, 90574}
# sections enrolled: 4
#
# student291(GRK3):
# id: 291
# base_score: 300
# section ranking: [90502, 90519, 90288, 90577, 90682]
# schedule: {90577, 90502}
# sections enrolled: 2
#
# student292(AMS4):
# id: 292
# base_score: 400
# section ranking: [90796, 90127, 90097, 90303, 90837]
# schedule: {90097, 90796, 90303, 90127}
# sections enrolled: 4
#
# student293(ARA4):
# id: 293
# base_score: 400
# section ranking: [90032, 90033, 90525, 90002, 90261]
# schedule: {90032, 90033, 90002, 90525}
# sections enrolled: 4
#
# student294(ASL5):
# id: 294
# base_score: 500
# section ranking: [90643, 90517, 90364, 90533, 90033]
# schedule: {90643, 90364, 90517, 90533}
# sections enrolled: 4
#
# student295(AMS3):
# id: 295
# base_score: 300
# section ranking: [90654, 90661, 90609, 90303, 90267]
# schedule: {90609, 90661, 90654, 90303}
# sections enrolled: 4
#
# student296(ART3):
# id: 296
# base_score: 300
# section ranking: [90045, 90046, 90021, 90145, 90038]
# schedule: {90038, 90045, 90046, 90021}
# sections enrolled: 4
#
# student297(PHY1):
# id: 297
# base_score: 100
# section ranking: [90770, 90035, 90011, 90171, 90005]
# schedule: {90171, 90005}
# sections enrolled: 2
#
# student298(AHI2):
# id: 298
# base_score: 200
# section ranking: [90638, 90005, 90004, 90592, 90157]
# schedule: {90004, 90157, 90638}
# sections enrolled: 3
#
# student299(ARC1):
# id: 299
# base_score: 100
# section ranking: [90035, 90037, 90010, 90016, 90034]
# schedule: {90016, 90010}
# sections enrolled: 2
#
# student300(AHI1):
# id: 300
# base_score: 100
# section ranking: [90013, 90153, 90141, 90634, 90005]
# schedule: {90634, 90013, 90005, 90141}
# sections enrolled: 4
#
# student301(JPN5):
# id: 301
# base_score: 500
# section ranking: [90553, 90303, 90235, 90552, 90542]
# schedule: {90553, 90235, 90542}
# sections enrolled: 3
#
# student302(COM5):
# id: 302
# base_score: 500
# section ranking: [90139, 90595, 90754, 90620, 90167]
# schedule: {90754, 90139, 90620, 90595}
# sections enrolled: 4
#
# student303(AST2):
# id: 303
# base_score: 200
# section ranking: [90023, 90058, 90475, 90057, 90804]
# schedule: {90023}
# sections enrolled: 1
#
# student304(HMD4):
# id: 304
# base_score: 400
# section ranking: [90578, 90287, 90199, 90509, 90651]
# schedule: {90578, 90509, 90287}
# sections enrolled: 3
#
# student305(BIO4):
# id: 305
# base_score: 400
# section ranking: [90297, 90088, 90789, 90121, 90675]
# schedule: {90088, 90297, 90789, 90121}
# sections enrolled: 4
#
# student306(LAT4):
# id: 306
# base_score: 400
# section ranking: [90683, 90517, 90518, 90519, 90332]
# schedule: {90683, 90517, 90518, 90519}
# sections enrolled: 4
#
# student307(PBH2):
# id: 307
# base_score: 200
# section ranking: [90375, 90376, 90597, 90537, 90316]
# schedule: {90597}
# sections enrolled: 1
#
# student308(IS5):
# id: 308
# base_score: 500
# section ranking: [90571, 90684, 90573, 90538, 90106]
# schedule: {90538, 90571, 90684, 90573}
# sections enrolled: 4
#
# student309(FYS4):
# id: 309
# base_score: 400
# section ranking: [90689, 90765, 90207, 90484, 90798]
# schedule: {90689, 90765, 90207}
# sections enrolled: 3
#
# student310(GC4):
# id: 310
# base_score: 400
# section ranking: [90055, 90674, 90488, 90772, 90693]
# schedule: {90674, 90772, 90693, 90055}
# sections enrolled: 4
#
# student311(BIO2):
# id: 311
# base_score: 200
# section ranking: [90088, 90326, 90768, 90348, 90141]
# schedule: {90348, 90141, 90326}
# sections enrolled: 3
#
# student312(CHI3):
# id: 312
# base_score: 300
# section ranking: [90536, 90108, 90107, 90109, 90673]
# schedule: {90536, 90109}
# sections enrolled: 2
#
# student313(FRH2):
# id: 313
# base_score: 200
# section ranking: [90478, 90783, 90646, 90475, 90679]
# schedule: {90646, 90783}
# sections enrolled: 2
#
# student314(GEO3):
# id: 314
# base_score: 300
# section ranking: [90260, 90254, 90289, 90122, 90769]
# schedule: {90289, 90769, 90254}
# sections enrolled: 3
#
# student315(GIS5):
# id: 315
# base_score: 500
# section ranking: [90794, 90535, 90344, 90620, 90771]
# schedule: {90794, 90771, 90620, 90535}
# sections enrolled: 4
#
# student316(MUS2):
# id: 316
# base_score: 200
# section ranking: [90259, 90049, 90736, 90164, 90449]
# schedule: {90736, 90049, 90259, 90164}
# sections enrolled: 4
#
# student317(CRT3):
# id: 317
# base_score: 300
# section ranking: [90649, 90168, 90333, 90667, 90095]
# schedule: {90649, 90667, 90095}
# sections enrolled: 3
#
# student318(MSM4):
# id: 318
# base_score: 400
# section ranking: [90014, 90683, 90193, 90312, 90203]
# schedule: {90193, 90203, 90683}
# sections enrolled: 3
#
# student319(LA3):
# id: 319
# base_score: 300
# section ranking: [90537, 90376, 90821, 90073, 90478]
# schedule: {90537, 90821}
# sections enrolled: 2
#
# student320(GOV2):
# id: 320
# base_score: 200
# section ranking: [90533, 90528, 90516, 90524, 90570]
# schedule: {90528, 90570, 90524, 90533}
# sections enrolled: 4
#
# student321(SPA4):
# id: 321
# base_score: 400
# section ranking: [90851, 90230, 90208, 90151, 90205]
# schedule: {90208, 90851, 90230, 90151}
# sections enrolled: 4
#
# student322(BOT2):
# id: 322
# base_score: 200
# section ranking: [90101, 90265, 90104, 90165, 90608]
# schedule: {90265, 90101}
# sections enrolled: 2
#
# student323(CHI2):
# id: 323
# base_score: 200
# section ranking: [90634, 90329, 90673, 90108, 90107]
# schedule: {90634}
# sections enrolled: 1
#
# student324(PBH5):
# id: 324
# base_score: 500
# section ranking: [90376, 90581, 90701, 90524, 90375]
# schedule: {90376, 90524, 90701, 90581}
# sections enrolled: 4
#
# ...
#
# student2896(HIS3):
# id: 2896
# base_score: 300
# section ranking: [90149, 90622, 90607, 90621, 90608]
# schedule: {90608, 90149, 90622, 90607}
# sections enrolled: 4
#
# student2897(FYS2):
# id: 2897
# base_score: 200
# section ranking: [90032, 90772, 90764, 90235, 90797]
# schedule: {90764, 90797, 90772, 90235}
# sections enrolled: 4
#
# student2898(AHI5):
# id: 2898
# base_score: 500
# section ranking: [90634, 90004, 90017, 90659, 90247]
# schedule: {90017, 90634, 90659, 90004}
# sections enrolled: 4
#
# student2899(CHI4):
# id: 2899
# base_score: 400
# section ranking: [90107, 90109, 90798, 90116, 90367]
# schedule: {90107, 90116, 90109, 90798}
# sections enrolled: 4
#
# student2900(HIS4):
# id: 2900
# base_score: 400
# section ranking: [90626, 90581, 90044, 90612, 90596]
# schedule: {90626, 90596, 90044, 90581}
# sections enrolled: 4
#
# student2901(BOT1):
# id: 2901
# base_score: 100
# section ranking: [90733, 90105, 90473, 90101, 90093]
# schedule: {90473, 90093, 90733}
# sections enrolled: 3
#
# student2902(ACC5):
# id: 2902
# base_score: 500
# section ranking: [90131, 90006, 90002, 90650, 90003]
# schedule: {90650, 90131, 90003, 90006}
# sections enrolled: 4
#
# student2903(JS4):
# id: 2903
# base_score: 400
# section ranking: [90250, 90642, 90345, 90551, 90329]
# schedule: {90345, 90250, 90329, 90551}
# sections enrolled: 4
#
# student2904(GER5):
# id: 2904
# base_score: 500
# section ranking: [90112, 90502, 90494, 90811, 90109]
# schedule: {90112, 90494, 90811, 90502}
# sections enrolled: 4
#
# student2905(SJS1):
# id: 2905
# base_score: 100
# section ranking: [90277, 90855, 90323, 90005, 90827]
# schedule: {90827, 90005, 90855}
# sections enrolled: 3
#
# student2906(LA4):
# id: 2906
# base_score: 400
# section ranking: [90645, 90549, 90542, 90208, 90547]
# schedule: {90208, 90547, 90645, 90549}
# sections enrolled: 4
#
# student2907(GEO3):
# id: 2907
# base_score: 300
# section ranking: [90084, 90260, 90554, 90289, 90254]
# schedule: {90260, 90289, 90084}
# sections enrolled: 3
#
# student2908(ES2):
# id: 2908
# base_score: 200
# section ranking: [90566, 90342, 90249, 90293, 90694]
# schedule: {90249, 90293, 90694, 90342}
# sections enrolled: 4
#
# student2909(AFR2):
# id: 2909
# base_score: 200
# section ranking: [90467, 90145, 90825, 90611, 90700]
# schedule: {90145, 90467, 90825, 90611}
# sections enrolled: 4
#
# student2910(GOV2):
# id: 2910
# base_score: 200
# section ranking: [90644, 90473, 90150, 90643, 90525]
# schedule: {90473, 90643, 90644, 90150}
# sections enrolled: 4
#
# student2911(PKP1):
# id: 2911
# base_score: 100
# section ranking: [90165, 90121, 90290, 90327, 90320]
# schedule: {90320, 90121}
# sections enrolled: 2
#
# student2912(GER4):
# id: 2912
# base_score: 400
# section ranking: [90494, 90098, 90497, 90502, 90163]
# schedule: {90497, 90098, 90163, 90494}
# sections enrolled: 4
#
# student2913(HBR4):
# id: 2913
# base_score: 400
# section ranking: [90600, 90565, 90344, 90302, 90376]
# schedule: {90600, 90344, 90302, 90376}
# sections enrolled: 4
#
# student2914(LAT1):
# id: 2914
# base_score: 100
# section ranking: [90041, 90517, 90132, 90467, 90494]
# schedule: {90041, 90467}
# sections enrolled: 2
#
# student2915(ENG1):
# id: 2915
# base_score: 100
# section ranking: [90662, 90663, 90647, 90650, 90450]
# schedule: {90662, 90663, 90450, 90650}
# sections enrolled: 4
#
# student2916(CHI3):
# id: 2916
# base_score: 300
# section ranking: [90673, 90109, 90083, 90713, 90107]
# schedule: {90713, 90673, 90083, 90107}
# sections enrolled: 4
#
# student2917(GEO4):
# id: 2917
# base_score: 400
# section ranking: [90260, 90047, 90254, 90251, 90289]
# schedule: {90289, 90251, 90260, 90254}
# sections enrolled: 4
#
# student2918(GER1):
# id: 2918
# base_score: 100
# section ranking: [90657, 90376, 90502, 90575, 90566]
# schedule: {90657, 90502}
# sections enrolled: 2
#
# student2919(EDU1):
# id: 2919
# base_score: 100
# section ranking: [90245, 90106, 90092, 90332, 90244]
# schedule: {90244, 90245}
# sections enrolled: 2
#
# student2920(COM1):
# id: 2920
# base_score: 100
# section ranking: [90145, 90683, 90464, 90140, 90800]
# schedule: {90464, 90145, 90800, 90140}
# sections enrolled: 4
#
# student2921(HBR1):
# id: 2921
# base_score: 100
# section ranking: [90600, 90497, 90804, 90109, 90734]
# schedule: {90497}
# sections enrolled: 1
#
# student2922(PHY5):
# id: 2922
# base_score: 500
# section ranking: [90333, 90331, 90330, 90473, 90488]
# schedule: {90488, 90330, 90331, 90333}
# sections enrolled: 4
#
# student2923(HMD3):
# id: 2923
# base_score: 300
# section ranking: [90336, 90754, 90833, 90562, 90581]
# schedule: {90833, 90754, 90562}
# sections enrolled: 3
#
# student2924(LA2):
# id: 2924
# base_score: 200
# section ranking: [90295, 90539, 90119, 90550, 90467]
# schedule: {90467, 90539, 90550, 90295}
# sections enrolled: 4
#
# student2925(AST2):
# id: 2925
# base_score: 200
# section ranking: [90058, 90474, 90056, 90057, 90012]
# schedule: {90056}
# sections enrolled: 1
#
# student2926(NEU2):
# id: 2926
# base_score: 200
# section ranking: [90308, 90610, 90141, 90287, 90825]
# schedule: {90825, 90610, 90308, 90141}
# sections enrolled: 4
#
# student2927(BOT4):
# id: 2927
# base_score: 400
# section ranking: [90094, 90106, 90478, 90183, 90318]
# schedule: {90106, 90478, 90094, 90183}
# sections enrolled: 4
#
# student2928(ITL5):
# id: 2928
# base_score: 500
# section ranking: [90045, 90022, 90560, 90558, 90776]
# schedule: {90560, 90045, 90022}
# sections enrolled: 3
#
# student2929(AT3):
# id: 2929
# base_score: 300
# section ranking: [90060, 90851, 90529, 90059, 90181]
# schedule: {90529, 90851, 90060, 90181}
# sections enrolled: 4
#
# student2930(SOC1):
# id: 2930
# base_score: 100
# section ranking: [90518, 90272, 90131, 90591, 90607]
# schedule: {90272, 90607, 90131, 90591}
# sections enrolled: 4
#
# student2931(SJS2):
# id: 2931
# base_score: 200
# section ranking: [90277, 90273, 90266, 90790, 90660]
# schedule: {90273, 90660, 90277, 90266}
# sections enrolled: 4
#
# student2932(THE4):
# id: 2932
# base_score: 400
# section ranking: [90766, 90181, 90478, 90751, 90578]
# schedule: {90578, 90478, 90181, 90766}
# sections enrolled: 4
#
# student2933(PKP3):
# id: 2933
# base_score: 300
# section ranking: [90327, 90660, 90347, 90842, 90698]
# schedule: {90660, 90327}
# sections enrolled: 2
#
# student2934(GRK1):
# id: 2934
# base_score: 100
# section ranking: [90468, 90224, 90300, 90054, 90682]
# schedule: {90224, 90300, 90468, 90054}
# sections enrolled: 4
#
# student2935(AHI5):
# id: 2935
# base_score: 500
# section ranking: [90013, 90822, 90015, 90111, 90060]
# schedule: {90111, 90013, 90822, 90015}
# sections enrolled: 4
#
# student2936(CRT5):
# id: 2936
# base_score: 500
# section ranking: [90168, 90140, 90532, 90338, 90107]
# schedule: {90168, 90532, 90338, 90140}
# sections enrolled: 4
#
# student2937(CRT1):
# id: 2937
# base_score: 100
# section ranking: [90274, 90168, 90582, 90472, 90221]
# schedule: {90274, 90472, 90582}
# sections enrolled: 3
#
# student2938(DAT1):
# id: 2938
# base_score: 100
# section ranking: [90218, 90097, 90246, 90221, 90082]
# schedule: {90082, 90246, 90221}
# sections enrolled: 3
#
# student2939(MAT2):
# id: 2939
# base_score: 200
# section ranking: [90153, 90509, 90501, 90820, 90116]
# schedule: {90153, 90116, 90820, 90509}
# sections enrolled: 4
#
# student2940(FYS4):
# id: 2940
# base_score: 400
# section ranking: [90823, 90652, 90633, 90795, 90689]
# schedule: {90633, 90652, 90823}
# sections enrolled: 3
#
# student2941(PHE4):
# id: 2941
# base_score: 400
# section ranking: [90349, 90657, 90193, 90389, 90346]
# schedule: {90193, 90657, 90389, 90349}
# sections enrolled: 4
#
# student2942(GIS2):
# id: 2942
# base_score: 200
# section ranking: [90269, 90639, 90620, 90575, 90535]
# schedule: {90535, 90639}
# sections enrolled: 2
#
# student2943(PAX3):
# id: 2943
# base_score: 300
# section ranking: [90374, 90175, 90793, 90572, 90253]
# schedule: {90572, 90374, 90175}
# sections enrolled: 3
#
# student2944(LAT2):
# id: 2944
# base_score: 200
# section ranking: [90128, 90499, 90518, 90090, 90135]
# schedule: {90128, 90090, 90499}
# sections enrolled: 3
#
# student2945(GER5):
# id: 2945
# base_score: 500
# section ranking: [90216, 90494, 90450, 90648, 90101]
# schedule: {90216, 90648, 90450, 90494}
# sections enrolled: 4
#
# student2946(COM1):
# id: 2946
# base_score: 100
# section ranking: [90545, 90451, 90244, 90139, 90218]
# schedule: {90244}
# sections enrolled: 1
#
# student2947(GOV1):
# id: 2947
# base_score: 100
# section ranking: [90524, 90556, 90564, 90645, 90522]
# schedule: {90556, 90564, 90524, 90645}
# sections enrolled: 4
#
# student2948(ENT1):
# id: 2948
# base_score: 100
# section ranking: [90248, 90247, 90534, 90615, 90016]
# schedule: {90016, 90615, 90534}
# sections enrolled: 3
#
# student2949(MUS5):
# id: 2949
# base_score: 500
# section ranking: [90855, 90078, 90462, 90390, 90386]
# schedule: {90462, 90390, 90078, 90855}
# sections enrolled: 4
#
# student2950(FRH5):
# id: 2950
# base_score: 500
# section ranking: [90793, 90031, 90476, 90472, 90148]
# schedule: {90472, 90793, 90476, 90031}
# sections enrolled: 4
#
# student2951(SOC2):
# id: 2951
# base_score: 200
# section ranking: [90778, 90630, 90169, 90699, 90271]
# schedule: {90169, 90630, 90271}
# sections enrolled: 3
#
# student2952(PHI4):
# id: 2952
# base_score: 400
# section ranking: [90618, 90151, 90572, 90126, 90275]
# schedule: {90618, 90275, 90126, 90151}
# sections enrolled: 4
#
# student2953(GRK2):
# id: 2953
# base_score: 200
# section ranking: [90220, 90682, 90577, 90575, 90079]
# schedule: {90682, 90079}
# sections enrolled: 2
#
# student2954(BOT4):
# id: 2954
# base_score: 400
# section ranking: [90105, 90095, 90733, 90286, 90541]
# schedule: {90105, 90286, 90095}
# sections enrolled: 3
#
# student2955(EDU4):
# id: 2955
# base_score: 400
# section ranking: [90244, 90243, 90833, 90047, 90242]
# schedule: {90833, 90243, 90244, 90047}
# sections enrolled: 4
#
# student2956(ACC5):
# id: 2956
# base_score: 500
# section ranking: [90289, 90699, 90204, 90003, 90002]
# schedule: {90289, 90002, 90204}
# sections enrolled: 3
#
# student2957(BIO5):
# id: 2957
# base_score: 500
# section ranking: [90773, 90796, 90323, 90771, 90254]
# schedule: {90771, 90796, 90773}
# sections enrolled: 3
#
# student2958(ITL1):
# id: 2958
# base_score: 100
# section ranking: [90810, 90525, 90562, 90561, 90634]
# schedule: {90562, 90810, 90634, 90525}
# sections enrolled: 4
#
# student2959(EDU2):
# id: 2959
# base_score: 200
# section ranking: [90246, 90244, 90515, 90681, 90242]
# schedule: {90242, 90515, 90244, 90246}
# sections enrolled: 4
#
# student2960(SJS1):
# id: 2960
# base_score: 100
# section ranking: [90277, 90048, 90106, 90655, 90643]
# schedule: {90643, 90655}
# sections enrolled: 2
#
# student2961(PKP5):
# id: 2961
# base_score: 500
# section ranking: [90123, 90690, 90327, 90480, 90615]
# schedule: {90615, 90690, 90123, 90327}
# sections enrolled: 4
#
# student2962(ANT5):
# id: 2962
# base_score: 500
# section ranking: [90188, 90006, 90020, 90019, 90109]
# schedule: {90020, 90188, 90109, 90006}
# sections enrolled: 4
#
# student2963(CHI4):
# id: 2963
# base_score: 400
# section ranking: [90143, 90050, 90101, 90538, 90218]
# schedule: {90050, 90218, 90143}
# sections enrolled: 3
#
# student2964(CLA1):
# id: 2964
# base_score: 100
# section ranking: [90135, 90639, 90130, 90372, 90137]
# schedule: {90639, 90372, 90135}
# sections enrolled: 3
#
# student2965(FDP4):
# id: 2965
# base_score: 400
# section ranking: [90294, 90801, 90342, 90286, 90587]
# schedule: {90801, 90587, 90294, 90342}
# sections enrolled: 4
#
# student2966(AT4):
# id: 2966
# base_score: 400
# section ranking: [90654, 90817, 90149, 90059, 90060]
# schedule: {90817, 90059, 90149, 90654}
# sections enrolled: 4
#
# student2967(SLA2):
# id: 2967
# base_score: 200
# section ranking: [90680, 90073, 90586, 90276, 90481]
# schedule: {90276, 90481, 90073, 90586}
# sections enrolled: 4
#
# student2968(FDP1):
# id: 2968
# base_score: 100
# section ranking: [90257, 90294, 90624, 90032, 90689]
# schedule: {90624, 90257, 90689}
# sections enrolled: 3
#
# student2969(JPN4):
# id: 2969
# base_score: 400
# section ranking: [90592, 90026, 90803, 90554, 90555]
# schedule: {90592, 90554, 90026, 90803}
# sections enrolled: 4
#
# student2970(ECO4):
# id: 2970
# base_score: 400
# section ranking: [90693, 90584, 90032, 90017, 90046]
# schedule: {90584, 90017, 90693, 90046}
# sections enrolled: 4
#
# student2971(SJS1):
# id: 2971
# base_score: 100
# section ranking: [90277, 90264, 90814, 90164, 90386]
# schedule: {90164, 90264, 90814}
# sections enrolled: 3
#
# student2972(GOV4):
# id: 2972
# base_score: 400
# section ranking: [90104, 90507, 90094, 90531, 90638]
# schedule: {90104, 90507, 90094, 90638}
# sections enrolled: 4
#
# student2973(MUS3):
# id: 2973
# base_score: 300
# section ranking: [90464, 90136, 90795, 90388, 90447]
# schedule: {90464, 90136, 90795, 90388}
# sections enrolled: 4
#
# student2974(FYS5):
# id: 2974
# base_score: 500
# section ranking: [90196, 90770, 90797, 90124, 90691]
# schedule: {90770, 90124, 90196, 90797}
# sections enrolled: 4
#
# student2975(HBR4):
# id: 2975
# base_score: 400
# section ranking: [90386, 90600, 90004, 90388, 90818]
# schedule: {90600, 90386, 90004, 90388}
# sections enrolled: 4
#
# student2976(BIO4):
# id: 2976
# base_score: 400
# section ranking: [90558, 90306, 90328, 90316, 90675]
# schedule: {90328, 90306, 90316, 90558}
# sections enrolled: 4
#
# student2977(LAT1):
# id: 2977
# base_score: 100
# section ranking: [90683, 90071, 90519, 90566, 90215]
# schedule: {90683}
# sections enrolled: 1
#
# student2978(AFR4):
# id: 2978
# base_score: 400
# section ranking: [90262, 90824, 90246, 90615, 90827]
# schedule: {90824, 90246, 90262}
# sections enrolled: 3
#
# student2979(NEU4):
# id: 2979
# base_score: 400
# section ranking: [90302, 90287, 90647, 90308, 90653]
# schedule: {90647, 90653, 90302, 90287}
# sections enrolled: 4
#
# student2980(NEU1):
# id: 2980
# base_score: 100
# section ranking: [90308, 90302, 90287, 90790, 90615]
# schedule: {90308}
# sections enrolled: 1
#
# student2981(GIS5):
# id: 2981
# base_score: 500
# section ranking: [90075, 90620, 90535, 90197, 90834]
# schedule: {90075, 90620, 90197, 90535}
# sections enrolled: 4
#
# student2982(HIS4):
# id: 2982
# base_score: 400
# section ranking: [90060, 90034, 90608, 90248, 90103]
# schedule: {90608, 90034, 90060, 90248}
# sections enrolled: 4
#
# student2983(COM2):
# id: 2983
# base_score: 200
# section ranking: [90143, 90179, 90046, 90464, 90207]
# schedule: {90464, 90179, 90207, 90143}
# sections enrolled: 4
#
# student2984(SOC1):
# id: 2984
# base_score: 100
# section ranking: [90591, 90273, 90646, 90366, 90098]
# schedule: {90273, 90591}
# sections enrolled: 2
#
# student2985(FYS3):
# id: 2985
# base_score: 300
# section ranking: [90032, 90473, 90771, 90802, 90046]
# schedule: {90473, 90802, 90771}
# sections enrolled: 3
#
# student2986(AST2):
# id: 2986
# base_score: 200
# section ranking: [90684, 90058, 90056, 90679, 90057]
# schedule: {90056, 90679}
# sections enrolled: 2
#
# student2987(FYS2):
# id: 2987
# base_score: 200
# section ranking: [90799, 90479, 90770, 90491, 90480]
# schedule: {90480, 90479, 90799}
# sections enrolled: 3
#
# student2988(RUS4):
# id: 2988
# base_score: 400
# section ranking: [90278, 90280, 90696, 90279, 90614]
# schedule: {90280, 90696, 90278, 90614}
# sections enrolled: 4
#
# student2989(HBR4):
# id: 2989
# base_score: 400
# section ranking: [90608, 90311, 90600, 90639, 90087]
# schedule: {90608, 90639, 90311}
# sections enrolled: 3
#
# student2990(CRT3):
# id: 2990
# base_score: 300
# section ranking: [90168, 90346, 90836, 90081, 90600]
# schedule: {90081, 90346, 90836}
# sections enrolled: 3
#
# student2991(HBR4):
# id: 2991
# base_score: 400
# section ranking: [90600, 90124, 90009, 90596, 90501]
# schedule: {90600, 90124, 90596, 90501}
# sections enrolled: 4
#
# student2992(NEU5):
# id: 2992
# base_score: 500
# section ranking: [90287, 90842, 90260, 90790, 90690]
# schedule: {90842, 90260, 90790, 90287}
# sections enrolled: 4
#
# student2993(HIS2):
# id: 2993
# base_score: 200
# section ranking: [90572, 90608, 90641, 90047, 90795]
# schedule: {90608, 90641, 90795, 90572}
# sections enrolled: 4
#
# student2994(HMD2):
# id: 2994
# base_score: 200
# section ranking: [90587, 90621, 90494, 90684, 90574]
# schedule: {90621, 90574}
# sections enrolled: 2
#
# student2995(MAT2):
# id: 2995
# base_score: 200
# section ranking: [90306, 90497, 90511, 90317, 90501]
# schedule: {90306, 90317, 90501, 90511}
# sections enrolled: 4
#
# student2996(EDU4):
# id: 2996
# base_score: 400
# section ranking: [90243, 90245, 90244, 90672, 90681]
# schedule: {90672, 90243, 90244, 90245}
# sections enrolled: 4
#
# student2997(SOC5):
# id: 2997
# base_score: 500
# section ranking: [90135, 90273, 90270, 90307, 90274]
# schedule: {90273, 90307, 90270, 90135}
# sections enrolled: 4
#
# student2998(MRC2):
# id: 2998
# base_score: 200
# section ranking: [90491, 90320, 90556, 90791, 90096]
# schedule: {90320, 90096, 90556, 90791}
# sections enrolled: 4
#
# student2999(DAN1):
# id: 2999
# base_score: 100
# section ranking: [90659, 90183, 90171, 90682, 90697]
# schedule: {90171, 90659}
# sections enrolled: 2

# %%
to_pop = []
for id, section in sections.items():
    if section.dept != "COM":
        to_pop.append(id)
for id in to_pop:
    sections.pop(id)
student_dict = data.generate_students_weighted(sections, 2000)
for key in student_dict:
    student_dict[key].find_conflicts(sections)
    print(student_dict[key].conflicts_dict)
# Out:
# {90144: set(), 90166: set(), 90139: set(), 90142: set(), 90163: set()}
# {90165: set(), 90139: {90145}, 90145: {90139}, 90166: set(), 90164: set()}
# {90145: set(), 90142: set(), 90146: set(), 90164: set(), 90148: set()}
# {90145: set(), 90143: set(), 90146: set(), 90334: set(), 90167: set()}
# {90334: set(), 90139: set(), 90163: set(), 90146: set(), 90142: set()}
# {90164: set(), 90146: set(), 90163: set(), 90148: set(), 90139: set()}
# {90145: set(), 90140: set(), 90143: set(), 90146: set(), 90163: set()}
# {90146: set(), 90142: set(), 90754: set(), 90147: set(), 90334: set()}
# {90165: set(), 90140: {90166}, 90146: set(), 90166: {90140}, 90145: set()}
# {90147: {90143}, 90140: set(), 90334: set(), 90143: {90147}, 90167: set()}
# {90165: set(), 90147: {90143}, 90143: {90147}, 90163: set(), 90164: set()}
# {90140: set(), 90147: set(), 90139: {90145}, 90145: {90139}, 90165: set()}
# {90164: set(), 90142: set(), 90139: set(), 90146: set(), 90754: set()}
# {90144: set(), 90147: set(), 90145: set(), 90164: set(), 90334: set()}
# {90164: set(), 90148: set(), 90142: set(), 90145: set(), 90334: set()}
# {90166: set(), 90164: set(), 90146: set(), 90148: set(), 90139: set()}
# {90144: set(), 90145: {90139}, 90139: {90145}, 90147: set(), 90146: set()}
# {90143: {90147}, 90146: set(), 90140: set(), 90164: set(), 90147: {90143}}
# {90163: set(), 90165: set(), 90334: set(), 90754: set(), 90142: set()}
# {90139: set(), 90148: set(), 90166: set(), 90167: set(), 90142: set()}
# {90145: set(), 90166: set(), 90167: set(), 90147: set(), 90148: set()}
# {90166: set(), 90139: {90145}, 90143: set(), 90754: set(), 90145: {90139}}
# {90334: set(), 90165: set(), 90139: set(), 90166: set(), 90146: set()}
# {90334: set(), 90145: set(), 90144: set(), 90164: set(), 90140: set()}
# {90163: set(), 90754: set(), 90143: set(), 90146: set(), 90140: set()}
# {90146: set(), 90754: set(), 90167: set(), 90140: set(), 90148: set()}
# {90139: set(), 90144: set(), 90334: set(), 90165: set(), 90143: set()}
# {90140: set(), 90139: set(), 90143: set(), 90146: set(), 90142: set()}
# {90334: set(), 90146: set(), 90164: set(), 90147: set(), 90167: set()}
# {90147: set(), 90164: set(), 90146: set(), 90148: set(), 90754: set()}
# {90754: set(), 90334: set(), 90145: {90139}, 90139: {90145}, 90167: set()}
# {90140: {90166}, 90166: {90140}, 90148: set(), 90146: set(), 90144: set()}
# {90167: set(), 90163: set(), 90147: set(), 90166: set(), 90334: set()}
# {90147: {90143}, 90146: set(), 90166: set(), 90143: {90147}, 90165: set()}
# {90165: set(), 90144: set(), 90164: set(), 90143: set(), 90146: set()}
# {90146: set(), 90140: set(), 90167: set(), 90165: set(), 90145: set()}
# {90164: set(), 90144: set(), 90163: set(), 90146: set(), 90334: set()}
# {90143: set(), 90148: set(), 90164: set(), 90166: set(), 90145: set()}
# {90163: set(), 90166: set(), 90754: set(), 90146: set(), 90142: set()}
# {90144: set(), 90165: set(), 90143: set(), 90139: set(), 90142: set()}
# {90140: set(), 90165: set(), 90754: set(), 90144: set(), 90334: set()}
# {90139: set(), 90754: set(), 90164: set(), 90144: set(), 90166: set()}
# {90167: set(), 90334: set(), 90163: set(), 90147: set(), 90165: set()}
# {90165: set(), 90143: set(), 90167: set(), 90334: set(), 90166: set()}
# {90165: set(), 90163: set(), 90140: set(), 90147: set(), 90754: set()}
# {90164: set(), 90147: {90143}, 90143: {90147}, 90146: set(), 90148: set()}
# {90139: {90145}, 90146: set(), 90148: set(), 90145: {90139}, 90142: set()}
# {90334: set(), 90146: set(), 90145: set(), 90163: set(), 90165: set()}
# {90163: set(), 90139: {90145}, 90165: set(), 90145: {90139}, 90147: set()}
# {90166: {90140}, 90754: set(), 90140: {90166}, 90144: set(), 90164: set()}
# {90142: set(), 90139: set(), 90334: set(), 90167: set(), 90163: set()}
# {90334: set(), 90164: set(), 90143: set(), 90166: set(), 90165: set()}
# {90142: set(), 90167: set(), 90146: set(), 90164: set(), 90334: set()}
# {90140: {90166}, 90139: set(), 90334: set(), 90166: {90140}, 90754: set()}
# {90164: set(), 90163: set(), 90166: set(), 90165: set(), 90146: set()}
# {90140: set(), 90164: set(), 90145: set(), 90167: set(), 90142: set()}
# {90143: set(), 90754: set(), 90148: set(), 90139: set(), 90164: set()}
# {90143: set(), 90146: set(), 90164: set(), 90148: set(), 90167: set()}
# {90147: {90143}, 90143: {90147}, 90167: set(), 90140: set(), 90144: set()}
# {90166: set(), 90167: set(), 90165: set(), 90145: set(), 90142: set()}
# {90166: {90140}, 90140: {90166}, 90143: set(), 90165: set(), 90167: set()}
# {90334: set(), 90146: set(), 90140: set(), 90142: set(), 90165: set()}
# {90166: {90140}, 90147: set(), 90139: set(), 90144: set(), 90140: {90166}}
# {90145: set(), 90167: set(), 90166: set(), 90165: set(), 90144: set()}
# {90145: set(), 90334: set(), 90167: set(), 90140: set(), 90754: set()}
# {90148: set(), 90144: set(), 90163: set(), 90142: set(), 90164: set()}
# {90146: set(), 90148: set(), 90144: set(), 90147: set(), 90166: set()}
# {90143: set(), 90166: set(), 90165: set(), 90167: set(), 90148: set()}
# {90754: set(), 90165: set(), 90334: set(), 90164: set(), 90144: set()}
# {90144: set(), 90142: set(), 90166: set(), 90148: set(), 90143: set()}
# {90143: set(), 90142: set(), 90166: set(), 90167: set(), 90164: set()}
# {90754: set(), 90140: set(), 90164: set(), 90142: set(), 90165: set()}
# {90165: set(), 90754: set(), 90148: set(), 90139: {90145}, 90145: {90139}}
# {90139: set(), 90148: set(), 90163: set(), 90165: set(), 90140: set()}
# {90163: set(), 90147: set(), 90334: set(), 90146: set(), 90148: set()}
# {90166: {90140}, 90164: set(), 90147: set(), 90165: set(), 90140: {90166}}
# {90163: set(), 90146: set(), 90167: set(), 90139: set(), 90164: set()}
# {90142: set(), 90144: set(), 90163: set(), 90166: set(), 90146: set()}
# {90143: set(), 90165: set(), 90148: set(), 90754: set(), 90139: set()}
# {90163: set(), 90143: {90147}, 90147: {90143}, 90164: set(), 90146: set()}
# {90163: set(), 90142: set(), 90754: set(), 90165: set(), 90144: set()}
# {90143: set(), 90144: set(), 90145: set(), 90164: set(), 90148: set()}
# {90147: set(), 90140: set(), 90148: set(), 90167: set(), 90163: set()}
# {90165: set(), 90167: set(), 90754: set(), 90146: set(), 90144: set()}
# {90166: set(), 90165: set(), 90164: set(), 90148: set(), 90147: set()}
# {90146: set(), 90754: set(), 90167: set(), 90144: set(), 90139: set()}
# {90143: set(), 90140: set(), 90334: set(), 90145: set(), 90164: set()}
# {90167: set(), 90145: set(), 90142: set(), 90165: set(), 90143: set()}
# {90145: set(), 90164: set(), 90144: set(), 90166: set(), 90146: set()}
# {90164: set(), 90142: set(), 90334: set(), 90140: set(), 90754: set()}
# {90144: set(), 90142: set(), 90166: {90140}, 90140: {90166}, 90163: set()}
# {90142: set(), 90145: set(), 90148: set(), 90165: set(), 90163: set()}
# {90143: set(), 90164: set(), 90165: set(), 90139: set(), 90334: set()}
# {90754: set(), 90164: set(), 90145: set(), 90147: set(), 90140: set()}
# {90147: set(), 90165: set(), 90146: set(), 90139: set(), 90148: set()}
# {90166: set(), 90754: set(), 90148: set(), 90146: set(), 90145: set()}
# {90143: {90147}, 90167: set(), 90139: set(), 90147: {90143}, 90144: set()}
# {90145: set(), 90143: set(), 90148: set(), 90164: set(), 90754: set()}
# {90142: set(), 90140: set(), 90334: set(), 90146: set(), 90165: set()}
# {90143: set(), 90145: set(), 90140: set(), 90146: set(), 90164: set()}
# {90163: set(), 90146: set(), 90165: set(), 90140: set(), 90144: set()}
# {90142: set(), 90145: set(), 90146: set(), 90163: set(), 90148: set()}
# {90166: set(), 90144: set(), 90139: set(), 90754: set(), 90143: set()}
# {90139: set(), 90140: set(), 90164: set(), 90142: set(), 90144: set()}
# {90148: set(), 90167: set(), 90165: set(), 90147: set(), 90166: set()}
# {90139: set(), 90754: set(), 90143: set(), 90142: set(), 90163: set()}
# {90142: set(), 90166: set(), 90167: set(), 90164: set(), 90139: set()}
# {90143: set(), 90754: set(), 90140: set(), 90144: set(), 90165: set()}
# {90167: set(), 90148: set(), 90142: set(), 90139: set(), 90754: set()}
# {90163: set(), 90165: set(), 90142: set(), 90144: set(), 90334: set()}
# {90148: set(), 90147: set(), 90167: set(), 90142: set(), 90165: set()}
# {90146: set(), 90143: set(), 90139: set(), 90167: set(), 90166: set()}
# {90754: set(), 90334: set(), 90167: set(), 90164: set(), 90166: set()}
# {90166: set(), 90143: set(), 90148: set(), 90167: set(), 90142: set()}
# {90147: set(), 90334: set(), 90165: set(), 90166: set(), 90754: set()}
# {90142: set(), 90165: set(), 90754: set(), 90166: set(), 90164: set()}
# {90145: {90139}, 90146: set(), 90139: {90145}, 90166: set(), 90164: set()}
# {90166: set(), 90148: set(), 90145: set(), 90165: set(), 90146: set()}
# {90143: {90147}, 90164: set(), 90146: set(), 90147: {90143}, 90167: set()}
# {90163: set(), 90754: set(), 90145: set(), 90164: set(), 90334: set()}
# {90163: set(), 90334: set(), 90166: set(), 90139: set(), 90143: set()}
# {90334: set(), 90146: set(), 90163: set(), 90139: set(), 90148: set()}
# {90145: set(), 90148: set(), 90146: set(), 90334: set(), 90147: set()}
# {90147: set(), 90334: set(), 90139: set(), 90163: set(), 90140: set()}
# {90143: set(), 90166: set(), 90167: set(), 90146: set(), 90148: set()}
# {90142: set(), 90146: set(), 90144: set(), 90140: set(), 90167: set()}
# {90164: set(), 90144: set(), 90143: set(), 90145: set(), 90142: set()}
# {90165: set(), 90144: set(), 90163: set(), 90140: set(), 90139: set()}
# {90164: set(), 90143: set(), 90142: set(), 90140: {90166}, 90166: {90140}}
# {90145: {90139}, 90165: set(), 90139: {90145}, 90142: set(), 90140: set()}
# {90165: set(), 90139: set(), 90148: set(), 90754: set(), 90163: set()}
# {90166: {90140}, 90165: set(), 90142: set(), 90144: set(), 90140: {90166}}
# {90167: set(), 90148: set(), 90139: set(), 90334: set(), 90144: set()}
# {90147: set(), 90148: set(), 90145: set(), 90163: set(), 90334: set()}
# {90148: set(), 90164: set(), 90147: set(), 90146: set(), 90166: set()}
# {90146: set(), 90145: {90139}, 90139: {90145}, 90754: set(), 90164: set()}
# {90163: set(), 90754: set(), 90144: set(), 90166: set(), 90164: set()}
# {90167: set(), 90334: set(), 90165: set(), 90146: set(), 90163: set()}
# {90334: set(), 90142: set(), 90163: set(), 90166: {90140}, 90140: {90166}}
# {90145: {90139}, 90754: set(), 90139: {90145}, 90147: set(), 90142: set()}
# {90146: set(), 90147: {90143}, 90163: set(), 90143: {90147}, 90164: set()}
# {90165: set(), 90143: set(), 90164: set(), 90334: set(), 90754: set()}
# {90146: set(), 90142: set(), 90145: {90139}, 90147: set(), 90139: {90145}}
# {90146: set(), 90754: set(), 90144: set(), 90147: set(), 90167: set()}
# {90166: set(), 90143: set(), 90754: set(), 90167: set(), 90165: set()}
# {90144: set(), 90163: set(), 90166: set(), 90164: set(), 90145: set()}
# {90139: set(), 90163: set(), 90148: set(), 90754: set(), 90334: set()}
# {90142: set(), 90163: set(), 90165: set(), 90148: set(), 90145: set()}
# {90163: set(), 90148: set(), 90144: set(), 90146: set(), 90165: set()}
# {90164: set(), 90146: set(), 90140: set(), 90139: set(), 90167: set()}
# {90148: set(), 90334: set(), 90146: set(), 90167: set(), 90754: set()}
# {90139: set(), 90143: {90147}, 90144: set(), 90147: {90143}, 90334: set()}
# {90334: set(), 90167: set(), 90145: set(), 90144: set(), 90165: set()}
# {90146: set(), 90145: set(), 90166: set(), 90163: set(), 90144: set()}
# {90334: set(), 90146: set(), 90164: set(), 90148: set(), 90167: set()}
# {90167: set(), 90147: set(), 90164: set(), 90146: set(), 90148: set()}
# {90144: set(), 90140: set(), 90142: set(), 90165: set(), 90147: set()}
# {90139: set(), 90146: set(), 90166: set(), 90148: set(), 90164: set()}
# {90754: set(), 90145: set(), 90166: set(), 90147: set(), 90163: set()}
# {90148: set(), 90164: set(), 90140: set(), 90139: set(), 90147: set()}
# {90148: set(), 90145: set(), 90163: set(), 90143: set(), 90146: set()}
# {90140: set(), 90144: set(), 90334: set(), 90147: set(), 90164: set()}
# {90147: {90143}, 90167: set(), 90754: set(), 90140: set(), 90143: {90147}}
# {90167: set(), 90144: set(), 90148: set(), 90145: set(), 90163: set()}
# {90166: set(), 90167: set(), 90139: {90145}, 90145: {90139}, 90163: set()}
# {90164: set(), 90166: set(), 90148: set(), 90163: set(), 90147: set()}
# {90142: set(), 90143: set(), 90148: set(), 90144: set(), 90145: set()}
# {90145: set(), 90163: set(), 90140: {90166}, 90144: set(), 90166: {90140}}
# {90147: set(), 90167: set(), 90144: set(), 90163: set(), 90334: set()}
# {90146: set(), 90334: set(), 90164: set(), 90140: set(), 90144: set()}
# {90147: set(), 90144: set(), 90142: set(), 90164: set(), 90166: set()}
# {90334: set(), 90148: set(), 90145: set(), 90144: set(), 90143: set()}
# {90148: set(), 90163: set(), 90140: set(), 90754: set(), 90139: set()}
# {90143: {90147}, 90144: set(), 90147: {90143}, 90167: set(), 90164: set()}
# {90142: set(), 90163: set(), 90167: set(), 90165: set(), 90334: set()}
# {90146: set(), 90334: set(), 90144: set(), 90143: set(), 90139: set()}
# {90143: set(), 90139: set(), 90167: set(), 90144: set(), 90334: set()}
# {90167: set(), 90142: set(), 90166: set(), 90143: set(), 90148: set()}
# {90165: set(), 90142: set(), 90147: set(), 90145: set(), 90146: set()}
# {90148: set(), 90754: set(), 90146: set(), 90165: set(), 90140: set()}
# {90139: set(), 90142: set(), 90140: set(), 90334: set(), 90167: set()}
# {90167: set(), 90143: {90147}, 90163: set(), 90146: set(), 90147: {90143}}
# {90142: set(), 90165: set(), 90147: set(), 90144: set(), 90163: set()}
# {90143: set(), 90140: {90166}, 90166: {90140}, 90144: set(), 90163: set()}
# {90140: {90166}, 90144: set(), 90166: {90140}, 90164: set(), 90754: set()}
# {90148: set(), 90147: set(), 90142: set(), 90164: set(), 90139: set()}
# {90163: set(), 90167: set(), 90148: set(), 90145: set(), 90164: set()}
# {90163: set(), 90148: set(), 90165: set(), 90754: set(), 90140: set()}
# {90167: set(), 90148: set(), 90166: set(), 90334: set(), 90147: set()}
# {90334: set(), 90165: set(), 90142: set(), 90163: set(), 90140: set()}
# {90163: set(), 90146: set(), 90145: set(), 90754: set(), 90165: set()}
# {90145: set(), 90148: set(), 90142: set(), 90146: set(), 90143: set()}
# {90148: set(), 90754: set(), 90142: set(), 90166: set(), 90334: set()}
# {90143: set(), 90166: set(), 90142: set(), 90754: set(), 90167: set()}
# {90167: set(), 90334: set(), 90144: set(), 90754: set(), 90166: set()}
# {90164: set(), 90166: set(), 90146: set(), 90754: set(), 90144: set()}
# {90143: set(), 90164: set(), 90163: set(), 90139: set(), 90148: set()}
# {90148: set(), 90754: set(), 90334: set(), 90167: set(), 90144: set()}
# {90146: set(), 90145: set(), 90164: set(), 90147: set(), 90334: set()}
# {90163: set(), 90334: set(), 90165: set(), 90145: set(), 90147: set()}
# {90334: set(), 90144: set(), 90143: set(), 90165: set(), 90146: set()}
# {90148: set(), 90166: set(), 90164: set(), 90754: set(), 90145: set()}
# {90144: set(), 90754: set(), 90165: set(), 90334: set(), 90146: set()}
# {90166: set(), 90144: set(), 90147: set(), 90148: set(), 90164: set()}
# {90139: set(), 90142: set(), 90166: set(), 90334: set(), 90163: set()}
# {90142: set(), 90165: set(), 90164: set(), 90166: set(), 90167: set()}
# {90140: set(), 90167: set(), 90142: set(), 90143: set(), 90163: set()}
# {90165: set(), 90148: set(), 90139: set(), 90334: set(), 90142: set()}
# {90166: {90140}, 90142: set(), 90167: set(), 90140: {90166}, 90144: set()}
# {90140: set(), 90334: set(), 90143: set(), 90148: set(), 90167: set()}
# {90142: set(), 90143: set(), 90163: set(), 90165: set(), 90334: set()}
# {90139: set(), 90334: set(), 90167: set(), 90754: set(), 90165: set()}
# {90754: set(), 90144: set(), 90145: set(), 90140: set(), 90147: set()}
# {90167: set(), 90142: set(), 90334: set(), 90144: set(), 90139: set()}
# {90334: set(), 90147: set(), 90145: set(), 90754: set(), 90146: set()}
# {90167: set(), 90144: set(), 90145: set(), 90163: set(), 90166: set()}
# {90754: set(), 90148: set(), 90163: set(), 90143: set(), 90139: set()}
# {90139: set(), 90144: set(), 90165: set(), 90163: set(), 90147: set()}
# {90145: set(), 90166: set(), 90144: set(), 90754: set(), 90143: set()}
# {90145: set(), 90164: set(), 90140: set(), 90146: set(), 90167: set()}
# {90144: set(), 90163: set(), 90754: set(), 90167: set(), 90164: set()}
# {90148: set(), 90145: {90139}, 90139: {90145}, 90163: set(), 90144: set()}
# {90142: set(), 90166: set(), 90143: set(), 90164: set(), 90165: set()}
# {90147: set(), 90165: set(), 90164: set(), 90140: set(), 90754: set()}
# {90167: set(), 90163: set(), 90164: set(), 90139: set(), 90334: set()}
# {90144: set(), 90148: set(), 90140: set(), 90139: set(), 90334: set()}
# {90147: {90143}, 90139: set(), 90334: set(), 90165: set(), 90143: {90147}}
# {90334: set(), 90145: {90139}, 90163: set(), 90143: set(), 90139: {90145}}
# {90754: set(), 90163: set(), 90147: set(), 90165: set(), 90146: set()}
# {90148: set(), 90144: set(), 90146: set(), 90143: set(), 90167: set()}
# {90145: set(), 90165: set(), 90142: set(), 90144: set(), 90148: set()}
# {90140: set(), 90754: set(), 90143: {90147}, 90147: {90143}, 90148: set()}
# {90164: set(), 90142: set(), 90140: set(), 90163: set(), 90145: set()}
# {90142: set(), 90163: set(), 90147: {90143}, 90164: set(), 90143: {90147}}
# {90140: {90166}, 90165: set(), 90166: {90140}, 90167: set(), 90146: set()}
# {90166: set(), 90142: set(), 90167: set(), 90334: set(), 90147: set()}
# {90148: set(), 90754: set(), 90146: set(), 90165: set(), 90164: set()}
# {90142: set(), 90163: set(), 90146: set(), 90143: set(), 90334: set()}
# {90165: set(), 90167: set(), 90754: set(), 90163: set(), 90334: set()}
# {90163: set(), 90166: {90140}, 90164: set(), 90754: set(), 90140: {90166}}
# {90754: set(), 90142: set(), 90139: set(), 90166: set(), 90334: set()}
# {90167: set(), 90147: {90143}, 90142: set(), 90140: set(), 90143: {90147}}
# {90144: set(), 90754: set(), 90148: set(), 90140: {90166}, 90166: {90140}}
# {90140: set(), 90148: set(), 90334: set(), 90142: set(), 90754: set()}
# {90147: {90143}, 90166: set(), 90143: {90147}, 90142: set(), 90167: set()}
# {90147: set(), 90140: {90166}, 90165: set(), 90754: set(), 90166: {90140}}
# {90165: set(), 90754: set(), 90145: set(), 90143: set(), 90167: set()}
# {90145: set(), 90142: set(), 90166: set(), 90147: set(), 90146: set()}
# {90140: set(), 90145: set(), 90163: set(), 90148: set(), 90146: set()}
# {90143: set(), 90167: set(), 90166: set(), 90144: set(), 90139: set()}
# {90140: {90166}, 90166: {90140}, 90142: set(), 90164: set(), 90139: set()}
# {90139: set(), 90140: set(), 90163: set(), 90754: set(), 90143: set()}
# {90334: set(), 90139: set(), 90148: set(), 90163: set(), 90147: set()}
# {90142: set(), 90139: {90145}, 90147: set(), 90145: {90139}, 90334: set()}
# {90167: set(), 90334: set(), 90165: set(), 90145: {90139}, 90139: {90145}}
# {90144: set(), 90164: set(), 90148: set(), 90163: set(), 90140: set()}
# {90147: set(), 90145: {90139}, 90754: set(), 90139: {90145}, 90334: set()}
# {90754: set(), 90166: set(), 90139: {90145}, 90143: set(), 90145: {90139}}
# {90754: set(), 90140: set(), 90164: set(), 90144: set(), 90334: set()}
# {90143: set(), 90164: set(), 90166: set(), 90145: set(), 90754: set()}
# {90146: set(), 90142: set(), 90145: set(), 90163: set(), 90165: set()}
# {90167: set(), 90166: set(), 90139: {90145}, 90164: set(), 90145: {90139}}
# {90144: set(), 90146: set(), 90140: set(), 90163: set(), 90165: set()}
# {90164: set(), 90166: set(), 90754: set(), 90146: set(), 90165: set()}
# {90144: set(), 90166: {90140}, 90163: set(), 90140: {90166}, 90145: set()}
# {90139: set(), 90148: set(), 90146: set(), 90167: set(), 90164: set()}
# {90142: set(), 90163: set(), 90754: set(), 90165: set(), 90143: set()}
# {90164: set(), 90145: set(), 90334: set(), 90146: set(), 90148: set()}
# {90334: set(), 90140: set(), 90142: set(), 90148: set(), 90144: set()}
# {90334: set(), 90164: set(), 90165: set(), 90146: set(), 90147: set()}
# {90147: set(), 90165: set(), 90145: set(), 90142: set(), 90167: set()}
# {90754: set(), 90164: set(), 90140: set(), 90142: set(), 90163: set()}
# {90334: set(), 90142: set(), 90145: set(), 90143: set(), 90164: set()}
# {90163: set(), 90166: set(), 90139: set(), 90146: set(), 90164: set()}
# {90147: set(), 90145: set(), 90142: set(), 90334: set(), 90144: set()}
# {90145: set(), 90163: set(), 90165: set(), 90334: set(), 90148: set()}
# {90167: set(), 90142: set(), 90165: set(), 90163: set(), 90166: set()}
# {90754: set(), 90147: set(), 90165: set(), 90145: set(), 90163: set()}
# {90140: set(), 90167: set(), 90334: set(), 90147: set(), 90754: set()}
# {90147: set(), 90167: set(), 90144: set(), 90145: set(), 90163: set()}
# {90164: set(), 90147: set(), 90167: set(), 90146: set(), 90165: set()}
# {90139: set(), 90148: set(), 90165: set(), 90147: {90143}, 90143: {90147}}
# {90147: set(), 90166: set(), 90145: set(), 90142: set(), 90144: set()}
# {90754: set(), 90167: set(), 90164: set(), 90144: set(), 90145: set()}
# {90139: {90145}, 90163: set(), 90164: set(), 90145: {90139}, 90167: set()}
# {90142: set(), 90163: set(), 90139: set(), 90146: set(), 90148: set()}
# {90167: set(), 90163: set(), 90147: set(), 90139: set(), 90164: set()}
# {90166: set(), 90163: set(), 90145: set(), 90167: set(), 90144: set()}
# {90140: {90166}, 90166: {90140}, 90145: set(), 90164: set(), 90146: set()}
# {90142: set(), 90334: set(), 90148: set(), 90140: set(), 90167: set()}
# {90166: set(), 90165: set(), 90754: set(), 90334: set(), 90142: set()}
# {90139: set(), 90144: set(), 90164: set(), 90140: set(), 90142: set()}
# {90146: set(), 90167: set(), 90163: set(), 90334: set(), 90166: set()}
# {90165: set(), 90145: set(), 90754: set(), 90142: set(), 90164: set()}
# {90164: set(), 90144: set(), 90334: set(), 90146: set(), 90163: set()}
# {90144: set(), 90334: set(), 90166: set(), 90163: set(), 90167: set()}
# {90148: set(), 90754: set(), 90164: set(), 90146: set(), 90147: set()}
# {90140: set(), 90146: set(), 90143: set(), 90148: set(), 90334: set()}
# {90164: set(), 90146: set(), 90143: {90147}, 90145: set(), 90147: {90143}}
# {90145: set(), 90140: set(), 90163: set(), 90334: set(), 90167: set()}
# {90164: set(), 90145: {90139}, 90139: {90145}, 90754: set(), 90163: set()}
# {90163: set(), 90754: set(), 90167: set(), 90166: set(), 90165: set()}
# {90144: set(), 90167: set(), 90165: set(), 90163: set(), 90140: set()}
# {90139: set(), 90148: set(), 90147: set(), 90140: set(), 90163: set()}
# {90139: set(), 90142: set(), 90144: set(), 90166: set(), 90334: set()}
# {90167: set(), 90139: set(), 90166: {90140}, 90140: {90166}, 90142: set()}
# {90146: set(), 90143: set(), 90754: set(), 90167: set(), 90163: set()}
# {90146: set(), 90165: set(), 90167: set(), 90163: set(), 90148: set()}
# {90145: set(), 90163: set(), 90140: set(), 90142: set(), 90148: set()}
# {90166: set(), 90145: {90139}, 90146: set(), 90142: set(), 90139: {90145}}
# {90165: set(), 90147: set(), 90142: set(), 90144: set(), 90166: set()}
# {90139: set(), 90140: set(), 90754: set(), 90148: set(), 90144: set()}
# {90146: set(), 90163: set(), 90139: set(), 90142: set(), 90144: set()}
# {90144: set(), 90334: set(), 90146: set(), 90163: set(), 90142: set()}
# {90148: set(), 90334: set(), 90166: set(), 90165: set(), 90143: set()}
# {90139: set(), 90143: set(), 90146: set(), 90142: set(), 90167: set()}
# {90146: set(), 90165: set(), 90142: set(), 90144: set(), 90143: set()}
# {90146: set(), 90148: set(), 90165: set(), 90147: set(), 90164: set()}
# {90144: set(), 90166: set(), 90164: set(), 90145: set(), 90165: set()}
# {90148: set(), 90334: set(), 90145: set(), 90147: set(), 90165: set()}
# {90146: set(), 90334: set(), 90139: set(), 90144: set(), 90142: set()}
# {90142: set(), 90334: set(), 90145: {90139}, 90140: set(), 90139: {90145}}
# {90754: set(), 90139: set(), 90140: set(), 90147: set(), 90334: set()}
# {90145: set(), 90167: set(), 90142: set(), 90165: set(), 90147: set()}
# {90334: set(), 90164: set(), 90143: set(), 90139: set(), 90144: set()}
# {90167: set(), 90142: set(), 90165: set(), 90147: set(), 90140: set()}
# {90145: set(), 90165: set(), 90167: set(), 90754: set(), 90144: set()}
# {90140: set(), 90145: set(), 90167: set(), 90164: set(), 90142: set()}
# {90146: set(), 90144: set(), 90140: set(), 90165: set(), 90163: set()}
# {90147: set(), 90166: set(), 90148: set(), 90144: set(), 90142: set()}
# {90334: set(), 90145: set(), 90143: set(), 90144: set(), 90165: set()}
# {90139: {90145}, 90143: set(), 90164: set(), 90163: set(), 90145: {90139}}
# {90334: set(), 90144: set(), 90147: set(), 90166: {90140}, 90140: {90166}}
# {90144: set(), 90334: set(), 90165: set(), 90166: set(), 90142: set()}
# {90140: set(), 90144: set(), 90145: {90139}, 90139: {90145}, 90143: set()}
# {90146: set(), 90142: set(), 90163: set(), 90165: set(), 90147: set()}
# {90142: set(), 90139: set(), 90147: set(), 90754: set(), 90163: set()}
# {90165: set(), 90142: set(), 90166: set(), 90145: set(), 90754: set()}
# {90145: set(), 90140: set(), 90146: set(), 90165: set(), 90148: set()}
# {90164: set(), 90166: set(), 90142: set(), 90139: set(), 90146: set()}
# {90145: {90139}, 90165: set(), 90146: set(), 90754: set(), 90139: {90145}}
# {90143: set(), 90144: set(), 90148: set(), 90754: set(), 90139: set()}
# {90148: set(), 90147: set(), 90142: set(), 90165: set(), 90164: set()}
# {90145: set(), 90166: set(), 90148: set(), 90163: set(), 90142: set()}
# {90148: set(), 90146: set(), 90145: set(), 90140: set(), 90754: set()}
# {90146: set(), 90754: set(), 90148: set(), 90139: set(), 90167: set()}
# {90163: set(), 90147: set(), 90144: set(), 90164: set(), 90334: set()}
# {90147: set(), 90142: set(), 90139: set(), 90165: set(), 90163: set()}
# {90143: set(), 90145: set(), 90754: set(), 90142: set(), 90144: set()}
# {90145: set(), 90148: set(), 90334: set(), 90142: set(), 90143: set()}
# {90165: set(), 90145: set(), 90166: set(), 90167: set(), 90334: set()}
# {90147: {90143}, 90334: set(), 90143: {90147}, 90146: set(), 90148: set()}
# {90140: set(), 90139: set(), 90167: set(), 90754: set(), 90148: set()}
# {90139: set(), 90142: set(), 90143: set(), 90163: set(), 90167: set()}
# {90165: set(), 90145: set(), 90164: set(), 90166: set(), 90144: set()}
# {90163: set(), 90146: set(), 90140: set(), 90165: set(), 90144: set()}
# {90144: set(), 90166: set(), 90142: set(), 90334: set(), 90146: set()}
# {90147: set(), 90167: set(), 90334: set(), 90163: set(), 90164: set()}
# {90146: set(), 90148: set(), 90167: set(), 90144: set(), 90754: set()}
# {90754: set(), 90334: set(), 90166: set(), 90164: set(), 90144: set()}
# {90165: set(), 90142: set(), 90147: set(), 90167: set(), 90166: set()}
# {90165: set(), 90146: set(), 90143: set(), 90148: set(), 90140: set()}
# {90334: set(), 90166: set(), 90165: set(), 90167: set(), 90144: set()}
# {90166: set(), 90148: set(), 90139: set(), 90167: set(), 90142: set()}
# {90334: set(), 90163: set(), 90145: set(), 90754: set(), 90164: set()}
# {90147: {90143}, 90139: set(), 90754: set(), 90143: {90147}, 90142: set()}
# {90166: set(), 90167: set(), 90147: set(), 90146: set(), 90164: set()}
# {90143: set(), 90144: set(), 90145: set(), 90166: set(), 90163: set()}
# {90166: set(), 90139: set(), 90147: set(), 90167: set(), 90146: set()}
# {90143: set(), 90165: set(), 90139: set(), 90164: set(), 90754: set()}
# {90164: set(), 90139: set(), 90163: set(), 90166: set(), 90334: set()}
# {90148: set(), 90140: set(), 90146: set(), 90139: set(), 90334: set()}
# {90142: set(), 90145: set(), 90140: set(), 90146: set(), 90148: set()}
# {90146: set(), 90140: set(), 90139: set(), 90164: set(), 90165: set()}
# {90145: set(), 90754: set(), 90140: set(), 90165: set(), 90167: set()}
# {90142: set(), 90139: set(), 90164: set(), 90148: set(), 90167: set()}
# {90140: set(), 90144: set(), 90146: set(), 90147: set(), 90334: set()}
# {90163: set(), 90140: {90166}, 90145: set(), 90143: set(), 90166: {90140}}
# {90140: set(), 90167: set(), 90754: set(), 90142: set(), 90144: set()}
# {90167: set(), 90145: set(), 90143: set(), 90142: set(), 90166: set()}
# {90139: {90145}, 90754: set(), 90145: {90139}, 90165: set(), 90142: set()}
# {90148: set(), 90165: set(), 90167: set(), 90166: set(), 90146: set()}
# {90144: set(), 90164: set(), 90163: set(), 90334: set(), 90147: set()}
# {90163: set(), 90754: set(), 90166: set(), 90334: set(), 90165: set()}
# {90144: set(), 90148: set(), 90754: set(), 90163: set(), 90166: set()}
# {90165: set(), 90166: {90140}, 90163: set(), 90148: set(), 90140: {90166}}
# {90148: set(), 90146: set(), 90142: set(), 90163: set(), 90143: set()}
# {90142: set(), 90164: set(), 90166: set(), 90145: set(), 90146: set()}
# {90145: {90139}, 90164: set(), 90143: {90147}, 90147: {90143}, 90139: {90145}}
# {90166: set(), 90143: set(), 90145: set(), 90144: set(), 90148: set()}
# {90143: {90147}, 90140: set(), 90146: set(), 90145: set(), 90147: {90143}}
# {90142: set(), 90754: set(), 90140: set(), 90334: set(), 90143: set()}
# {90754: set(), 90167: set(), 90142: set(), 90148: set(), 90144: set()}
# {90147: {90143}, 90148: set(), 90143: {90147}, 90146: set(), 90165: set()}
# {90165: set(), 90144: set(), 90334: set(), 90142: set(), 90148: set()}
# {90163: set(), 90164: set(), 90144: set(), 90334: set(), 90148: set()}
# {90163: set(), 90754: set(), 90334: set(), 90148: set(), 90143: set()}
# {90163: set(), 90139: set(), 90754: set(), 90142: set(), 90334: set()}
# {90146: set(), 90148: set(), 90334: set(), 90165: set(), 90166: set()}
# {90139: set(), 90166: set(), 90147: set(), 90164: set(), 90334: set()}
# {90754: set(), 90164: set(), 90139: set(), 90147: set(), 90334: set()}
# {90142: set(), 90144: set(), 90146: set(), 90334: set(), 90163: set()}
# {90140: set(), 90144: set(), 90145: set(), 90754: set(), 90148: set()}
# {90164: set(), 90147: set(), 90165: set(), 90167: set(), 90166: set()}
# {90166: set(), 90754: set(), 90142: set(), 90144: set(), 90148: set()}
# {90165: set(), 90754: set(), 90146: set(), 90142: set(), 90164: set()}
# {90165: set(), 90142: set(), 90164: set(), 90163: set(), 90148: set()}
# {90139: {90145}, 90140: set(), 90164: set(), 90145: {90139}, 90146: set()}
# {90163: set(), 90166: {90140}, 90140: {90166}, 90165: set(), 90167: set()}
# {90163: set(), 90167: set(), 90147: set(), 90146: set(), 90166: set()}
# {90163: set(), 90147: {90143}, 90334: set(), 90165: set(), 90143: {90147}}
# {90334: set(), 90142: set(), 90145: set(), 90146: set(), 90148: set()}
# {90754: set(), 90145: {90139}, 90166: set(), 90147: set(), 90139: {90145}}
# {90165: set(), 90754: set(), 90145: set(), 90334: set(), 90144: set()}
# {90334: set(), 90148: set(), 90142: set(), 90166: set(), 90146: set()}
# {90145: set(), 90143: set(), 90166: set(), 90334: set(), 90144: set()}
# {90148: set(), 90142: set(), 90164: set(), 90143: {90147}, 90147: {90143}}
# {90164: set(), 90145: set(), 90143: set(), 90754: set(), 90167: set()}
# {90334: set(), 90146: set(), 90140: set(), 90143: set(), 90145: set()}
# {90165: set(), 90139: set(), 90144: set(), 90140: set(), 90142: set()}
# {90144: set(), 90145: set(), 90334: set(), 90142: set(), 90143: set()}
# {90140: set(), 90334: set(), 90139: set(), 90165: set(), 90147: set()}
# {90144: set(), 90754: set(), 90140: set(), 90164: set(), 90143: set()}
# {90146: set(), 90144: set(), 90139: set(), 90167: set(), 90164: set()}
# {90163: set(), 90140: set(), 90145: set(), 90144: set(), 90167: set()}
# {90145: set(), 90143: set(), 90164: set(), 90163: set(), 90167: set()}
# {90146: set(), 90143: {90147}, 90144: set(), 90145: set(), 90147: {90143}}
# {90165: set(), 90167: set(), 90145: set(), 90142: set(), 90147: set()}
# {90165: set(), 90145: set(), 90164: set(), 90146: set(), 90167: set()}
# {90165: set(), 90139: set(), 90146: set(), 90143: set(), 90166: set()}
# {90146: set(), 90143: set(), 90145: set(), 90142: set(), 90140: set()}
# {90148: set(), 90166: set(), 90167: set(), 90163: set(), 90147: set()}
# {90167: set(), 90145: set(), 90142: set(), 90143: set(), 90163: set()}
# {90143: set(), 90166: set(), 90142: set(), 90139: set(), 90334: set()}
# {90754: set(), 90148: set(), 90144: set(), 90164: set(), 90143: set()}
# {90163: set(), 90334: set(), 90167: set(), 90143: set(), 90148: set()}
# {90146: set(), 90167: set(), 90142: set(), 90147: set(), 90164: set()}
# {90163: set(), 90146: set(), 90148: set(), 90142: set(), 90334: set()}
# {90139: set(), 90163: set(), 90147: set(), 90334: set(), 90167: set()}
# {90167: set(), 90145: set(), 90147: set(), 90140: set(), 90334: set()}
# {90166: set(), 90147: set(), 90163: set(), 90145: set(), 90142: set()}
# {90145: set(), 90147: set(), 90146: set(), 90163: set(), 90140: set()}
# {90146: set(), 90144: set(), 90163: set(), 90164: set(), 90148: set()}
# {90146: set(), 90754: set(), 90163: set(), 90140: {90166}, 90166: {90140}}
# {90139: set(), 90167: set(), 90142: set(), 90754: set(), 90144: set()}
# {90146: set(), 90139: {90145}, 90163: set(), 90754: set(), 90145: {90139}}
# {90148: set(), 90146: set(), 90143: set(), 90167: set(), 90163: set()}
# {90145: {90139}, 90164: set(), 90139: {90145}, 90140: set(), 90167: set()}
# {90165: set(), 90163: set(), 90167: set(), 90140: set(), 90147: set()}
# {90165: set(), 90334: set(), 90142: set(), 90148: set(), 90143: set()}
# {90143: {90147}, 90142: set(), 90147: {90143}, 90166: {90140}, 90140: {90166}}
# {90139: set(), 90144: set(), 90165: set(), 90166: {90140}, 90140: {90166}}
# {90167: set(), 90163: set(), 90754: set(), 90142: set(), 90140: set()}
# {90163: set(), 90166: set(), 90754: set(), 90142: set(), 90144: set()}
# {90145: set(), 90166: set(), 90164: set(), 90167: set(), 90754: set()}
# {90140: set(), 90165: set(), 90754: set(), 90145: set(), 90144: set()}
# {90148: set(), 90166: {90140}, 90167: set(), 90140: {90166}, 90143: set()}
# {90167: set(), 90163: set(), 90166: set(), 90142: set(), 90164: set()}
# {90139: set(), 90140: {90166}, 90165: set(), 90146: set(), 90166: {90140}}
# {90334: set(), 90140: set(), 90143: {90147}, 90147: {90143}, 90146: set()}
# {90334: set(), 90164: set(), 90146: set(), 90165: set(), 90139: set()}
# {90754: set(), 90164: set(), 90143: set(), 90146: set(), 90142: set()}
# {90334: set(), 90140: set(), 90147: set(), 90754: set(), 90165: set()}
# {90146: set(), 90164: set(), 90145: set(), 90144: set(), 90143: set()}
# {90167: set(), 90142: set(), 90163: set(), 90146: set(), 90754: set()}
# {90754: set(), 90143: set(), 90142: set(), 90163: set(), 90167: set()}
# {90147: set(), 90146: set(), 90334: set(), 90163: set(), 90165: set()}
# {90334: set(), 90140: set(), 90754: set(), 90144: set(), 90167: set()}
# {90166: set(), 90164: set(), 90163: set(), 90145: set(), 90165: set()}
# {90147: set(), 90166: set(), 90165: set(), 90163: set(), 90164: set()}
# {90142: set(), 90166: set(), 90164: set(), 90139: set(), 90334: set()}
# {90143: {90147}, 90334: set(), 90144: set(), 90140: set(), 90147: {90143}}
# {90144: set(), 90143: {90147}, 90165: set(), 90147: {90143}, 90139: set()}
# {90165: set(), 90146: set(), 90143: set(), 90164: set(), 90145: set()}
# {90139: set(), 90754: set(), 90148: set(), 90147: {90143}, 90143: {90147}}
# {90143: {90147}, 90167: set(), 90145: set(), 90163: set(), 90147: {90143}}
# {90147: set(), 90164: set(), 90165: set(), 90144: set(), 90163: set()}
# {90166: {90140}, 90754: set(), 90164: set(), 90139: set(), 90140: {90166}}
# {90140: set(), 90143: set(), 90148: set(), 90754: set(), 90167: set()}
# {90147: {90143}, 90167: set(), 90165: set(), 90143: {90147}, 90164: set()}
# {90165: set(), 90143: set(), 90334: set(), 90164: set(), 90163: set()}
# {90165: set(), 90146: set(), 90140: {90166}, 90166: {90140}, 90142: set()}
# {90145: set(), 90163: set(), 90146: set(), 90140: set(), 90148: set()}
# {90140: set(), 90143: set(), 90754: set(), 90165: set(), 90145: set()}
# {90147: set(), 90142: set(), 90166: set(), 90165: set(), 90167: set()}
# {90165: set(), 90145: set(), 90143: set(), 90144: set(), 90167: set()}
# {90147: set(), 90754: set(), 90163: set(), 90145: set(), 90334: set()}
# {90148: set(), 90143: {90147}, 90147: {90143}, 90145: set(), 90754: set()}
# {90140: set(), 90143: {90147}, 90754: set(), 90145: set(), 90147: {90143}}
# {90146: set(), 90147: {90143}, 90143: {90147}, 90139: set(), 90148: set()}
# {90167: set(), 90148: set(), 90166: {90140}, 90140: {90166}, 90163: set()}
# {90147: set(), 90139: set(), 90334: set(), 90166: set(), 90144: set()}
# {90142: set(), 90144: set(), 90139: set(), 90166: {90140}, 90140: {90166}}
# {90334: set(), 90166: {90140}, 90140: {90166}, 90147: set(), 90142: set()}
# {90165: set(), 90140: set(), 90142: set(), 90146: set(), 90163: set()}
# {90144: set(), 90334: set(), 90145: set(), 90163: set(), 90142: set()}
# {90144: set(), 90334: set(), 90145: set(), 90143: set(), 90142: set()}
# {90334: set(), 90143: {90147}, 90754: set(), 90147: {90143}, 90163: set()}
# {90165: set(), 90144: set(), 90166: set(), 90145: set(), 90164: set()}
# {90139: set(), 90164: set(), 90165: set(), 90166: {90140}, 90140: {90166}}
# {90146: set(), 90139: set(), 90148: set(), 90142: set(), 90167: set()}
# {90165: set(), 90166: set(), 90139: {90145}, 90144: set(), 90145: {90139}}
# {90164: set(), 90147: set(), 90144: set(), 90142: set(), 90163: set()}
# {90148: set(), 90165: set(), 90144: set(), 90143: {90147}, 90147: {90143}}
# {90139: set(), 90164: set(), 90143: {90147}, 90140: set(), 90147: {90143}}
# {90754: set(), 90167: set(), 90139: {90145}, 90145: {90139}, 90334: set()}
# {90146: set(), 90148: set(), 90165: set(), 90334: set(), 90139: set()}
# {90146: set(), 90754: set(), 90144: set(), 90148: set(), 90143: set()}
# {90165: set(), 90166: set(), 90167: set(), 90143: set(), 90334: set()}
# {90165: set(), 90140: set(), 90148: set(), 90167: set(), 90164: set()}
# {90145: set(), 90166: {90140}, 90167: set(), 90165: set(), 90140: {90166}}
# {90143: set(), 90167: set(), 90139: {90145}, 90145: {90139}, 90163: set()}
# {90145: {90139}, 90167: set(), 90164: set(), 90139: {90145}, 90146: set()}
# {90164: set(), 90334: set(), 90163: set(), 90147: set(), 90145: set()}
# {90145: set(), 90142: set(), 90167: set(), 90163: set(), 90148: set()}
# {90163: set(), 90165: set(), 90754: set(), 90147: set(), 90146: set()}
# {90147: set(), 90167: set(), 90166: set(), 90146: set(), 90145: set()}
# {90334: set(), 90145: set(), 90140: set(), 90164: set(), 90754: set()}
# {90143: set(), 90166: set(), 90139: set(), 90144: set(), 90142: set()}
# {90146: set(), 90163: set(), 90140: set(), 90143: set(), 90164: set()}
# {90165: set(), 90167: set(), 90147: set(), 90164: set(), 90146: set()}
# {90144: set(), 90146: set(), 90166: set(), 90143: set(), 90142: set()}
# {90163: set(), 90145: set(), 90147: set(), 90146: set(), 90165: set()}
# {90163: set(), 90147: set(), 90164: set(), 90334: set(), 90167: set()}
# {90140: set(), 90164: set(), 90144: set(), 90754: set(), 90334: set()}
# {90334: set(), 90140: set(), 90754: set(), 90144: set(), 90139: set()}
# {90142: set(), 90143: set(), 90334: set(), 90148: set(), 90144: set()}
# {90334: set(), 90754: set(), 90146: set(), 90145: set(), 90140: set()}
# {90139: {90145}, 90145: {90139}, 90165: set(), 90143: set(), 90167: set()}
# {90334: set(), 90144: set(), 90165: set(), 90754: set(), 90164: set()}
# {90139: set(), 90165: set(), 90167: set(), 90143: set(), 90140: set()}
# {90145: set(), 90166: set(), 90164: set(), 90144: set(), 90163: set()}
# {90143: set(), 90148: set(), 90139: set(), 90754: set(), 90163: set()}
# {90167: set(), 90145: set(), 90164: set(), 90334: set(), 90147: set()}
# {90334: set(), 90140: set(), 90165: set(), 90145: set(), 90144: set()}
# {90139: set(), 90165: set(), 90146: set(), 90164: set(), 90142: set()}
# {90163: set(), 90140: {90166}, 90147: {90143}, 90143: {90147}, 90166: {90140}}
# {90145: {90139}, 90163: set(), 90334: set(), 90139: {90145}, 90165: set()}
# {90147: set(), 90165: set(), 90334: set(), 90148: set(), 90754: set()}
# {90143: set(), 90163: set(), 90164: set(), 90140: set(), 90144: set()}
# {90142: set(), 90139: set(), 90143: {90147}, 90164: set(), 90147: {90143}}
# {90145: set(), 90163: set(), 90142: set(), 90144: set(), 90147: set()}
# {90148: set(), 90143: set(), 90166: set(), 90165: set(), 90145: set()}
# {90165: set(), 90140: set(), 90163: set(), 90147: set(), 90754: set()}
# {90334: set(), 90139: set(), 90163: set(), 90165: set(), 90148: set()}
# {90163: set(), 90142: set(), 90148: set(), 90164: set(), 90144: set()}
# {90167: set(), 90754: set(), 90144: set(), 90148: set(), 90147: set()}
# {90145: {90139}, 90165: set(), 90163: set(), 90166: set(), 90139: {90145}}
# {90167: set(), 90163: set(), 90145: {90139}, 90139: {90145}, 90164: set()}
# {90334: set(), 90139: set(), 90148: set(), 90142: set(), 90143: set()}
# {90166: set(), 90163: set(), 90147: set(), 90145: set(), 90142: set()}
# {90167: set(), 90140: set(), 90148: set(), 90144: set(), 90754: set()}
# {90164: set(), 90754: set(), 90148: set(), 90145: set(), 90140: set()}
# {90166: set(), 90164: set(), 90147: set(), 90139: set(), 90754: set()}
# {90754: set(), 90139: set(), 90167: set(), 90334: set(), 90164: set()}
# {90144: set(), 90146: set(), 90164: set(), 90142: set(), 90166: set()}
# {90144: set(), 90166: set(), 90167: set(), 90142: set(), 90164: set()}
# {90754: set(), 90146: set(), 90143: set(), 90163: set(), 90145: set()}
# {90142: set(), 90148: set(), 90754: set(), 90140: set(), 90139: set()}
# {90148: set(), 90145: set(), 90163: set(), 90334: set(), 90143: set()}
# {90334: set(), 90165: set(), 90144: set(), 90143: set(), 90163: set()}
# {90164: set(), 90145: {90139}, 90139: {90145}, 90146: set(), 90166: set()}
# {90146: set(), 90148: set(), 90754: set(), 90147: set(), 90164: set()}
# {90147: set(), 90163: set(), 90144: set(), 90140: set(), 90139: set()}
# {90147: set(), 90145: {90139}, 90139: {90145}, 90334: set(), 90144: set()}
# {90334: set(), 90144: set(), 90164: set(), 90166: set(), 90147: set()}
# {90146: set(), 90334: set(), 90143: set(), 90144: set(), 90148: set()}
# {90145: set(), 90143: set(), 90142: set(), 90164: set(), 90167: set()}
# {90139: {90145}, 90146: set(), 90145: {90139}, 90140: set(), 90143: set()}
# {90164: set(), 90163: set(), 90143: set(), 90144: set(), 90148: set()}
# {90148: set(), 90147: set(), 90144: set(), 90139: set(), 90166: set()}
# {90140: {90166}, 90144: set(), 90148: set(), 90166: {90140}, 90146: set()}
# {90147: {90143}, 90145: set(), 90143: {90147}, 90163: set(), 90334: set()}
# {90147: set(), 90140: {90166}, 90145: set(), 90164: set(), 90166: {90140}}
# {90163: set(), 90142: set(), 90148: set(), 90754: set(), 90146: set()}
# {90754: set(), 90145: set(), 90164: set(), 90140: set(), 90142: set()}
# {90163: set(), 90147: set(), 90166: set(), 90142: set(), 90144: set()}
# {90163: set(), 90144: set(), 90334: set(), 90165: set(), 90164: set()}
# {90144: set(), 90146: set(), 90334: set(), 90165: set(), 90148: set()}
# {90139: set(), 90163: set(), 90166: set(), 90144: set(), 90167: set()}
# {90139: set(), 90146: set(), 90163: set(), 90147: set(), 90165: set()}
# {90143: set(), 90145: set(), 90140: set(), 90144: set(), 90167: set()}
# {90163: set(), 90754: set(), 90166: {90140}, 90140: {90166}, 90147: set()}
# {90166: set(), 90147: set(), 90145: set(), 90144: set(), 90164: set()}
# {90754: set(), 90140: set(), 90163: set(), 90143: {90147}, 90147: {90143}}
# {90163: set(), 90144: set(), 90165: set(), 90167: set(), 90334: set()}
# {90334: set(), 90166: set(), 90145: set(), 90144: set(), 90164: set()}
# {90164: set(), 90144: set(), 90143: set(), 90167: set(), 90754: set()}
# {90147: {90143}, 90167: set(), 90143: {90147}, 90164: set(), 90163: set()}
# {90148: set(), 90163: set(), 90754: set(), 90144: set(), 90164: set()}
# {90163: set(), 90139: set(), 90166: set(), 90142: set(), 90148: set()}
# {90139: set(), 90164: set(), 90163: set(), 90143: set(), 90166: set()}
# {90144: set(), 90754: set(), 90142: set(), 90164: set(), 90139: set()}
# {90164: set(), 90140: {90166}, 90163: set(), 90754: set(), 90166: {90140}}
# {90148: set(), 90754: set(), 90145: set(), 90142: set(), 90166: set()}
# {90147: set(), 90167: set(), 90144: set(), 90163: set(), 90334: set()}
# {90144: set(), 90164: set(), 90143: set(), 90142: set(), 90145: set()}
# {90144: set(), 90163: set(), 90145: {90139}, 90164: set(), 90139: {90145}}
# {90146: set(), 90145: {90139}, 90140: set(), 90139: {90145}, 90144: set()}
# {90164: set(), 90147: set(), 90142: set(), 90163: set(), 90139: set()}
# {90146: set(), 90163: set(), 90142: set(), 90166: set(), 90165: set()}
# {90148: set(), 90144: set(), 90145: set(), 90163: set(), 90146: set()}
# {90164: set(), 90148: set(), 90147: set(), 90165: set(), 90146: set()}
# {90145: set(), 90164: set(), 90144: set(), 90147: set(), 90142: set()}
# {90143: set(), 90145: set(), 90163: set(), 90165: set(), 90166: set()}
# {90147: {90143}, 90334: set(), 90754: set(), 90165: set(), 90143: {90147}}
# {90754: set(), 90146: set(), 90165: set(), 90334: set(), 90145: set()}
# {90334: set(), 90140: set(), 90145: set(), 90167: set(), 90164: set()}
# {90163: set(), 90146: set(), 90164: set(), 90145: set(), 90143: set()}
# {90167: set(), 90144: set(), 90145: {90139}, 90166: set(), 90139: {90145}}
# {90143: set(), 90334: set(), 90145: {90139}, 90139: {90145}, 90167: set()}
# {90147: set(), 90165: set(), 90146: set(), 90144: set(), 90145: set()}
# {90163: set(), 90144: set(), 90148: set(), 90164: set(), 90146: set()}
# {90140: set(), 90754: set(), 90147: set(), 90144: set(), 90163: set()}
# {90164: set(), 90145: set(), 90167: set(), 90147: set(), 90140: set()}
# {90334: set(), 90754: set(), 90165: set(), 90147: set(), 90146: set()}
# {90148: set(), 90139: set(), 90754: set(), 90142: set(), 90144: set()}
# {90166: {90140}, 90164: set(), 90142: set(), 90140: {90166}, 90144: set()}
# {90163: set(), 90146: set(), 90166: {90140}, 90140: {90166}, 90147: set()}
# {90139: set(), 90754: set(), 90167: set(), 90147: set(), 90146: set()}
# {90144: set(), 90146: set(), 90167: set(), 90142: set(), 90166: set()}
# {90140: set(), 90139: set(), 90146: set(), 90148: set(), 90754: set()}
# {90142: set(), 90754: set(), 90140: set(), 90143: set(), 90146: set()}
# {90146: set(), 90140: {90166}, 90167: set(), 90334: set(), 90166: {90140}}
# {90164: set(), 90140: set(), 90142: set(), 90144: set(), 90145: set()}
# {90754: set(), 90164: set(), 90148: set(), 90143: set(), 90166: set()}
# {90166: set(), 90146: set(), 90144: set(), 90163: set(), 90143: set()}
# {90139: set(), 90143: set(), 90142: set(), 90167: set(), 90144: set()}
# {90140: set(), 90148: set(), 90334: set(), 90165: set(), 90164: set()}
# {90146: set(), 90334: set(), 90139: set(), 90163: set(), 90165: set()}
# {90165: set(), 90145: set(), 90140: {90166}, 90167: set(), 90166: {90140}}
# {90754: set(), 90167: set(), 90140: set(), 90143: set(), 90144: set()}
# {90164: set(), 90754: set(), 90148: set(), 90142: set(), 90143: set()}
# {90166: set(), 90163: set(), 90146: set(), 90144: set(), 90754: set()}
# {90142: set(), 90166: set(), 90143: set(), 90145: set(), 90163: set()}
# {90147: {90143}, 90143: {90147}, 90164: set(), 90144: set(), 90166: set()}
# {90164: set(), 90142: set(), 90165: set(), 90143: set(), 90754: set()}
# {90167: set(), 90754: set(), 90147: set(), 90144: set(), 90165: set()}
# {90166: {90140}, 90140: {90166}, 90143: set(), 90139: set(), 90144: set()}
# {90146: set(), 90140: set(), 90148: set(), 90164: set(), 90334: set()}
# {90143: set(), 90163: set(), 90144: set(), 90167: set(), 90145: set()}
# {90147: {90143}, 90166: set(), 90139: set(), 90143: {90147}, 90148: set()}
# {90140: set(), 90139: {90145}, 90754: set(), 90145: {90139}, 90334: set()}
# {90139: set(), 90167: set(), 90143: set(), 90148: set(), 90166: set()}
# {90163: set(), 90164: set(), 90143: set(), 90142: set(), 90144: set()}
# {90148: set(), 90167: set(), 90147: set(), 90144: set(), 90165: set()}
# {90164: set(), 90166: set(), 90145: {90139}, 90139: {90145}, 90143: set()}
# {90144: set(), 90164: set(), 90167: set(), 90139: set(), 90166: set()}
# {90334: set(), 90143: set(), 90148: set(), 90165: set(), 90144: set()}
# {90163: set(), 90145: {90139}, 90143: set(), 90144: set(), 90139: {90145}}
# {90147: set(), 90334: set(), 90167: set(), 90754: set(), 90139: set()}
# {90140: {90166}, 90166: {90140}, 90165: set(), 90145: set(), 90142: set()}
# {90167: set(), 90754: set(), 90334: set(), 90166: set(), 90165: set()}
# {90139: {90145}, 90166: set(), 90145: {90139}, 90146: set(), 90164: set()}
# {90142: set(), 90164: set(), 90163: set(), 90334: set(), 90167: set()}
# {90754: set(), 90139: {90145}, 90144: set(), 90147: set(), 90145: {90139}}
# {90166: set(), 90164: set(), 90146: set(), 90165: set(), 90163: set()}
# {90145: set(), 90142: set(), 90148: set(), 90164: set(), 90334: set()}
# {90166: set(), 90163: set(), 90754: set(), 90146: set(), 90143: set()}
# {90145: set(), 90146: set(), 90165: set(), 90164: set(), 90166: set()}
# {90143: set(), 90139: set(), 90140: set(), 90144: set(), 90754: set()}
# {90139: set(), 90334: set(), 90143: {90147}, 90164: set(), 90147: {90143}}
# {90166: set(), 90148: set(), 90144: set(), 90147: set(), 90165: set()}
# {90164: set(), 90163: set(), 90147: {90143}, 90145: set(), 90143: {90147}}
# {90140: set(), 90164: set(), 90144: set(), 90163: set(), 90165: set()}
# {90147: set(), 90164: set(), 90167: set(), 90165: set(), 90334: set()}
# {90164: set(), 90334: set(), 90163: set(), 90144: set(), 90142: set()}
# ...
# {90166: set(), 90167: set(), 90145: set(), 90144: set(), 90148: set()}
# {90139: set(), 90334: set(), 90165: set(), 90144: set(), 90167: set()}
# {90144: set(), 90165: set(), 90143: set(), 90754: set(), 90334: set()}
# {90147: set(), 90144: set(), 90167: set(), 90164: set(), 90140: set()}
# {90166: set(), 90147: set(), 90145: {90139}, 90139: {90145}, 90148: set()}
# {90139: {90145}, 90146: set(), 90145: {90139}, 90334: set(), 90166: set()}
# {90754: set(), 90143: set(), 90145: set(), 90167: set(), 90144: set()}
# {90142: set(), 90145: set(), 90146: set(), 90143: set(), 90140: set()}
# {90143: {90147}, 90147: {90143}, 90163: set(), 90334: set(), 90165: set()}
# {90334: set(), 90148: set(), 90145: set(), 90163: set(), 90754: set()}
# {90147: set(), 90166: set(), 90148: set(), 90164: set(), 90334: set()}
# {90140: set(), 90143: set(), 90754: set(), 90165: set(), 90146: set()}
# {90143: {90147}, 90147: {90143}, 90148: set(), 90163: set(), 90140: set()}
# {90164: set(), 90144: set(), 90754: set(), 90166: set(), 90163: set()}
# {90146: set(), 90148: set(), 90166: set(), 90142: set(), 90164: set()}
# {90754: set(), 90165: set(), 90163: set(), 90147: set(), 90144: set()}
# {90163: set(), 90145: set(), 90144: set(), 90754: set(), 90148: set()}
# {90165: set(), 90148: set(), 90167: set(), 90143: set(), 90145: set()}
# {90140: set(), 90139: set(), 90164: set(), 90146: set(), 90147: set()}
# {90145: set(), 90167: set(), 90147: set(), 90140: set(), 90334: set()}
# {90163: set(), 90166: set(), 90334: set(), 90164: set(), 90148: set()}
# {90163: set(), 90139: {90145}, 90754: set(), 90145: {90139}, 90144: set()}
# {90147: {90143}, 90143: {90147}, 90164: set(), 90167: set(), 90142: set()}
# {90167: set(), 90334: set(), 90165: set(), 90143: set(), 90139: set()}
# {90147: set(), 90166: set(), 90145: set(), 90334: set(), 90163: set()}
# {90334: set(), 90754: set(), 90140: set(), 90148: set(), 90144: set()}
# {90147: {90143}, 90166: set(), 90143: {90147}, 90167: set(), 90334: set()}
# {90146: set(), 90140: set(), 90165: set(), 90145: set(), 90143: set()}
# {90163: set(), 90166: set(), 90167: set(), 90164: set(), 90143: set()}
# {90163: set(), 90143: set(), 90165: set(), 90139: set(), 90142: set()}
# {90146: set(), 90754: set(), 90143: set(), 90334: set(), 90142: set()}
# {90140: {90166}, 90166: {90140}, 90146: set(), 90139: set(), 90334: set()}
# {90143: set(), 90146: set(), 90167: set(), 90139: set(), 90142: set()}
# {90165: set(), 90144: set(), 90163: set(), 90146: set(), 90167: set()}
# {90163: set(), 90164: set(), 90145: set(), 90142: set(), 90754: set()}
# {90148: set(), 90139: set(), 90144: set(), 90146: set(), 90165: set()}
# {90164: set(), 90139: {90145}, 90166: set(), 90754: set(), 90145: {90139}}
# {90146: set(), 90163: set(), 90334: set(), 90148: set(), 90145: set()}
# {90163: set(), 90167: set(), 90334: set(), 90164: set(), 90140: set()}
# {90145: set(), 90166: set(), 90167: set(), 90334: set(), 90144: set()}
# {90140: {90166}, 90163: set(), 90166: {90140}, 90754: set(), 90147: set()}
# {90142: set(), 90148: set(), 90140: set(), 90163: set(), 90144: set()}
# {90754: set(), 90166: set(), 90142: set(), 90144: set(), 90167: set()}
# {90165: set(), 90166: {90140}, 90146: set(), 90140: {90166}, 90148: set()}
# {90145: {90139}, 90334: set(), 90139: {90145}, 90140: set(), 90143: set()}
# {90147: {90143}, 90144: set(), 90754: set(), 90139: set(), 90143: {90147}}
# {90166: set(), 90145: set(), 90148: set(), 90146: set(), 90144: set()}
# {90145: {90139}, 90146: set(), 90148: set(), 90139: {90145}, 90167: set()}
# {90165: set(), 90140: {90166}, 90166: {90140}, 90147: set(), 90144: set()}
# {90166: set(), 90142: set(), 90754: set(), 90163: set(), 90145: set()}
# {90754: set(), 90144: set(), 90146: set(), 90148: set(), 90147: set()}
# {90143: set(), 90144: set(), 90165: set(), 90145: set(), 90146: set()}
# {90148: set(), 90144: set(), 90165: set(), 90164: set(), 90147: set()}
# {90167: set(), 90754: set(), 90334: set(), 90146: set(), 90147: set()}
# {90148: set(), 90164: set(), 90144: set(), 90147: set(), 90142: set()}
# {90167: set(), 90163: set(), 90148: set(), 90166: set(), 90145: set()}
# {90146: set(), 90140: set(), 90164: set(), 90144: set(), 90148: set()}
# {90166: set(), 90142: set(), 90146: set(), 90139: set(), 90167: set()}
# {90754: set(), 90165: set(), 90163: set(), 90167: set(), 90147: set()}
# {90139: set(), 90144: set(), 90334: set(), 90754: set(), 90143: set()}
# {90164: set(), 90166: set(), 90167: set(), 90146: set(), 90334: set()}
# {90167: set(), 90148: set(), 90754: set(), 90145: set(), 90140: set()}
# {90144: set(), 90163: set(), 90145: set(), 90140: set(), 90147: set()}
# {90164: set(), 90142: set(), 90147: set(), 90165: set(), 90148: set()}
# {90165: set(), 90164: set(), 90146: set(), 90143: set(), 90148: set()}
# {90164: set(), 90165: set(), 90167: set(), 90142: set(), 90139: set()}
# {90167: set(), 90144: set(), 90754: set(), 90146: set(), 90164: set()}
# {90140: {90166}, 90163: set(), 90166: {90140}, 90164: set(), 90334: set()}
# {90165: set(), 90146: set(), 90140: set(), 90164: set(), 90142: set()}
# {90144: set(), 90165: set(), 90147: set(), 90142: set(), 90166: set()}
# {90165: set(), 90166: set(), 90334: set(), 90163: set(), 90144: set()}
# {90140: set(), 90754: set(), 90142: set(), 90139: set(), 90167: set()}
# {90167: set(), 90148: set(), 90145: set(), 90147: set(), 90166: set()}
# {90148: set(), 90147: set(), 90145: set(), 90164: set(), 90163: set()}
# {90143: set(), 90165: set(), 90142: set(), 90334: set(), 90163: set()}
# {90142: set(), 90144: set(), 90163: set(), 90148: set(), 90167: set()}
# {90144: set(), 90139: set(), 90143: set(), 90142: set(), 90754: set()}
# {90165: set(), 90145: set(), 90164: set(), 90163: set(), 90143: set()}
# {90164: set(), 90334: set(), 90142: set(), 90148: set(), 90167: set()}
# {90139: set(), 90146: set(), 90334: set(), 90148: set(), 90140: set()}
# {90165: set(), 90140: set(), 90144: set(), 90143: set(), 90146: set()}
# {90163: set(), 90334: set(), 90140: set(), 90167: set(), 90147: set()}
# {90334: set(), 90146: set(), 90139: set(), 90754: set(), 90142: set()}
# {90165: set(), 90140: set(), 90144: set(), 90143: set(), 90164: set()}
# {90163: set(), 90145: set(), 90165: set(), 90164: set(), 90146: set()}
# {90163: set(), 90142: set(), 90143: set(), 90145: set(), 90334: set()}
# {90167: set(), 90146: set(), 90334: set(), 90140: set(), 90144: set()}
# {90164: set(), 90163: set(), 90147: set(), 90166: set(), 90142: set()}
# {90143: {90147}, 90334: set(), 90145: set(), 90147: {90143}, 90165: set()}
# {90163: set(), 90146: set(), 90142: set(), 90148: set(), 90145: set()}
# {90167: set(), 90166: set(), 90163: set(), 90145: {90139}, 90139: {90145}}
# {90140: set(), 90139: set(), 90334: set(), 90164: set(), 90167: set()}
# {90165: set(), 90145: set(), 90164: set(), 90148: set(), 90144: set()}
# {90145: set(), 90147: set(), 90166: {90140}, 90142: set(), 90140: {90166}}
# {90142: set(), 90140: {90166}, 90139: set(), 90166: {90140}, 90164: set()}
# {90334: set(), 90139: set(), 90754: set(), 90143: set(), 90146: set()}
# {90144: set(), 90164: set(), 90163: set(), 90139: {90145}, 90145: {90139}}
# {90166: set(), 90145: set(), 90334: set(), 90163: set(), 90167: set()}
# {90163: set(), 90139: set(), 90140: set(), 90142: set(), 90144: set()}
# {90148: set(), 90163: set(), 90145: set(), 90166: set(), 90167: set()}
# {90145: set(), 90146: set(), 90142: set(), 90148: set(), 90144: set()}
# {90148: set(), 90140: set(), 90334: set(), 90143: set(), 90139: set()}
# {90165: set(), 90139: set(), 90148: set(), 90147: set(), 90140: set()}
# {90146: set(), 90754: set(), 90165: set(), 90144: set(), 90142: set()}
# {90754: set(), 90143: set(), 90139: set(), 90140: set(), 90334: set()}
# {90140: set(), 90167: set(), 90165: set(), 90754: set(), 90164: set()}
# {90334: set(), 90167: set(), 90147: {90143}, 90143: {90147}, 90145: set()}
# {90754: set(), 90145: set(), 90140: set(), 90146: set(), 90334: set()}
# {90139: set(), 90334: set(), 90140: set(), 90146: set(), 90164: set()}
# {90139: {90145}, 90145: {90139}, 90754: set(), 90165: set(), 90334: set()}
# {90143: set(), 90165: set(), 90144: set(), 90167: set(), 90140: set()}
# {90144: set(), 90140: set(), 90139: set(), 90163: set(), 90147: set()}
# {90167: set(), 90142: set(), 90163: set(), 90145: set(), 90143: set()}
# {90142: set(), 90145: set(), 90148: set(), 90334: set(), 90166: set()}
# {90144: set(), 90167: set(), 90146: set(), 90754: set(), 90166: set()}
# {90148: set(), 90144: set(), 90167: set(), 90143: set(), 90165: set()}
# {90145: set(), 90143: set(), 90142: set(), 90148: set(), 90334: set()}
# {90146: set(), 90140: set(), 90167: set(), 90142: set(), 90145: set()}
# {90165: set(), 90146: set(), 90163: set(), 90139: set(), 90144: set()}
# {90147: set(), 90167: set(), 90140: set(), 90139: set(), 90164: set()}
# {90148: set(), 90140: {90166}, 90139: set(), 90165: set(), 90166: {90140}}
# {90166: {90140}, 90140: {90166}, 90148: set(), 90163: set(), 90147: set()}
# {90163: set(), 90146: set(), 90165: set(), 90147: set(), 90164: set()}
# {90146: set(), 90148: set(), 90164: set(), 90165: set(), 90145: set()}
# {90334: set(), 90140: set(), 90139: {90145}, 90145: {90139}, 90167: set()}
# {90144: set(), 90139: set(), 90148: set(), 90146: set(), 90166: set()}
# {90144: set(), 90140: {90166}, 90166: {90140}, 90145: {90139}, 90139: {90145}}
# {90145: set(), 90143: set(), 90144: set(), 90142: set(), 90164: set()}
# {90148: set(), 90145: set(), 90754: set(), 90147: set(), 90146: set()}
# {90754: set(), 90147: {90143}, 90144: set(), 90163: set(), 90143: {90147}}
# {90163: set(), 90148: set(), 90166: set(), 90142: set(), 90167: set()}
# {90165: set(), 90754: set(), 90143: set(), 90163: set(), 90142: set()}
# {90139: set(), 90146: set(), 90164: set(), 90167: set(), 90142: set()}
# {90165: set(), 90167: set(), 90164: set(), 90143: set(), 90145: set()}
# {90164: set(), 90754: set(), 90145: set(), 90166: set(), 90144: set()}
# {90140: {90166}, 90163: set(), 90143: set(), 90166: {90140}, 90167: set()}
# {90148: set(), 90167: set(), 90163: set(), 90166: set(), 90165: set()}
# {90164: set(), 90142: set(), 90163: set(), 90139: set(), 90146: set()}
# {90148: set(), 90334: set(), 90146: set(), 90145: set(), 90163: set()}
# {90334: set(), 90167: set(), 90165: set(), 90166: set(), 90754: set()}
# {90147: {90143}, 90143: {90147}, 90164: set(), 90146: set(), 90163: set()}
# {90139: set(), 90163: set(), 90167: set(), 90166: set(), 90147: set()}
# {90165: set(), 90140: set(), 90145: set(), 90163: set(), 90147: set()}
# {90143: set(), 90166: set(), 90167: set(), 90144: set(), 90145: set()}
# {90148: set(), 90144: set(), 90140: {90166}, 90166: {90140}, 90147: set()}
# {90142: set(), 90144: set(), 90140: set(), 90164: set(), 90146: set()}
# {90166: set(), 90167: set(), 90143: set(), 90165: set(), 90334: set()}
# {90147: {90143}, 90143: {90147}, 90165: set(), 90164: set(), 90163: set()}
# {90754: set(), 90147: set(), 90139: set(), 90148: set(), 90142: set()}
# {90146: set(), 90166: {90140}, 90754: set(), 90144: set(), 90140: {90166}}
# {90142: set(), 90143: set(), 90334: set(), 90148: set(), 90146: set()}
# {90143: set(), 90164: set(), 90144: set(), 90754: set(), 90145: set()}
# {90167: set(), 90146: set(), 90334: set(), 90148: set(), 90145: set()}
# {90142: set(), 90139: {90145}, 90166: set(), 90148: set(), 90145: {90139}}
# {90140: set(), 90142: set(), 90334: set(), 90146: set(), 90167: set()}
# {90165: set(), 90147: set(), 90167: set(), 90139: set(), 90754: set()}
# {90334: set(), 90143: set(), 90754: set(), 90163: set(), 90144: set()}
# {90144: set(), 90165: set(), 90167: set(), 90163: set(), 90334: set()}
# {90163: set(), 90143: set(), 90165: set(), 90148: set(), 90146: set()}
# {90334: set(), 90142: set(), 90165: set(), 90143: set(), 90144: set()}
# {90146: set(), 90145: set(), 90163: set(), 90147: set(), 90148: set()}
# {90163: set(), 90166: set(), 90145: set(), 90165: set(), 90148: set()}
# {90143: set(), 90163: set(), 90142: set(), 90165: set(), 90144: set()}
# {90754: set(), 90148: set(), 90147: {90143}, 90167: set(), 90143: {90147}}
# {90143: set(), 90142: set(), 90144: set(), 90167: set(), 90754: set()}
# {90144: set(), 90164: set(), 90140: set(), 90163: set(), 90139: set()}
# {90146: set(), 90147: set(), 90167: set(), 90754: set(), 90142: set()}
# {90145: set(), 90147: set(), 90163: set(), 90167: set(), 90754: set()}
# {90164: set(), 90144: set(), 90165: set(), 90163: set(), 90140: set()}
# {90167: set(), 90139: set(), 90148: set(), 90143: set(), 90166: set()}
# {90143: {90147}, 90147: {90143}, 90165: set(), 90166: set(), 90144: set()}
# {90146: set(), 90754: set(), 90148: set(), 90142: set(), 90145: set()}
# {90147: set(), 90754: set(), 90140: {90166}, 90166: {90140}, 90163: set()}
# {90146: set(), 90144: set(), 90142: set(), 90139: set(), 90147: set()}
# {90165: set(), 90148: set(), 90754: set(), 90145: set(), 90166: set()}
# {90167: set(), 90142: set(), 90147: set(), 90140: {90166}, 90166: {90140}}
# {90146: set(), 90166: set(), 90164: set(), 90334: set(), 90754: set()}
# {90163: set(), 90334: set(), 90754: set(), 90167: set(), 90143: set()}
# {90142: set(), 90146: set(), 90165: set(), 90143: set(), 90144: set()}
# {90145: set(), 90164: set(), 90140: {90166}, 90166: {90140}, 90165: set()}
# {90166: {90140}, 90140: {90166}, 90148: set(), 90754: set(), 90163: set()}
# {90145: {90139}, 90164: set(), 90139: {90145}, 90142: set(), 90148: set()}
# {90167: set(), 90166: set(), 90164: set(), 90143: set(), 90139: set()}
# {90754: set(), 90139: set(), 90146: set(), 90163: set(), 90167: set()}
# {90164: set(), 90166: set(), 90144: set(), 90147: set(), 90139: set()}
# {90165: set(), 90167: set(), 90164: set(), 90166: set(), 90147: set()}
# {90145: set(), 90148: set(), 90334: set(), 90167: set(), 90144: set()}
# {90142: set(), 90163: set(), 90144: set(), 90334: set(), 90165: set()}
# {90145: set(), 90144: set(), 90143: set(), 90166: set(), 90334: set()}
# {90164: set(), 90142: set(), 90165: set(), 90148: set(), 90143: set()}
# {90144: set(), 90143: set(), 90145: set(), 90167: set(), 90165: set()}
# {90334: set(), 90165: set(), 90164: set(), 90142: set(), 90166: set()}
# {90147: set(), 90144: set(), 90145: {90139}, 90139: {90145}, 90140: set()}
# {90143: set(), 90166: {90140}, 90164: set(), 90754: set(), 90140: {90166}}
# {90146: set(), 90147: set(), 90163: set(), 90164: set(), 90165: set()}
# {90139: set(), 90164: set(), 90166: set(), 90334: set(), 90144: set()}
# {90144: set(), 90143: set(), 90146: set(), 90167: set(), 90140: set()}
# {90146: set(), 90334: set(), 90140: set(), 90139: set(), 90754: set()}
# {90148: set(), 90144: set(), 90139: set(), 90140: {90166}, 90166: {90140}}
# {90166: set(), 90164: set(), 90142: set(), 90144: set(), 90334: set()}
# {90142: set(), 90143: set(), 90146: set(), 90164: set(), 90334: set()}
# {90334: set(), 90166: set(), 90163: set(), 90167: set(), 90146: set()}
# {90143: {90147}, 90148: set(), 90147: {90143}, 90165: set(), 90163: set()}
# {90139: {90145}, 90164: set(), 90754: set(), 90142: set(), 90145: {90139}}
# {90167: set(), 90754: set(), 90140: set(), 90145: set(), 90164: set()}
# {90148: set(), 90142: set(), 90143: set(), 90139: set(), 90166: set()}
# {90140: set(), 90167: set(), 90139: set(), 90163: set(), 90146: set()}
# {90144: set(), 90163: set(), 90148: set(), 90334: set(), 90164: set()}
# {90334: set(), 90163: set(), 90140: set(), 90147: set(), 90754: set()}
# {90145: set(), 90143: set(), 90142: set(), 90146: set(), 90148: set()}
# {90754: set(), 90142: set(), 90166: set(), 90143: set(), 90145: set()}
# {90148: set(), 90147: set(), 90167: set(), 90166: set(), 90142: set()}
# {90754: set(), 90140: {90166}, 90334: set(), 90166: {90140}, 90142: set()}
# {90164: set(), 90144: set(), 90334: set(), 90139: set(), 90166: set()}
# {90334: set(), 90164: set(), 90146: set(), 90166: set(), 90139: set()}
# {90139: {90145}, 90145: {90139}, 90167: set(), 90147: set(), 90166: set()}
# {90334: set(), 90139: {90145}, 90146: set(), 90166: set(), 90145: {90139}}
# {90164: set(), 90145: set(), 90165: set(), 90148: set(), 90146: set()}
# {90165: set(), 90334: set(), 90754: set(), 90147: set(), 90167: set()}
# {90163: set(), 90146: set(), 90142: set(), 90167: set(), 90164: set()}
# {90164: set(), 90146: set(), 90163: set(), 90144: set(), 90148: set()}
# {90140: set(), 90147: set(), 90146: set(), 90139: set(), 90164: set()}

# %%
monte_carlo_gs(student_dict, sections, 10)
# Out:
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# 0

# %%
gs.gale_shapley_match(student_dict, sections)
for id, student in student_dict.items():
    if len(student.enrolled_in) > 3:
        print(student)
# Out:
# student1651(COM5):
# id: 1651
# base_score: 500
# section ranking: [90143, 90147, 90142, 90140, 90144]
# schedule: {90144, 90140, 90142, 90143}
# sections enrolled: 4
#
# student1662(COM5):
# id: 1662
# base_score: 500
# section ranking: [90140, 90142, 90754, 90334, 90139]
# schedule: {90754, 90139, 90140, 90142}
# sections enrolled: 4
#
# student1675(COM5):
# id: 1675
# base_score: 500
# section ranking: [90164, 90139, 90145, 90143, 90142]
# schedule: {90139, 90164, 90142, 90143}
# sections enrolled: 4
#
# student1686(COM5):
# id: 1686
# base_score: 500
# section ranking: [90145, 90139, 90167, 90165, 90147]
# schedule: {90145, 90147, 90165, 90167}
# sections enrolled: 4
#
# student1701(COM5):
# id: 1701
# base_score: 500
# section ranking: [90147, 90165, 90334, 90167, 90142]
# schedule: {90147, 90165, 90142, 90167}
# sections enrolled: 4
#
# student1704(COM5):
# id: 1704
# base_score: 500
# section ranking: [90163, 90148, 90334, 90139, 90167]
# schedule: {90139, 90163, 90148, 90167}
# sections enrolled: 4
#
# student1710(COM5):
# id: 1710
# base_score: 500
# section ranking: [90334, 90140, 90754, 90165, 90164]
# schedule: {90754, 90140, 90165, 90164}
# sections enrolled: 4
#
# student1712(COM5):
# id: 1712
# base_score: 500
# section ranking: [90754, 90142, 90140, 90145, 90164]
# schedule: {90145, 90754, 90140, 90142}
# sections enrolled: 4
#
# student1730(COM5):
# id: 1730
# base_score: 500
# section ranking: [90166, 90144, 90143, 90167, 90139]
# schedule: {90144, 90167, 90166, 90143}
# sections enrolled: 4
#
# student1740(COM5):
# id: 1740
# base_score: 500
# section ranking: [90146, 90165, 90144, 90143, 90163]
# schedule: {90144, 90163, 90165, 90143}
# sections enrolled: 4
#
# student1741(COM5):
# id: 1741
# base_score: 500
# section ranking: [90146, 90334, 90166, 90754, 90167]
# schedule: {90146, 90167, 90166, 90754}
# sections enrolled: 4
#
# student1742(COM5):
# id: 1742
# base_score: 500
# section ranking: [90166, 90147, 90143, 90167, 90146]
# schedule: {90146, 90147, 90166, 90167}
# sections enrolled: 4
#
# student1751(COM5):
# id: 1751
# base_score: 500
# section ranking: [90165, 90167, 90145, 90148, 90140]
# schedule: {90145, 90148, 90165, 90167}
# sections enrolled: 4
#
# student1757(COM5):
# id: 1757
# base_score: 500
# section ranking: [90754, 90148, 90334, 90140, 90146]
# schedule: {90754, 90146, 90148, 90140}
# sections enrolled: 4
#
# student1758(COM5):
# id: 1758
# base_score: 500
# section ranking: [90334, 90166, 90139, 90146, 90144]
# schedule: {90144, 90146, 90139, 90166}
# sections enrolled: 4
#
# student1760(COM5):
# id: 1760
# base_score: 500
# section ranking: [90147, 90140, 90164, 90143, 90163]
# schedule: {90163, 90147, 90140, 90164}
# sections enrolled: 4
#
# student1766(COM5):
# id: 1766
# base_score: 500
# section ranking: [90143, 90145, 90144, 90139, 90140]
# schedule: {90144, 90145, 90140, 90143}
# sections enrolled: 4
#
# student1770(COM5):
# id: 1770
# base_score: 500
# section ranking: [90143, 90165, 90754, 90147, 90164]
# schedule: {90754, 90164, 90165, 90143}
# sections enrolled: 4
#
# student1774(COM5):
# id: 1774
# base_score: 500
# section ranking: [90140, 90143, 90334, 90148, 90142]
# schedule: {90140, 90142, 90148, 90143}
# sections enrolled: 4
#
# student1775(COM5):
# id: 1775
# base_score: 500
# section ranking: [90140, 90147, 90167, 90142, 90139]
# schedule: {90147, 90140, 90142, 90167}
# sections enrolled: 4
#
# student1780(COM5):
# id: 1780
# base_score: 500
# section ranking: [90144, 90165, 90143, 90754, 90334]
# schedule: {90144, 90754, 90165, 90143}
# sections enrolled: 4
#
# student1782(COM5):
# id: 1782
# base_score: 500
# section ranking: [90166, 90147, 90145, 90139, 90148]
# schedule: {90145, 90147, 90148, 90166}
# sections enrolled: 4
#
# student1783(COM5):
# id: 1783
# base_score: 500
# section ranking: [90139, 90146, 90145, 90334, 90166]
# schedule: {90166, 90146, 90139, 90334}
# sections enrolled: 4
#
# student1788(COM5):
# id: 1788
# base_score: 500
# section ranking: [90147, 90166, 90148, 90164, 90334]
# schedule: {90147, 90148, 90166, 90164}
# sections enrolled: 4
#
# student1795(COM5):
# id: 1795
# base_score: 500
# section ranking: [90165, 90148, 90167, 90143, 90145]
# schedule: {90143, 90148, 90165, 90167}
# sections enrolled: 4
#
# student1798(COM5):
# id: 1798
# base_score: 500
# section ranking: [90163, 90166, 90334, 90164, 90148]
# schedule: {90163, 90164, 90334, 90166}
# sections enrolled: 4
#
# student1805(COM5):
# id: 1805
# base_score: 500
# section ranking: [90146, 90140, 90165, 90145, 90143]
# schedule: {90145, 90146, 90140, 90165}
# sections enrolled: 4
#
# student1820(COM5):
# id: 1820
# base_score: 500
# section ranking: [90754, 90166, 90142, 90144, 90167]
# schedule: {90144, 90754, 90166, 90142}
# sections enrolled: 4
#
# student1822(COM5):
# id: 1822
# base_score: 500
# section ranking: [90145, 90334, 90139, 90140, 90143]
# schedule: {90145, 90140, 90334, 90143}
# sections enrolled: 4
#
# student1823(COM5):
# id: 1823
# base_score: 500
# section ranking: [90147, 90144, 90754, 90139, 90143]
# schedule: {90144, 90139, 90754, 90147}
# sections enrolled: 4
#
# student1824(COM5):
# id: 1824
# base_score: 500
# section ranking: [90166, 90145, 90148, 90146, 90144]
# schedule: {90145, 90146, 90148, 90166}
# sections enrolled: 4
#
# student1826(COM5):
# id: 1826
# base_score: 500
# section ranking: [90165, 90140, 90166, 90147, 90144]
# schedule: {90144, 90147, 90140, 90165}
# sections enrolled: 4
#
# student1832(COM5):
# id: 1832
# base_score: 500
# section ranking: [90148, 90164, 90144, 90147, 90142]
# schedule: {90144, 90147, 90148, 90164}
# sections enrolled: 4
#
# student1835(COM5):
# id: 1835
# base_score: 500
# section ranking: [90166, 90142, 90146, 90139, 90167]
# schedule: {90146, 90139, 90166, 90142}
# sections enrolled: 4
#
# student1838(COM5):
# id: 1838
# base_score: 500
# section ranking: [90164, 90166, 90167, 90146, 90334]
# schedule: {90146, 90164, 90166, 90167}
# sections enrolled: 4
#
# student1856(COM5):
# id: 1856
# base_score: 500
# section ranking: [90164, 90334, 90142, 90148, 90167]
# schedule: {90164, 90148, 90334, 90142}
# sections enrolled: 4
#
# student1860(COM5):
# id: 1860
# base_score: 500
# section ranking: [90334, 90146, 90139, 90754, 90142]
# schedule: {90146, 90139, 90334, 90754}
# sections enrolled: 4
#
# student1867(COM5):
# id: 1867
# base_score: 500
# section ranking: [90163, 90146, 90142, 90148, 90145]
# schedule: {90146, 90163, 90148, 90142}
# sections enrolled: 4
#
# student1869(COM5):
# id: 1869
# base_score: 500
# section ranking: [90140, 90139, 90334, 90164, 90167]
# schedule: {90139, 90140, 90334, 90164}
# sections enrolled: 4
#
# student1870(COM5):
# id: 1870
# base_score: 500
# section ranking: [90165, 90145, 90164, 90148, 90144]
# schedule: {90145, 90164, 90165, 90148}
# sections enrolled: 4
#
# student1876(COM5):
# id: 1876
# base_score: 500
# section ranking: [90163, 90139, 90140, 90142, 90144]
# schedule: {90139, 90163, 90140, 90142}
# sections enrolled: 4
#
# student1887(COM5):
# id: 1887
# base_score: 500
# section ranking: [90139, 90145, 90754, 90165, 90334]
# schedule: {90754, 90139, 90165, 90334}
# sections enrolled: 4
#
# student1896(COM5):
# id: 1896
# base_score: 500
# section ranking: [90165, 90146, 90163, 90139, 90144]
# schedule: {90139, 90146, 90163, 90165}
# sections enrolled: 4
#
# student1902(COM5):
# id: 1902
# base_score: 500
# section ranking: [90334, 90140, 90139, 90145, 90167]
# schedule: {90139, 90140, 90334, 90167}
# sections enrolled: 4
#
# student1906(COM5):
# id: 1906
# base_score: 500
# section ranking: [90148, 90145, 90754, 90147, 90146]
# schedule: {90145, 90754, 90147, 90148}
# sections enrolled: 4
#
# student1907(COM5):
# id: 1907
# base_score: 500
# section ranking: [90754, 90147, 90144, 90163, 90143]
# schedule: {90144, 90163, 90754, 90147}
# sections enrolled: 4
#
# student1919(COM5):
# id: 1919
# base_score: 500
# section ranking: [90139, 90163, 90167, 90166, 90147]
# schedule: {90163, 90139, 90166, 90167}
# sections enrolled: 4
#
# student1924(COM5):
# id: 1924
# base_score: 500
# section ranking: [90166, 90167, 90143, 90165, 90334]
# schedule: {90143, 90165, 90166, 90167}
# sections enrolled: 4
#
# student1927(COM5):
# id: 1927
# base_score: 500
# section ranking: [90146, 90166, 90754, 90144, 90140]
# schedule: {90144, 90146, 90166, 90754}
# sections enrolled: 4
#
# student1928(COM5):
# id: 1928
# base_score: 500
# section ranking: [90142, 90143, 90334, 90148, 90146]
# schedule: {90148, 90334, 90142, 90143}
# sections enrolled: 4
#
# student1929(COM5):
# id: 1929
# base_score: 500
# section ranking: [90143, 90164, 90144, 90754, 90145]
# schedule: {90144, 90754, 90164, 90143}
# sections enrolled: 4
#
# student1944(COM5):
# id: 1944
# base_score: 500
# section ranking: [90146, 90147, 90167, 90754, 90142]
# schedule: {90146, 90147, 90754, 90167}
# sections enrolled: 4
#
# student1945(COM5):
# id: 1945
# base_score: 500
# section ranking: [90145, 90147, 90163, 90167, 90754]
# schedule: {90145, 90147, 90163, 90167}
# sections enrolled: 4
#
# student1963(COM5):
# id: 1963
# base_score: 500
# section ranking: [90165, 90167, 90164, 90166, 90147]
# schedule: {90164, 90165, 90166, 90167}
# sections enrolled: 4
#
# student1974(COM5):
# id: 1974
# base_score: 500
# section ranking: [90144, 90143, 90146, 90167, 90140]
# schedule: {90144, 90146, 90167, 90143}
# sections enrolled: 4
#
# student1981(COM5):
# id: 1981
# base_score: 500
# section ranking: [90139, 90164, 90754, 90142, 90145]
# schedule: {90754, 90139, 90164, 90142}
# sections enrolled: 4
#
# student1983(COM5):
# id: 1983
# base_score: 500
# section ranking: [90148, 90142, 90143, 90139, 90166]
# schedule: {90139, 90148, 90142, 90143}
# sections enrolled: 4
#
# student1987(COM5):
# id: 1987
# base_score: 500
# section ranking: [90145, 90143, 90142, 90146, 90148]
# schedule: {90145, 90146, 90142, 90143}
# sections enrolled: 4
#
# student1992(COM5):
# id: 1992
# base_score: 500
# section ranking: [90334, 90164, 90146, 90166, 90139]
# schedule: {90166, 90146, 90164, 90334}
# sections enrolled: 4
#
# student1999(COM5):
# id: 1999
# base_score: 500
# section ranking: [90140, 90147, 90146, 90139, 90164]
# schedule: {90139, 90146, 90147, 90140}
# sections enrolled: 4
