# %%
import copy
import sys

import data
import gs
import test_stability
from count_potential_rogues import count_potential_rogues

# %%
sections = data.section_JSON_to_dict("../scraping/classes22.json")
print(len(sections))
student_dict = data.generate_students_weighted(sections, 3000)
for key in student_dict:
    student_dict[key].find_conflicts(sections)
print(count_potential_rogues(student_dict))
# Out:
# 601
# 22 90330
# 26 90330
# 27 90101
# 28 90366
# 59 90324
# 91 90101
# 120 90278
# 128 90773
# 156 90237
# 166 90295
# 222 90010
# 233 90118
# 312 90266
# 319 90295
# 335 90257
# 358 90342
# 391 90775
# 424 90317
# 449 90696
# 471 90005
# 529 90253
# 530 90217
# 546 90671
# 562 90217
# 566 90751
# 570 90559
# 590 90105
# 600 90037
# 689 90756
# 748 90325
# 792 90180
# 816 90177
# 879 90600
# 889 90257
# 956 90583
# 956 90366
# 1004 90295
# 1018 90320
# 1223 90472
# 1224 90084
# 1257 90320
# 1323 90254
# 1360 90321
# 1362 90103
# 1398 90101
# 1427 90173
# 1492 90353
# 1524 90254
# 1524 90324
# 1529 90316
# 1591 90600
# 1597 90173
# 1638 90509
# 1639 90173
# 1641 90472
# 1657 90302
# 1668 90173
# 1678 90697
# 1769 90323
# 1792 90135
# 1824 90774
# 1843 90659
# 1934 90084
# 1948 90150
# 1971 90366
# 2003 90600
# 2021 90173
# 2030 90329
# 2040 90145
# 2068 90254
# 2087 90553
# 2098 90629
# 2110 90366
# 2112 90566
# 2135 90173
# 2139 90037
# 2142 90092
# 2153 90278
# 2250 90584
# 2250 90134
# 2259 90462
# 2264 90583
# 2295 90302
# 2326 90157
# 2347 90352
# 2412 90301
# 2422 90278
# 2437 90554
# 2452 90081
# 2466 90673
# 2479 90472
# 2480 90119
# 2560 90700
# 2584 90016
# 2679 90557
# 2707 90323
# 2745 90037
# 2771 90517
# 2806 90600
# 2848 90583
# 2889 90217
# 2950 90317
# 102

# %%
def monte_carlo_gs(student_dict: dict, section_dict: dict, iteration_limit: int = 500) -> int:
    best = float("inf")
    seeds = [i for i in range(1, iteration_limit + 2)]
    i = 0
    while i < iteration_limit:
        i += 1
        
        new_student_dict = copy.deepcopy(student_dict)
        new_section_dict = copy.deepcopy(section_dict)
        new_matching = gs.gale_shapley_match(new_student_dict, new_section_dict, shuffle = True, seed = seeds[i])
        
        rogues = test_stability.is_weakly_stable(new_matching[0], new_matching[1])[1]
        
        if rogues < best:
            best = rogues
            
    return int(best)

# %%
monte_carlo_gs(student_dict, sections, 10)
# Out:
# counter: 3
# counter: 2
# counter: 3
# counter: 2
# counter: 1
# counter: 3
# counter: 2
# counter: 3
# counter: 1
# counter: 3
# 1

# %%
matched_students, matched_sections = gs.gale_shapley_match(copy.deepcopy(student_dict), copy.deepcopy(sections))
for id, s in matched_students.items():
    if len(s.enrolled_in) > 0:
        print(s)
# Out:
# student0(NEU2):
# id: 0
# base_score: 200
# section ranking: [90753, 90099, 90308, 90790, 90297]
# schedule: {90297, 90753, 90099, 90308}
# sections enrolled: 4
#
# student1(GOV2):
# id: 1
# base_score: 200
# section ranking: [90643, 90753, 90570, 90686, 90021]
# schedule: {90753, 90570, 90643, 90021}
# sections enrolled: 4
#
# student2(GIS4):
# id: 2
# base_score: 400
# section ranking: [90620, 90688, 90235, 90325, 90269]
# schedule: {90688, 90235, 90620, 90325}
# sections enrolled: 4
#
# student3(SPA4):
# id: 3
# base_score: 400
# section ranking: [90215, 90804, 90199, 90801, 90476]
# schedule: {90801, 90804, 90199, 90215}
# sections enrolled: 4
#
# student4(EDU1):
# id: 4
# base_score: 100
# section ranking: [90243, 90245, 90770, 90550, 90244]
# schedule: {90244, 90245, 90550}
# sections enrolled: 3
#
# student5(BOT5):
# id: 5
# base_score: 500
# section ranking: [90242, 90039, 90243, 90093, 90541]
# schedule: {90242, 90243, 90093, 90039}
# sections enrolled: 4
#
# student6(ITL2):
# id: 6
# base_score: 200
# section ranking: [90774, 90558, 90560, 90689, 90567]
# schedule: {90560, 90689, 90774}
# sections enrolled: 3
#
# student7(BOT5):
# id: 7
# base_score: 500
# section ranking: [90104, 90535, 90097, 90666, 90033]
# schedule: {90104, 90666, 90535}
# sections enrolled: 3
#
# student8(ITL1):
# id: 8
# base_score: 100
# section ranking: [90818, 90386, 90499, 90558, 90560]
# schedule: {90818, 90499}
# sections enrolled: 2
#
# student9(SJS3):
# id: 9
# base_score: 300
# section ranking: [90277, 90124, 90011, 90109, 90315]
# schedule: {90109, 90011, 90124, 90277}
# sections enrolled: 4
#
# student10(PHE4):
# id: 10
# base_score: 400
# section ranking: [90306, 90364, 90775, 90365, 90196]
# schedule: {90306, 90364, 90365, 90196}
# sections enrolled: 4
#
# student11(GEO3):
# id: 11
# base_score: 300
# section ranking: [90252, 90135, 90333, 90289, 90260]
# schedule: {90289, 90252, 90135}
# sections enrolled: 3
#
# student12(PAX2):
# id: 12
# base_score: 200
# section ranking: [90374, 90187, 90553, 90250, 90099]
# schedule: {90187, 90099}
# sections enrolled: 2
#
# student13(FRH2):
# id: 13
# base_score: 200
# section ranking: [90569, 90031, 90674, 90474, 90478]
# schedule: {90569, 90474, 90478, 90031}
# sections enrolled: 4
#
# student14(EAS3):
# id: 14
# base_score: 300
# section ranking: [90219, 90615, 90273, 90220, 90270]
# schedule: {90273, 90219, 90220, 90615}
# sections enrolled: 4
#
# student15(LIN5):
# id: 15
# base_score: 500
# section ranking: [90684, 90593, 90291, 90572, 90516]
# schedule: {90572, 90593, 90291, 90684}
# sections enrolled: 4
#
# student16(BOT5):
# id: 16
# base_score: 500
# section ranking: [90548, 90170, 90140, 90102, 90094]
# schedule: {90170, 90548, 90140, 90102}
# sections enrolled: 4
#
# student17(JPN3):
# id: 17
# base_score: 300
# section ranking: [90552, 90553, 90168, 90815, 90555]
# schedule: {90815}
# sections enrolled: 1
#
# student18(CLA3):
# id: 18
# base_score: 300
# section ranking: [90639, 90028, 90275, 90615, 90137]
# schedule: {90615, 90137, 90275, 90639}
# sections enrolled: 4
#
# student19(AT3):
# id: 19
# base_score: 300
# section ranking: [90048, 90817, 90012, 90734, 90595]
# schedule: {90048, 90817, 90595, 90734}
# sections enrolled: 4
#
# student20(ENG1):
# id: 20
# base_score: 100
# section ranking: [90791, 90348, 90387, 90833, 90647]
# schedule: {90833, 90348, 90647}
# sections enrolled: 3
#
# student21(HBR4):
# id: 21
# base_score: 400
# section ranking: [90600, 90020, 90372, 90617, 90358]
# schedule: {90600, 90617, 90020, 90372}
# sections enrolled: 4
#
# student22(PHY1):
# id: 22
# base_score: 100
# section ranking: [90450, 90330, 90666, 90132, 90097]
# schedule: {90666}
# sections enrolled: 1
#
# student23(GER1):
# id: 23
# base_score: 100
# section ranking: [90088, 90694, 90549, 90566, 90023]
# schedule: {90694, 90023}
# sections enrolled: 2
#
# student24(RUS5):
# id: 24
# base_score: 500
# section ranking: [90278, 90279, 90573, 90529, 90280]
# schedule: {90529, 90573, 90278, 90279}
# sections enrolled: 4
#
# student25(FYS3):
# id: 25
# base_score: 300
# section ranking: [90616, 90799, 90486, 90767, 90321]
# schedule: {90616, 90321, 90799}
# sections enrolled: 3
#
# student26(PAX1):
# id: 26
# base_score: 100
# section ranking: [90002, 90277, 90374, 90330, 90220]
# schedule: {90002}
# sections enrolled: 1
#
# student27(BOT3):
# id: 27
# base_score: 300
# section ranking: [90104, 90279, 90101, 90053, 90289]
# schedule: {90104, 90289, 90053}
# sections enrolled: 3
#
# student28(CHM5):
# id: 28
# base_score: 500
# section ranking: [90121, 90686, 90127, 90366, 90116]
# schedule: {90121, 90116, 90686, 90127}
# sections enrolled: 4
#
# student29(GWS2):
# id: 29
# base_score: 200
# section ranking: [90766, 90029, 90343, 90582, 90182]
# schedule: {90029, 90766, 90343}
# sections enrolled: 3
#
# student30(AST2):
# id: 30
# base_score: 200
# section ranking: [90057, 90058, 90367, 90056, 90053]
# schedule: {90053, 90367}
# sections enrolled: 2
#
# student31(HIS3):
# id: 31
# base_score: 300
# section ranking: [90051, 90641, 90294, 90626, 90612]
# schedule: {90641, 90612}
# sections enrolled: 2
#
# student32(HIS5):
# id: 32
# base_score: 500
# section ranking: [90136, 90803, 90621, 90305, 90059]
# schedule: {90136, 90305, 90803, 90621}
# sections enrolled: 4
#
# student33(PBH4):
# id: 33
# base_score: 400
# section ranking: [90047, 90375, 90376, 90024, 90021]
# schedule: {90376, 90375, 90024, 90047}
# sections enrolled: 4
#
# student34(PHE5):
# id: 34
# base_score: 500
# section ranking: [90307, 90358, 90614, 90359, 90208]
# schedule: {90208, 90307, 90358, 90614}
# sections enrolled: 4
#
# student35(DAT4):
# id: 35
# base_score: 400
# section ranking: [90167, 90218, 90169, 90346, 90811]
# schedule: {90169, 90218, 90346, 90167}
# sections enrolled: 4
#
# student36(PKP3):
# id: 36
# base_score: 300
# section ranking: [90327, 90206, 90639, 90588, 90478]
# schedule: {90478, 90206, 90639}
# sections enrolled: 3
#
# student37(ANT3):
# id: 37
# base_score: 300
# section ranking: [90560, 90751, 90181, 90104, 90018]
# schedule: {90560, 90104, 90181, 90751}
# sections enrolled: 4
#
# student38(CHM1):
# id: 38
# base_score: 100
# section ranking: [90615, 90129, 90046, 90123, 90575]
# schedule: {90123, 90046, 90615}
# sections enrolled: 3
#
# student39(ACC2):
# id: 39
# base_score: 200
# section ranking: [90002, 90003, 90556, 90242, 90145]
# schedule: {90002, 90003, 90556, 90242}
# sections enrolled: 4
#
# student40(AFR4):
# id: 40
# base_score: 400
# section ranking: [90718, 90278, 90616, 90241, 90569]
# schedule: {90616, 90241, 90569, 90718}
# sections enrolled: 4
#
# student41(PHY3):
# id: 41
# base_score: 300
# section ranking: [90331, 90336, 90279, 90274, 90332]
# schedule: {90336, 90274, 90331, 90279}
# sections enrolled: 4
#
# student42(CRE3):
# id: 42
# base_score: 300
# section ranking: [90387, 90016, 90829, 90623, 90291]
# schedule: {90016, 90387, 90829, 90623}
# sections enrolled: 4
#
# student43(FLM2):
# id: 43
# base_score: 200
# section ranking: [90206, 90316, 90295, 90296, 90547]
# schedule: {90206, 90295}
# sections enrolled: 2
#
# student44(AHI3):
# id: 44
# base_score: 300
# section ranking: [90017, 90520, 90796, 90013, 90004]
# schedule: {90520, 90017, 90796, 90013}
# sections enrolled: 4
#
# student45(THE3):
# id: 45
# base_score: 300
# section ranking: [90836, 90156, 90152, 90281, 90698]
# schedule: {90698, 90836, 90156}
# sections enrolled: 3
#
# student46(PSY1):
# id: 46
# base_score: 100
# section ranking: [90344, 90328, 90300, 90325, 90286]
# schedule: {90328, 90300}
# sections enrolled: 2
#
# student47(SJS3):
# id: 47
# base_score: 300
# section ranking: [90257, 90116, 90056, 90223, 90277]
# schedule: {90056, 90257, 90116, 90277}
# sections enrolled: 4
#
# student48(LAT5):
# id: 48
# base_score: 500
# section ranking: [90517, 90518, 90519, 90619, 90683]
# schedule: {90619, 90517, 90518, 90519}
# sections enrolled: 4
#
# student49(AHI2):
# id: 49
# base_score: 200
# section ranking: [90448, 90638, 90003, 90734, 90818]
# schedule: {90448, 90003, 90734}
# sections enrolled: 3
#
# student50(GWS2):
# id: 50
# base_score: 200
# section ranking: [90597, 90268, 90834, 90594, 90661]
# schedule: {90594, 90661, 90268, 90597}
# sections enrolled: 4
#
# student51(RUS4):
# id: 51
# base_score: 400
# section ranking: [90278, 90280, 90594, 90279, 90218]
# schedule: {90280, 90594, 90218}
# sections enrolled: 3
#
# student52(FDP3):
# id: 52
# base_score: 300
# section ranking: [90294, 90794, 90468, 90690, 90128]
# schedule: {90128, 90794, 90468, 90690}
# sections enrolled: 4
#
# student53(GOV5):
# id: 53
# base_score: 500
# section ranking: [90166, 90224, 90522, 90584, 90565]
# schedule: {90224, 90565, 90166, 90584}
# sections enrolled: 4
#
# student54(EAS5):
# id: 54
# base_score: 500
# section ranking: [90633, 90126, 90676, 90478, 90618]
# schedule: {90633, 90676, 90126}
# sections enrolled: 3
#
# student55(PHY3):
# id: 55
# base_score: 300
# section ranking: [90333, 90330, 90337, 90542, 90332]
# schedule: {90337, 90330, 90332, 90542}
# sections enrolled: 4
#
# student56(PKP1):
# id: 56
# base_score: 100
# section ranking: [90327, 90049, 90164, 90358, 90389]
# schedule: {90389}
# sections enrolled: 1
#
# student57(PHI5):
# id: 57
# base_score: 500
# section ranking: [90347, 90342, 90553, 90346, 90344]
# schedule: {90344, 90553, 90347, 90342}
# sections enrolled: 4
#
# student58(THE1):
# id: 58
# base_score: 100
# section ranking: [90690, 90152, 90836, 90160, 90180]
# schedule: {90836}
# sections enrolled: 1
#
# student59(BIO4):
# id: 59
# base_score: 400
# section ranking: [90271, 90078, 90324, 90028, 90301]
# schedule: {90028, 90301, 90271}
# sections enrolled: 3
#
# student60(DAN5):
# id: 60
# base_score: 500
# section ranking: [90611, 90549, 90530, 90825, 90022]
# schedule: {90825, 90611, 90549, 90022}
# sections enrolled: 4
#
# student61(ARA1):
# id: 61
# base_score: 100
# section ranking: [90289, 90032, 90225, 90033, 90679]
# schedule: {90225}
# sections enrolled: 1
#
# student62(SJS5):
# id: 62
# base_score: 500
# section ranking: [90277, 90287, 90688, 90003, 90106]
# schedule: {90688, 90003, 90277, 90287}
# sections enrolled: 4
#
# student63(PSY4):
# id: 63
# base_score: 400
# section ranking: [90318, 90736, 90322, 90285, 90756]
# schedule: {90322, 90756, 90285, 90318}
# sections enrolled: 4
#
# student64(PHE2):
# id: 64
# base_score: 200
# section ranking: [90352, 90349, 90121, 90308, 90264]
# schedule: {90352}
# sections enrolled: 1
#
# student65(AMS4):
# id: 65
# base_score: 400
# section ranking: [90151, 90512, 90837, 90011, 90342]
# schedule: {90512, 90837, 90151}
# sections enrolled: 3
#
# student66(BIO1):
# id: 66
# base_score: 100
# section ranking: [90576, 90071, 90315, 90306, 90092]
# schedule: {90306, 90315, 90071}
# sections enrolled: 3
#
# student67(BOT5):
# id: 67
# base_score: 500
# section ranking: [90617, 90702, 90308, 90776, 90106]
# schedule: {90617, 90106, 90308, 90702}
# sections enrolled: 4
#
# student68(DAN3):
# id: 68
# base_score: 300
# section ranking: [90185, 90323, 90301, 90183, 90204]
# schedule: {90185, 90323, 90301}
# sections enrolled: 3
#
# student69(ES3):
# id: 69
# base_score: 300
# section ranking: [90100, 90057, 90149, 90076, 90206]
# schedule: {90076, 90206}
# sections enrolled: 2
#
# student70(FYS2):
# id: 70
# base_score: 200
# section ranking: [90536, 90764, 90343, 90531, 90447]
# schedule: {90536, 90531, 90764, 90343}
# sections enrolled: 4
#
# student71(DAT3):
# id: 71
# base_score: 300
# section ranking: [90218, 90701, 90576, 90175, 90166]
# schedule: {90576, 90701, 90175}
# sections enrolled: 3
#
# student72(PAX1):
# id: 72
# base_score: 100
# section ranking: [90125, 90374, 90531, 90388, 90619]
# schedule: {90531, 90388, 90125}
# sections enrolled: 3
#
# student73(FRH4):
# id: 73
# base_score: 400
# section ranking: [90646, 90472, 90478, 90022, 90477]
# schedule: {90472, 90478, 90022, 90646}
# sections enrolled: 4
#
# student74(FDP1):
# id: 74
# base_score: 100
# section ranking: [90347, 90734, 90002, 90294, 90464]
# schedule: {90002, 90347}
# sections enrolled: 2
#
# student75(RUS3):
# id: 75
# base_score: 300
# section ranking: [90372, 90156, 90280, 90323, 90278]
# schedule: {90280, 90372, 90156}
# sections enrolled: 3
#
# student76(MAT1):
# id: 76
# base_score: 100
# section ranking: [90515, 90508, 90596, 90842, 90702]
# schedule: {90515}
# sections enrolled: 1
#
# student77(BIO1):
# id: 77
# base_score: 100
# section ranking: [90090, 90026, 90126, 90128, 90039]
# schedule: {90026, 90128, 90090, 90039}
# sections enrolled: 4
#
# student78(SOC3):
# id: 78
# base_score: 300
# section ranking: [90591, 90098, 90264, 90579, 90018]
# schedule: {90264, 90018, 90591}
# sections enrolled: 3
#
# student79(FDP1):
# id: 79
# base_score: 100
# section ranking: [90294, 90295, 90156, 90135, 90599]
# schedule: {90156, 90135, 90295}
# sections enrolled: 3
#
# student80(ASL1):
# id: 80
# base_score: 100
# section ranking: [90055, 90778, 90305, 90580, 90098]
# schedule: {90305}
# sections enrolled: 1
#
# student81(SJS3):
# id: 81
# base_score: 300
# section ranking: [90277, 90114, 90181, 90096, 90791]
# schedule: {90114, 90181, 90277}
# sections enrolled: 3
#
# student82(AMS4):
# id: 82
# base_score: 400
# section ranking: [90619, 90267, 90643, 90011, 90020]
# schedule: {90643, 90020, 90619, 90267}
# sections enrolled: 4
#
# student83(EDU4):
# id: 83
# base_score: 400
# section ranking: [90036, 90242, 90567, 90374, 90245]
# schedule: {90242, 90374, 90567}
# sections enrolled: 3
#
# student84(BOT3):
# id: 84
# base_score: 300
# section ranking: [90198, 90095, 90299, 90104, 90102]
# schedule: {90299, 90198, 90095}
# sections enrolled: 3
#
# student85(RUS5):
# id: 85
# base_score: 500
# section ranking: [90296, 90278, 90280, 90279, 90531]
# schedule: {90296, 90531, 90278, 90280}
# sections enrolled: 4
#
# student86(AFR5):
# id: 86
# base_score: 500
# section ranking: [90790, 90698, 90297, 90179, 90592]
# schedule: {90297, 90698, 90179, 90790}
# sections enrolled: 4
#
# student87(PHI4):
# id: 87
# base_score: 400
# section ranking: [90701, 90346, 90348, 90342, 90054]
# schedule: {90346, 90348, 90701, 90054}
# sections enrolled: 4
#
# student88(ES2):
# id: 88
# base_score: 200
# section ranking: [90767, 90277, 90257, 90217, 90127]
# schedule: {90257, 90217, 90767}
# sections enrolled: 3
#
# student89(PSY5):
# id: 89
# base_score: 500
# section ranking: [90325, 90113, 90547, 90311, 90322]
# schedule: {90113, 90547, 90325, 90311}
# sections enrolled: 4
#
# student90(ARA1):
# id: 90
# base_score: 100
# section ranking: [90248, 90153, 90032, 90179, 90033]
# schedule: {90153, 90179}
# sections enrolled: 2
#
# student91(BOT4):
# id: 91
# base_score: 400
# section ranking: [90104, 90101, 90756, 90095, 90103]
# schedule: {90104, 90103, 90756, 90095}
# sections enrolled: 4
#
# student92(JPN4):
# id: 92
# base_score: 400
# section ranking: [90116, 90616, 90553, 90281, 90554]
# schedule: {90616, 90553, 90281, 90116}
# sections enrolled: 4
#
# student93(BOT3):
# id: 93
# base_score: 300
# section ranking: [90093, 90649, 90039, 90106, 90102]
# schedule: {90649, 90093, 90039}
# sections enrolled: 3
#
# student94(ITL2):
# id: 94
# base_score: 200
# section ranking: [90652, 90560, 90287, 90562, 90764]
# schedule: {90764, 90562, 90652}
# sections enrolled: 3
#
# student95(GRK2):
# id: 95
# base_score: 200
# section ranking: [90292, 90682, 90577, 90670, 90575]
# schedule: {90682}
# sections enrolled: 1
#
# student96(ECO4):
# id: 96
# base_score: 400
# section ranking: [90012, 90028, 90855, 90226, 90269]
# schedule: {90028, 90012, 90226, 90855}
# sections enrolled: 4
#
# student97(SJS1):
# id: 97
# base_score: 100
# section ranking: [90277, 90206, 90107, 90099, 90100]
# schedule: {90206}
# sections enrolled: 1
#
# student98(PHY5):
# id: 98
# base_score: 500
# section ranking: [90328, 90332, 90630, 90278, 90136]
# schedule: {90328, 90136, 90332, 90278}
# sections enrolled: 4
#
# student99(ANT3):
# id: 99
# base_score: 300
# section ranking: [90598, 90797, 90100, 90188, 90181]
# schedule: {90181, 90188, 90797, 90598}
# sections enrolled: 4
#
# student100(AMS1):
# id: 100
# base_score: 100
# section ranking: [90303, 90684, 90011, 90257, 90623]
# schedule: {90257, 90303}
# sections enrolled: 2
#
# student101(NEU5):
# id: 101
# base_score: 500
# section ranking: [90302, 90308, 90287, 90529, 90790]
# schedule: {90529, 90790, 90302, 90287}
# sections enrolled: 4
#
# student102(PHI2):
# id: 102
# base_score: 200
# section ranking: [90320, 90774, 90578, 90347, 90348]
# schedule: {90320, 90578, 90347, 90774}
# sections enrolled: 4
#
# student103(PBH1):
# id: 103
# base_score: 100
# section ranking: [90376, 90375, 90609, 90566, 90622]
# schedule: {90609}
# sections enrolled: 1
#
# student104(ACC1):
# id: 104
# base_score: 100
# section ranking: [90232, 90630, 90589, 90003, 90002]
# schedule: {90232, 90002, 90589, 90630}
# sections enrolled: 4
#
# student105(PAX5):
# id: 105
# base_score: 500
# section ranking: [90374, 90206, 90464, 90226, 90479]
# schedule: {90464, 90206, 90374, 90479}
# sections enrolled: 4
#
# student106(ES2):
# id: 106
# base_score: 200
# section ranking: [90364, 90483, 90569, 90783, 90036]
# schedule: {90569, 90483, 90364, 90783}
# sections enrolled: 4
#
# student107(THE5):
# id: 107
# base_score: 500
# section ranking: [90792, 90156, 90341, 90160, 90152]
# schedule: {90792, 90160, 90156, 90341}
# sections enrolled: 4
#
# student108(BIO4):
# id: 108
# base_score: 400
# section ranking: [90084, 90815, 90674, 90104, 90676]
# schedule: {90084, 90676}
# sections enrolled: 2
#
# student111(JPN4):
# id: 111
# base_score: 400
# section ranking: [90668, 90450, 90299, 90141, 90111]
# schedule: {90450, 90299, 90668, 90141}
# sections enrolled: 4
#
# student112(ACC5):
# id: 112
# base_score: 500
# section ranking: [90002, 90312, 90003, 90273, 90772]
# schedule: {90312, 90273, 90002, 90003}
# sections enrolled: 4
#
# student113(ARC3):
# id: 113
# base_score: 300
# section ranking: [90579, 90494, 90035, 90842, 90451]
# schedule: {90579, 90494}
# sections enrolled: 2
#
# student114(GWS1):
# id: 114
# base_score: 100
# section ranking: [90595, 90834, 90655, 90642, 90585]
# schedule: {90585, 90595, 90655}
# sections enrolled: 3
#
# student115(ANT2):
# id: 115
# base_score: 200
# section ranking: [90804, 90598, 90029, 90467, 90006]
# schedule: {90467, 90804, 90029, 90598}
# sections enrolled: 4
#
# student116(RUS2):
# id: 116
# base_score: 200
# section ranking: [90566, 90648, 90327, 90280, 90279]
# schedule: {90648}
# sections enrolled: 1
#
# student117(PAX5):
# id: 117
# base_score: 500
# section ranking: [90355, 90374, 90650, 90250, 90816]
# schedule: {90650, 90355, 90374, 90250}
# sections enrolled: 4
#
# student118(MAT1):
# id: 118
# base_score: 100
# section ranking: [90139, 90518, 90326, 90266, 90500]
# schedule: {90266, 90139, 90500, 90326}
# sections enrolled: 4
#
# student119(MSM1):
# id: 119
# base_score: 100
# section ranking: [90220, 90014, 90203, 90120, 90676]
# schedule: {90120, 90676}
# sections enrolled: 2
#
# student120(RUS4):
# id: 120
# base_score: 400
# section ranking: [90485, 90185, 90278, 90153, 90332]
# schedule: {90185, 90332, 90485, 90153}
# sections enrolled: 4
#
# student121(SJS5):
# id: 121
# base_score: 500
# section ranking: [90101, 90277, 90227, 90307, 90240]
# schedule: {90227, 90101, 90307, 90277}
# sections enrolled: 4
#
# student122(SPA1):
# id: 122
# base_score: 100
# section ranking: [90855, 90637, 90216, 90111, 90214]
# schedule: {90216, 90111, 90637, 90855}
# sections enrolled: 4
#
# student123(ENT1):
# id: 123
# base_score: 100
# section ranking: [90248, 90699, 90160, 90247, 90559]
# schedule: {90699, 90559}
# sections enrolled: 2
#
# student124(BOT2):
# id: 124
# base_score: 200
# section ranking: [90733, 90252, 90104, 90241, 90132]
# schedule: {90104, 90252, 90132}
# sections enrolled: 3
#
# student125(AST2):
# id: 125
# base_score: 200
# section ranking: [90057, 90058, 90802, 90308, 90056]
# schedule: {90802, 90308}
# sections enrolled: 2
#
# student126(AMS4):
# id: 126
# base_score: 400
# section ranking: [90011, 90609, 90654, 90130, 90659]
# schedule: {90659, 90130, 90011, 90654}
# sections enrolled: 4
#
# student127(FYS2):
# id: 127
# base_score: 200
# section ranking: [90797, 90770, 90168, 90296, 90571]
# schedule: {90797}
# sections enrolled: 1
#
# student128(COM4):
# id: 128
# base_score: 400
# section ranking: [90148, 90146, 90462, 90773, 90531]
# schedule: {90146, 90531, 90148}
# sections enrolled: 3
#
# student129(ARC5):
# id: 129
# base_score: 500
# section ranking: [90035, 90767, 90016, 90822, 90267]
# schedule: {90016, 90035, 90822, 90767}
# sections enrolled: 4
#
# student130(HIS4):
# id: 130
# base_score: 400
# section ranking: [90616, 90507, 90607, 90612, 90545]
# schedule: {90616, 90507, 90612, 90607}
# sections enrolled: 4
#
# student132(PHI5):
# id: 132
# base_score: 500
# section ranking: [90278, 90344, 90342, 90572, 90027]
# schedule: {90344, 90027, 90572, 90278}
# sections enrolled: 4
#
# student133(AT1):
# id: 133
# base_score: 100
# section ranking: [90075, 90223, 90011, 90528, 90060]
# schedule: {90075, 90011, 90223}
# sections enrolled: 3
#
# student134(DAT4):
# id: 134
# base_score: 400
# section ranking: [90235, 90038, 90218, 90031, 90476]
# schedule: {90218, 90235, 90476, 90038}
# sections enrolled: 4
#
# student135(AHI2):
# id: 135
# base_score: 200
# section ranking: [90634, 90639, 90157, 90799, 90823]
# schedule: {90634, 90157, 90799}
# sections enrolled: 3
#
# student136(AMS3):
# id: 136
# base_score: 300
# section ranking: [90837, 90349, 90533, 90026, 90672]
# schedule: {90026, 90837, 90533}
# sections enrolled: 3
#
# student137(EAS1):
# id: 137
# base_score: 100
# section ranking: [90149, 90851, 90510, 90220, 90633]
# schedule: {90851, 90510}
# sections enrolled: 2
#
# student138(EAS2):
# id: 138
# base_score: 200
# section ranking: [90220, 90219, 90633, 90675, 90464]
# schedule: {90219}
# sections enrolled: 1
#
# student139(LAT1):
# id: 139
# base_score: 100
# section ranking: [90167, 90694, 90683, 90518, 90810]
# schedule: {90683, 90694, 90167}
# sections enrolled: 3
#
# student140(CRT5):
# id: 140
# base_score: 500
# section ranking: [90025, 90168, 90774, 90548, 90031]
# schedule: {90168, 90025, 90548, 90774}
# sections enrolled: 4
#
# student141(ASL3):
# id: 141
# base_score: 300
# section ranking: [90077, 90150, 90778, 90055, 90567]
# schedule: {90077, 90150}
# sections enrolled: 2
#
# student142(DAT5):
# id: 142
# base_score: 500
# section ranking: [90624, 90125, 90447, 90218, 90478]
# schedule: {90624, 90218, 90125}
# sections enrolled: 3
#
# student143(ART5):
# id: 143
# base_score: 500
# section ranking: [90036, 90054, 90816, 90038, 90472]
# schedule: {90816, 90036, 90054, 90038}
# sections enrolled: 4
#
# student144(ANT5):
# id: 144
# base_score: 500
# section ranking: [90580, 90027, 90098, 90829, 90683]
# schedule: {90098, 90027, 90580, 90829}
# sections enrolled: 4
#
# student145(PSY5):
# id: 145
# base_score: 500
# section ranking: [90756, 90040, 90773, 90736, 90788]
# schedule: {90040, 90736, 90756, 90773}
# sections enrolled: 4
#
# student146(SOC3):
# id: 146
# base_score: 300
# section ranking: [90550, 90184, 90274, 90658, 90273]
# schedule: {90184, 90273, 90658, 90550}
# sections enrolled: 4
#
# student147(FDP1):
# id: 147
# base_score: 100
# section ranking: [90294, 90214, 90484, 90486, 90358]
# schedule: {90486, 90214}
# sections enrolled: 2
#
# student148(JS4):
# id: 148
# base_score: 400
# section ranking: [90345, 90250, 90551, 90353, 90642]
# schedule: {90345, 90250, 90551}
# sections enrolled: 3
#
# student149(PHE3):
# id: 149
# base_score: 300
# section ranking: [90177, 90365, 90355, 90643, 90023]
# schedule: {90643, 90177, 90355, 90365}
# sections enrolled: 4
#
# student150(RUS4):
# id: 150
# base_score: 400
# section ranking: [90279, 90280, 90278, 90323, 90290]
# schedule: {90290, 90323, 90279}
# sections enrolled: 3
#
# student151(AMS2):
# id: 151
# base_score: 200
# section ranking: [90488, 90837, 90623, 90303, 90654]
# schedule: {90837, 90303}
# sections enrolled: 2
#
# student152(ENT5):
# id: 152
# base_score: 500
# section ranking: [90248, 90247, 90654, 90661, 90322]
# schedule: {90248, 90322, 90661, 90247}
# sections enrolled: 4
#
# student153(HIS2):
# id: 153
# base_score: 200
# section ranking: [90608, 90612, 90590, 90621, 90566]
# schedule: {90608, 90612, 90621}
# sections enrolled: 3
#
# student154(ASL4):
# id: 154
# base_score: 400
# section ranking: [90778, 90055, 90669, 90260, 90271]
# schedule: {90271, 90669, 90055}
# sections enrolled: 3
#
# student155(IS5):
# id: 155
# base_score: 500
# section ranking: [90573, 90122, 90571, 90352, 90563]
# schedule: {90122, 90571, 90573, 90563}
# sections enrolled: 4
#
# student156(GC2):
# id: 156
# base_score: 200
# section ranking: [90192, 90488, 90258, 90237, 90130]
# schedule: {90258, 90237}
# sections enrolled: 2
#
# student157(EDU3):
# id: 157
# base_score: 300
# section ranking: [90245, 90681, 90244, 90246, 90242]
# schedule: {90681, 90242, 90244, 90245}
# sections enrolled: 4
#
# student159(HBR5):
# id: 159
# base_score: 500
# section ranking: [90600, 90245, 90464, 90014, 90387]
# schedule: {90600, 90387, 90464}
# sections enrolled: 3
#
# student160(HBR2):
# id: 160
# base_score: 200
# section ranking: [90389, 90558, 90600, 90241, 90184]
# schedule: {90184, 90241, 90389, 90558}
# sections enrolled: 4
#
# student161(PAX4):
# id: 161
# base_score: 400
# section ranking: [90374, 90690, 90491, 90173, 90389]
# schedule: {90690, 90491, 90389, 90374}
# sections enrolled: 4
#
# student162(ENG4):
# id: 162
# base_score: 400
# section ranking: [90833, 90664, 90666, 90651, 90274]
# schedule: {90664, 90833, 90666, 90274}
# sections enrolled: 4
#
# student163(GC1):
# id: 163
# base_score: 100
# section ranking: [90488, 90244, 90336, 90591, 90788]
# schedule: {90244, 90591}
# sections enrolled: 2
#
# student164(PHE2):
# id: 164
# base_score: 200
# section ranking: [90349, 90027, 90367, 90537, 90358]
# schedule: {90367}
# sections enrolled: 1
#
# student165(HMD1):
# id: 165
# base_score: 100
# section ranking: [90590, 90250, 90574, 90583, 90509]
# schedule: {90250, 90509, 90574}
# sections enrolled: 3
#
# student166(FLM2):
# id: 166
# base_score: 200
# section ranking: [90225, 90696, 90295, 90802, 90614]
# schedule: {90225, 90802, 90295}
# sections enrolled: 3
#
# student167(HIS3):
# id: 167
# base_score: 300
# section ranking: [90593, 90621, 90595, 90688, 90192]
# schedule: {90688, 90593, 90595, 90192}
# sections enrolled: 4
#
# student168(GIS2):
# id: 168
# base_score: 200
# section ranking: [90269, 90620, 90535, 90328, 90262]
# schedule: {90262, 90535}
# sections enrolled: 2
#
# student169(DAN5):
# id: 169
# base_score: 500
# section ranking: [90312, 90184, 90697, 90462, 90203]
# schedule: {90312, 90697, 90203, 90184}
# sections enrolled: 4
#
# student170(GIS4):
# id: 170
# base_score: 400
# section ranking: [90766, 90036, 90144, 90535, 90620]
# schedule: {90144, 90036, 90766, 90535}
# sections enrolled: 4
#
# student171(THE3):
# id: 171
# base_score: 300
# section ranking: [90189, 90102, 90817, 90607, 90599]
# schedule: {90817, 90189, 90599}
# sections enrolled: 3
#
# student172(PHE5):
# id: 172
# base_score: 500
# section ranking: [90219, 90023, 90160, 90682, 90653]
# schedule: {90219, 90653, 90023}
# sections enrolled: 3
#
# student173(PHY3):
# id: 173
# base_score: 300
# section ranking: [90138, 90626, 90329, 90802, 90140]
# schedule: {90802, 90329, 90138, 90140}
# sections enrolled: 4
#
# student174(GOV5):
# id: 174
# base_score: 500
# section ranking: [90538, 90564, 90521, 90122, 90783]
# schedule: {90521, 90538, 90564, 90783}
# sections enrolled: 4
#
# student175(STA5):
# id: 175
# base_score: 500
# section ranking: [90354, 90196, 90193, 90768, 90192]
# schedule: {90768, 90193, 90354, 90196}
# sections enrolled: 4
#
# student176(AHI2):
# id: 176
# base_score: 200
# section ranking: [90680, 90005, 90235, 90823, 90103]
# schedule: {90235, 90005}
# sections enrolled: 2
#
# student177(STA2):
# id: 177
# base_score: 200
# section ranking: [90195, 90194, 90480, 90196, 90084]
# schedule: {90480, 90195, 90084}
# sections enrolled: 3
#
# student178(IS2):
# id: 178
# base_score: 200
# section ranking: [90573, 90571, 90513, 90563, 90229]
# schedule: {90513, 90563, 90229}
# sections enrolled: 3
#
# student179(NEU4):
# id: 179
# base_score: 400
# section ranking: [90321, 90287, 90146, 90518, 90308]
# schedule: {90321, 90146, 90308, 90287}
# sections enrolled: 4
#
# student180(DAN3):
# id: 180
# base_score: 300
# section ranking: [90169, 90292, 90098, 90183, 90171]
# schedule: {90169, 90098, 90292, 90183}
# sections enrolled: 4
#
# student181(GEO1):
# id: 181
# base_score: 100
# section ranking: [90260, 90622, 90254, 90033, 90592]
# schedule: {90622}
# sections enrolled: 1
#
# student182(ITL1):
# id: 182
# base_score: 100
# section ranking: [90560, 90599, 90565, 90598, 90563]
# schedule: {90560, 90563, 90565, 90599}
# sections enrolled: 4
#
# student183(JPN3):
# id: 183
# base_score: 300
# section ranking: [90553, 90552, 90555, 90593, 90554]
# schedule: {90593, 90554}
# sections enrolled: 2
#
# student184(FDP1):
# id: 184
# base_score: 100
# section ranking: [90294, 90224, 90275, 90116, 90204]
# schedule: {90224, 90275, 90116, 90204}
# sections enrolled: 4
#
# student185(ASL3):
# id: 185
# base_score: 300
# section ranking: [90778, 90055, 90618, 90303, 90297]
# schedule: {90618, 90303}
# sections enrolled: 2
#
# student186(GER4):
# id: 186
# base_score: 400
# section ranking: [90171, 90205, 90359, 90219, 90502]
# schedule: {90171, 90205, 90502, 90359}
# sections enrolled: 4
#
# student187(PHI4):
# id: 187
# base_score: 400
# section ranking: [90346, 90086, 90542, 90025, 90341]
# schedule: {90025, 90346, 90341, 90542}
# sections enrolled: 4
#
# student188(AHI3):
# id: 188
# base_score: 300
# section ranking: [90475, 90180, 90819, 90157, 90004]
# schedule: {90475, 90004, 90157, 90819}
# sections enrolled: 4
#
# student189(GRK2):
# id: 189
# base_score: 200
# section ranking: [90577, 90170, 90659, 90580, 90336]
# schedule: {90170, 90659, 90580}
# sections enrolled: 3
#
# student190(ENG4):
# id: 190
# base_score: 400
# section ranking: [90650, 90136, 90319, 90656, 90788]
# schedule: {90136, 90650, 90788, 90319}
# sections enrolled: 4
#
# student191(AT3):
# id: 191
# base_score: 300
# section ranking: [90059, 90639, 90060, 90012, 90682]
# schedule: {90682, 90012, 90639}
# sections enrolled: 3
#
# student192(ANT3):
# id: 192
# base_score: 300
# section ranking: [90598, 90025, 90642, 90702, 90024]
# schedule: {90025, 90642, 90598, 90702}
# sections enrolled: 4
#
# student193(MRC2):
# id: 193
# base_score: 200
# section ranking: [90491, 90040, 90094, 90286, 90482]
# schedule: {90040, 90482, 90286}
# sections enrolled: 3
#
# student194(DAN2):
# id: 194
# base_score: 200
# section ranking: [90122, 90338, 90449, 90197, 90127]
# schedule: {90122, 90338, 90197}
# sections enrolled: 3
#
# student195(PHE1):
# id: 195
# base_score: 100
# section ranking: [90355, 90342, 90569, 90358, 90592]
# schedule: {90592, 90569, 90355, 90342}
# sections enrolled: 4
#
# student196(CHI4):
# id: 196
# base_score: 400
# section ranking: [90129, 90673, 90301, 90630, 90241]
# schedule: {90129, 90301, 90673}
# sections enrolled: 3
#
# student197(STA4):
# id: 197
# base_score: 400
# section ranking: [90855, 90208, 90554, 90788, 90734]
# schedule: {90208, 90554, 90855}
# sections enrolled: 3
#
# student198(GWS5):
# id: 198
# base_score: 500
# section ranking: [90764, 90736, 90792, 90203, 90842]
# schedule: {90736, 90842, 90764, 90792}
# sections enrolled: 4
#
# student199(ACC1):
# id: 199
# base_score: 100
# section ranking: [90643, 90071, 90003, 90002, 90484]
# schedule: {90002, 90643, 90003, 90071}
# sections enrolled: 4
#
# student200(GRK4):
# id: 200
# base_score: 400
# section ranking: [90353, 90580, 90632, 90131, 90674]
# schedule: {90632, 90674, 90131, 90580}
# sections enrolled: 4
#
# student201(CRT5):
# id: 201
# base_score: 500
# section ranking: [90626, 90594, 90168, 90836, 90814]
# schedule: {90168, 90626, 90594, 90836}
# sections enrolled: 4
#
# student202(GWS5):
# id: 202
# base_score: 500
# section ranking: [90655, 90754, 90657, 90343, 90030]
# schedule: {90657, 90754, 90030, 90655}
# sections enrolled: 4
#
# student203(STA2):
# id: 203
# base_score: 200
# section ranking: [90196, 90193, 90247, 90056, 90447]
# schedule: {90447}
# sections enrolled: 1
#
# student204(SOC3):
# id: 204
# base_score: 300
# section ranking: [90262, 90704, 90631, 90273, 90139]
# schedule: {90704, 90139, 90262, 90631}
# sections enrolled: 4
#
# student205(PKP4):
# id: 205
# base_score: 400
# section ranking: [90471, 90203, 90694, 90097, 90650]
# schedule: {90097, 90203, 90694, 90471}
# sections enrolled: 4
#
# student206(SPA4):
# id: 206
# base_score: 400
# section ranking: [90770, 90100, 90804, 90713, 90851]
# schedule: {90713, 90770, 90804, 90100}
# sections enrolled: 4
#
# student207(CRE1):
# id: 207
# base_score: 100
# section ranking: [90636, 90639, 90095, 90307, 90374]
# schedule: {90307, 90636, 90095}
# sections enrolled: 3
#
# student208(AHI4):
# id: 208
# base_score: 400
# section ranking: [90009, 90634, 90333, 90041, 90005]
# schedule: {90009, 90634, 90041, 90333}
# sections enrolled: 4
#
# student209(MSM5):
# id: 209
# base_score: 500
# section ranking: [90286, 90014, 90736, 90181, 90451]
# schedule: {90181, 90286}
# sections enrolled: 2
#
# student210(ES1):
# id: 210
# base_score: 100
# section ranking: [90293, 90587, 90026, 90791, 90673]
# schedule: {90293}
# sections enrolled: 1
#
# student211(GRK1):
# id: 211
# base_score: 100
# section ranking: [90501, 90044, 90341, 90575, 90816]
# schedule: {90816, 90341, 90501}
# sections enrolled: 3
#
# student212(CLA2):
# id: 212
# base_score: 200
# section ranking: [90135, 90138, 90598, 90502, 90137]
# schedule: {90137, 90598, 90135}
# sections enrolled: 3
#
# student213(AMS2):
# id: 213
# base_score: 200
# section ranking: [90842, 90204, 90151, 90269, 90734]
# schedule: {90204, 90734, 90151}
# sections enrolled: 3
#
# student214(SJS3):
# id: 214
# base_score: 300
# section ranking: [90277, 90611, 90524, 90266, 90581]
# schedule: {90581, 90611, 90524, 90277}
# sections enrolled: 4
#
# student215(GEO2):
# id: 215
# base_score: 200
# section ranking: [90254, 90289, 90247, 90260, 90252]
# schedule: {90252}
# sections enrolled: 1
#
# student216(MUS1):
# id: 216
# base_score: 100
# section ranking: [90463, 90464, 90607, 90469, 90491]
# schedule: {90469, 90463}
# sections enrolled: 2
#
# student217(FDP2):
# id: 217
# base_score: 200
# section ranking: [90294, 90559, 90252, 90842, 90578]
# schedule: {90578, 90252, 90559}
# sections enrolled: 3
#
# student218(IS4):
# id: 218
# base_score: 400
# section ranking: [90647, 90026, 90237, 90093, 90083]
# schedule: {90093, 90026, 90237, 90647}
# sections enrolled: 4
#
# student219(LA2):
# id: 219
# base_score: 200
# section ranking: [90558, 90545, 90074, 90820, 90167]
# schedule: {90545, 90074, 90820, 90558}
# sections enrolled: 4
#
# student220(SOC5):
# id: 220
# base_score: 500
# section ranking: [90270, 90261, 90765, 90175, 90262]
# schedule: {90175, 90261, 90270, 90765}
# sections enrolled: 4
#
# student221(FRH1):
# id: 221
# base_score: 100
# section ranking: [90476, 90478, 90627, 90477, 90473]
# schedule: {90477}
# sections enrolled: 1
#
# student222(CRT4):
# id: 222
# base_score: 400
# section ranking: [90476, 90194, 90010, 90051, 90168]
# schedule: {90168, 90194, 90051, 90476}
# sections enrolled: 4
#
# student223(LA1):
# id: 223
# base_score: 100
# section ranking: [90538, 90140, 90820, 90274, 90099]
# schedule: {90274, 90099, 90820}
# sections enrolled: 3
#
# student224(ES1):
# id: 224
# base_score: 100
# section ranking: [90312, 90288, 90341, 90694, 90810]
# schedule: {90312, 90810, 90341, 90694}
# sections enrolled: 4
#
# student225(AMS4):
# id: 225
# base_score: 400
# section ranking: [90855, 90654, 90659, 90485, 90164]
# schedule: {90659, 90164, 90654, 90855}
# sections enrolled: 4
#
# student226(HIS4):
# id: 226
# base_score: 400
# section ranking: [90621, 90152, 90164, 90612, 90607]
# schedule: {90612, 90164, 90621}
# sections enrolled: 3
#
# student227(PHI3):
# id: 227
# base_score: 300
# section ranking: [90160, 90040, 90348, 90346, 90344]
# schedule: {90040, 90344, 90346, 90348}
# sections enrolled: 4
#
# student228(GRK5):
# id: 228
# base_score: 500
# section ranking: [90312, 90077, 90577, 90575, 90532]
# schedule: {90312, 90577, 90532, 90575}
# sections enrolled: 4
#
# student229(BOT1):
# id: 229
# base_score: 100
# section ranking: [90466, 90105, 90525, 90103, 90101]
# schedule: {90466, 90525}
# sections enrolled: 2
#
# student230(LIN2):
# id: 230
# base_score: 200
# section ranking: [90354, 90792, 90516, 90684, 90025]
# schedule: {90792, 90516}
# sections enrolled: 2
#
# student231(PHI5):
# id: 231
# base_score: 500
# section ranking: [90338, 90347, 90260, 90572, 90819]
# schedule: {90572, 90338, 90347, 90260}
# sections enrolled: 4
#
# student232(COM3):
# id: 232
# base_score: 300
# section ranking: [90277, 90147, 90145, 90049, 90143]
# schedule: {90145, 90147, 90277}
# sections enrolled: 3
#
# student233(SOC2):
# id: 233
# base_score: 200
# section ranking: [90270, 90216, 90118, 90591, 90177]
# schedule: {90216, 90177, 90591}
# sections enrolled: 3
#
# student234(CLA2):
# id: 234
# base_score: 200
# section ranking: [90094, 90292, 90342, 90138, 90010]
# schedule: {90094, 90342}
# sections enrolled: 2
#
# student235(MAT2):
# id: 235
# base_score: 200
# section ranking: [90671, 90475, 90508, 90499, 90516]
# schedule: {90516, 90499, 90508, 90671}
# sections enrolled: 4
#
# student236(NEU4):
# id: 236
# base_score: 400
# section ranking: [90575, 90164, 90308, 90302, 90193]
# schedule: {90193, 90308, 90164, 90575}
# sections enrolled: 4
#
# student237(MRC1):
# id: 237
# base_score: 100
# section ranking: [90491, 90642, 90562, 90236, 90756]
# schedule: {90756, 90236}
# sections enrolled: 2
#
# student238(ACC5):
# id: 238
# base_score: 500
# section ranking: [90783, 90791, 90002, 90003, 90342]
# schedule: {90003, 90783}
# sections enrolled: 2
#
# student239(AT5):
# id: 239
# base_score: 500
# section ranking: [90673, 90149, 90048, 90451, 90296]
# schedule: {90048, 90673, 90296}
# sections enrolled: 3
#
# student240(PHE5):
# id: 240
# base_score: 500
# section ranking: [90288, 90371, 90354, 90363, 90353]
# schedule: {90288, 90353, 90371, 90363}
# sections enrolled: 4
#
# student241(ES4):
# id: 241
# base_score: 400
# section ranking: [90100, 90251, 90026, 90253, 90626]
# schedule: {90626, 90251, 90100, 90253}
# sections enrolled: 4
#
# student242(LIN3):
# id: 242
# base_score: 300
# section ranking: [90684, 90516, 90035, 90218, 90332]
# schedule: {90516, 90684}
# sections enrolled: 2
#
# student243(DAT5):
# id: 243
# base_score: 500
# section ranking: [90060, 90218, 90667, 90596, 90855]
# schedule: {90218, 90667, 90060, 90596}
# sections enrolled: 4
#
# student244(GC4):
# id: 244
# base_score: 400
# section ranking: [90488, 90343, 90589, 90668, 90294]
# schedule: {90488, 90668, 90589, 90343}
# sections enrolled: 4
#
# student245(FRH1):
# id: 245
# base_score: 100
# section ranking: [90768, 90517, 90776, 90472, 90478]
# schedule: {90776}
# sections enrolled: 1
#
# student246(ART2):
# id: 246
# base_score: 200
# section ranking: [90816, 90500, 90543, 90658, 90054]
# schedule: {90816, 90500, 90543}
# sections enrolled: 3
#
# student247(ARC1):
# id: 247
# base_score: 100
# section ranking: [90327, 90288, 90035, 90822, 90642]
# schedule: {90822}
# sections enrolled: 1
#
# student248(LA3):
# id: 248
# base_score: 300
# section ranking: [90541, 90538, 90544, 90519, 90823]
# schedule: {90544, 90538, 90541, 90823}
# sections enrolled: 4
#
# student249(STA3):
# id: 249
# base_score: 300
# section ranking: [90573, 90192, 90193, 90196, 90194]
# schedule: {90192, 90193, 90194, 90573}
# sections enrolled: 4
#
# student250(LAT5):
# id: 250
# base_score: 500
# section ranking: [90291, 90683, 90156, 90518, 90517]
# schedule: {90683, 90291, 90156, 90518}
# sections enrolled: 4
#
# student251(ES1):
# id: 251
# base_score: 100
# section ranking: [90051, 90536, 90293, 90538, 90195]
# schedule: {90293}
# sections enrolled: 1
#
# student252(PKP3):
# id: 252
# base_score: 300
# section ranking: [90327, 90317, 90187, 90183, 90516]
# schedule: {90187, 90317, 90183}
# sections enrolled: 3
#
# student253(CRE5):
# id: 253
# base_score: 500
# section ranking: [90021, 90218, 90540, 90794, 90599]
# schedule: {90794, 90218, 90540, 90021}
# sections enrolled: 4
#
# student254(HIS2):
# id: 254
# base_score: 200
# section ranking: [90014, 90826, 90612, 90626, 90616]
# schedule: {90616, 90826, 90612}
# sections enrolled: 3
#
# student255(IS2):
# id: 255
# base_score: 200
# section ranking: [90571, 90573, 90214, 90366, 90306]
# schedule: {90214, 90366}
# sections enrolled: 2
#
# student256(PKP4):
# id: 256
# base_score: 400
# section ranking: [90327, 90799, 90148, 90616, 90648]
# schedule: {90616, 90799, 90148, 90327}
# sections enrolled: 4
#
# student257(ACC4):
# id: 257
# base_score: 400
# section ranking: [90002, 90152, 90003, 90222, 90609]
# schedule: {90152, 90002, 90003}
# sections enrolled: 3
#
# student258(GER4):
# id: 258
# base_score: 400
# section ranking: [90024, 90636, 90303, 90484, 90502]
# schedule: {90024, 90484, 90636, 90303}
# sections enrolled: 4
#
# student259(JS1):
# id: 259
# base_score: 100
# section ranking: [90448, 90551, 90348, 90642, 90345]
# schedule: {90448, 90348}
# sections enrolled: 2
#
# student260(DAT3):
# id: 260
# base_score: 300
# section ranking: [90166, 90653, 90218, 90733, 90273]
# schedule: {90273, 90733, 90166, 90653}
# sections enrolled: 4
#
# student261(BIO3):
# id: 261
# base_score: 300
# section ranking: [90468, 90073, 90658, 90090, 90567]
# schedule: {90073, 90658, 90468, 90090}
# sections enrolled: 4
#
# student262(ARC2):
# id: 262
# base_score: 200
# section ranking: [90822, 90034, 90035, 90842, 90010]
# schedule: {90822}
# sections enrolled: 1
#
# student263(PSY1):
# id: 263
# base_score: 100
# section ranking: [90623, 90317, 90224, 90326, 90736]
# schedule: {90224, 90317}
# sections enrolled: 2
#
# student264(STA2):
# id: 264
# base_score: 200
# section ranking: [90028, 90193, 90194, 90192, 90312]
# schedule: {90312}
# sections enrolled: 1
#
# student265(BIO3):
# id: 265
# base_score: 300
# section ranking: [90083, 90087, 90082, 90265, 90079]
# schedule: {90082, 90083, 90079, 90087}
# sections enrolled: 4
#
# student266(CRT3):
# id: 266
# base_score: 300
# section ranking: [90168, 90199, 90497, 90247, 90795]
# schedule: {90497, 90795, 90199}
# sections enrolled: 3
#
# student267(PKP3):
# id: 267
# base_score: 300
# section ranking: [90327, 90056, 90566, 90100, 90643]
# schedule: {90056, 90643, 90566}
# sections enrolled: 3
#
# student268(ASL2):
# id: 268
# base_score: 200
# section ranking: [90778, 90055, 90607, 90627, 90017]
# schedule: {90017, 90627, 90607}
# sections enrolled: 3
#
# student269(ASL2):
# id: 269
# base_score: 200
# section ranking: [90150, 90545, 90718, 90055, 90778]
# schedule: {90545, 90718}
# sections enrolled: 2
#
# student270(ECO3):
# id: 270
# base_score: 300
# section ranking: [90560, 90271, 90819, 90298, 90287]
# schedule: {90560, 90819, 90271}
# sections enrolled: 3
#
# student271(SOC1):
# id: 271
# base_score: 100
# section ranking: [90619, 90261, 90629, 90630, 90020]
# schedule: {90619, 90020, 90261, 90630}
# sections enrolled: 4
#
# student272(PHI5):
# id: 272
# base_score: 500
# section ranking: [90338, 90182, 90572, 90344, 90352]
# schedule: {90344, 90338, 90572, 90182}
# sections enrolled: 4
#
# student273(JS5):
# id: 273
# base_score: 500
# section ranking: [90268, 90642, 90564, 90551, 90345]
# schedule: {90345, 90642, 90564, 90268}
# sections enrolled: 4
#
# student274(ARA4):
# id: 274
# base_score: 400
# section ranking: [90033, 90258, 90635, 90032, 90463]
# schedule: {90032, 90258, 90635}
# sections enrolled: 3
#
# student275(ENT3):
# id: 275
# base_score: 300
# section ranking: [90764, 90248, 90198, 90247, 90181]
# schedule: {90764, 90181, 90198}
# sections enrolled: 3
#
# student276(HIS1):
# id: 276
# base_score: 100
# section ranking: [90619, 90626, 90672, 90597, 90607]
# schedule: {90619, 90597}
# sections enrolled: 2
#
# student277(ARC3):
# id: 277
# base_score: 300
# section ranking: [90136, 90344, 90016, 90289, 90822]
# schedule: {90136, 90344, 90822, 90016}
# sections enrolled: 4
#
# student278(PHE3):
# id: 278
# base_score: 300
# section ranking: [90355, 90352, 90358, 90366, 90353]
# schedule: {90352, 90355}
# sections enrolled: 2
#
# student279(HIS2):
# id: 279
# base_score: 200
# section ranking: [90783, 90510, 90622, 90259, 90017]
# schedule: {90017, 90510, 90783}
# sections enrolled: 3
#
# student280(GC2):
# id: 280
# base_score: 200
# section ranking: [90488, 90484, 90567, 90528, 90020]
# schedule: {90528, 90020, 90484, 90567}
# sections enrolled: 4
#
# student281(HMD2):
# id: 281
# base_score: 200
# section ranking: [90578, 90590, 90579, 90292, 90027]
# schedule: {90578, 90579}
# sections enrolled: 2
#
# student282(PHI5):
# id: 282
# base_score: 500
# section ranking: [90347, 90243, 90593, 90344, 90299]
# schedule: {90344, 90593, 90347, 90243}
# sections enrolled: 4
#
# student283(CRT5):
# id: 283
# base_score: 500
# section ranking: [90168, 90084, 90587, 90819, 90363]
# schedule: {90168, 90819, 90084, 90363}
# sections enrolled: 4
#
# student284(ARC4):
# id: 284
# base_score: 400
# section ranking: [90664, 90037, 90022, 90501, 90587]
# schedule: {90664, 90037}
# sections enrolled: 2
#
# student285(GWS1):
# id: 285
# base_score: 100
# section ranking: [90249, 90050, 90584, 90481, 90167]
# schedule: {90584, 90249, 90481, 90167}
# sections enrolled: 4
#
# student286(ENT5):
# id: 286
# base_score: 500
# section ranking: [90817, 90827, 90247, 90621, 90248]
# schedule: {90817, 90827, 90621, 90247}
# sections enrolled: 4
#
# student287(ASL2):
# id: 287
# base_score: 200
# section ranking: [90778, 90055, 90050, 90700, 90168]
# schedule: {90050, 90700}
# sections enrolled: 2
#
# student288(ANT3):
# id: 288
# base_score: 300
# section ranking: [90287, 90647, 90022, 90132, 90598]
# schedule: {90647, 90132, 90022, 90598}
# sections enrolled: 4
#
# student289(HBR1):
# id: 289
# base_score: 100
# section ranking: [90469, 90586, 90573, 90112, 90031]
# schedule: {90586, 90469, 90031}
# sections enrolled: 3
#
# student290(ENT4):
# id: 290
# base_score: 400
# section ranking: [90389, 90129, 90530, 90670, 90220]
# schedule: {90129, 90530, 90389, 90670}
# sections enrolled: 4
#
# student291(GWS4):
# id: 291
# base_score: 400
# section ranking: [90594, 90020, 90343, 90792, 90497]
# schedule: {90792, 90594, 90020, 90343}
# sections enrolled: 4
#
# student292(EAS2):
# id: 292
# base_score: 200
# section ranking: [90695, 90633, 90220, 90219, 90534]
# schedule: {90219, 90534, 90695}
# sections enrolled: 3
#
# student293(SJS5):
# id: 293
# base_score: 500
# section ranking: [90277, 90794, 90071, 90833, 90185]
# schedule: {90185, 90833, 90277, 90071}
# sections enrolled: 4
#
# student294(GIS4):
# id: 294
# base_score: 400
# section ranking: [90639, 90620, 90535, 90269, 90769]
# schedule: {90535, 90620, 90269, 90639}
# sections enrolled: 4
#
# student295(PHY2):
# id: 295
# base_score: 200
# section ranking: [90686, 90610, 90633, 90329, 90337]
# schedule: {90337, 90610, 90686}
# sections enrolled: 3
#
# student296(PHI1):
# id: 296
# base_score: 100
# section ranking: [90645, 90682, 90346, 90141, 90342]
# schedule: {90682, 90141, 90645, 90342}
# sections enrolled: 4
#
# student297(ANT5):
# id: 297
# base_score: 500
# section ranking: [90768, 90122, 90188, 90019, 90132]
# schedule: {90768, 90122, 90188, 90132}
# sections enrolled: 4
#
# student298(STA2):
# id: 298
# base_score: 200
# section ranking: [90195, 90098, 90193, 90244, 90123]
# schedule: {90123, 90195, 90244}
# sections enrolled: 3
#
# student299(GWS5):
# id: 299
# base_score: 500
# section ranking: [90558, 90206, 90681, 90834, 90584]
# schedule: {90206, 90834, 90558, 90681}
# sections enrolled: 4
#
# student300(NEU5):
# id: 300
# base_score: 500
# section ranking: [90287, 90308, 90790, 90690, 90083]
# schedule: {90690, 90308, 90790, 90287}
# sections enrolled: 4
#
# student301(ENT3):
# id: 301
# base_score: 300
# section ranking: [90205, 90208, 90608, 90247, 90343]
# schedule: {90208, 90608, 90205}
# sections enrolled: 3
#
# student302(MAT5):
# id: 302
# base_score: 500
# section ranking: [90500, 90537, 90819, 90038, 90509]
# schedule: {90537, 90819, 90500, 90038}
# sections enrolled: 4
#
# student303(GIS1):
# id: 303
# base_score: 100
# section ranking: [90535, 90657, 90662, 90269, 90082]
# schedule: {90657}
# sections enrolled: 1
#
# student304(STA1):
# id: 304
# base_score: 100
# section ranking: [90585, 90193, 90195, 90205, 90851]
# schedule: {90585, 90851, 90205}
# sections enrolled: 3
#
# student305(CRE1):
# id: 305
# base_score: 100
# section ranking: [90635, 90226, 90266, 90021, 90189]
# schedule: {90226, 90635, 90021, 90266}
# sections enrolled: 4
#
# student306(THE3):
# id: 306
# base_score: 300
# section ranking: [90673, 90022, 90185, 90836, 90652]
# schedule: {90185, 90673, 90836}
# sections enrolled: 3
#
# student307(GWS4):
# id: 307
# base_score: 400
# section ranking: [90468, 90584, 90112, 90120, 90621]
# schedule: {90584, 90112, 90468, 90120}
# sections enrolled: 4
#
# student308(SOC4):
# id: 308
# base_score: 400
# section ranking: [90261, 90265, 90633, 90591, 90598]
# schedule: {90265, 90261, 90633, 90591}
# sections enrolled: 4
#
# student309(HIS2):
# id: 309
# base_score: 200
# section ranking: [90627, 90621, 90641, 90608, 90607]
# schedule: {90608, 90641, 90627, 90621}
# sections enrolled: 4
#
# student310(SJS5):
# id: 310
# base_score: 500
# section ranking: [90277, 90251, 90208, 90488, 90198]
# schedule: {90488, 90251, 90277, 90198}
# sections enrolled: 4
#
# student311(EAS1):
# id: 311
# base_score: 100
# section ranking: [90222, 90219, 90633, 90659, 90220]
# schedule: {90219, 90222}
# sections enrolled: 2
#
# student312(AT2):
# id: 312
# base_score: 200
# section ranking: [90060, 90451, 90266, 90476, 90510]
# schedule: {90266, 90510}
# sections enrolled: 2
#
# student313(BIO3):
# id: 313
# base_score: 300
# section ranking: [90141, 90074, 90079, 90102, 90301]
# schedule: {90074, 90141, 90301}
# sections enrolled: 3
#
# student314(GOV5):
# id: 314
# base_score: 500
# section ranking: [90195, 90690, 90175, 90797, 90522]
# schedule: {90690, 90195, 90797, 90175}
# sections enrolled: 4
#
# student315(LAT5):
# id: 315
# base_score: 500
# section ranking: [90517, 90824, 90076, 90552, 90325]
# schedule: {90824, 90325, 90076, 90517}
# sections enrolled: 4
#
# student316(RUS5):
# id: 316
# base_score: 500
# section ranking: [90280, 90279, 90278, 90214, 90472]
# schedule: {90280, 90472, 90278}
# sections enrolled: 3
#
# student317(HIS2):
# id: 317
# base_score: 200
# section ranking: [90610, 90672, 90528, 90619, 90243]
# schedule: {90528, 90610, 90619, 90243}
# sections enrolled: 4
#
# student318(THE4):
# id: 318
# base_score: 400
# section ranking: [90173, 90156, 90260, 90753, 90594]
# schedule: {90753, 90173}
# sections enrolled: 2
#
# student319(FLM4):
# id: 319
# base_score: 400
# section ranking: [90696, 90295, 90109, 90296, 90769]
# schedule: {90696, 90769, 90109, 90296}
# sections enrolled: 4
#
# student320(ANT3):
# id: 320
# base_score: 300
# section ranking: [90141, 90018, 90188, 90127, 90027]
# schedule: {90018, 90188, 90141, 90127}
# sections enrolled: 4
#
# student321(GEO5):
# id: 321
# base_score: 500
# section ranking: [90254, 90252, 90071, 90546, 90260]
# schedule: {90546, 90252, 90254, 90071}
# sections enrolled: 4
#
# student322(AHI4):
# id: 322
# base_score: 400
# section ranking: [90491, 90818, 90009, 90823, 90634]
# schedule: {90634, 90818, 90491, 90823}
# sections enrolled: 4
#
# student323(GEO4):
# id: 323
# base_score: 400
# section ranking: [90260, 90254, 90289, 90204, 90657]
# schedule: {90289, 90260, 90254, 90204}
# sections enrolled: 4
#
# student324(GER3):
# id: 324
# base_score: 300
# section ranking: [90476, 90390, 90503, 90494, 90653]
# ...
# schedule: {90569, 90562, 90563, 90558}
# sections enrolled: 4
#
# student2896(HIS1):
# id: 2896
# base_score: 100
# section ranking: [90564, 90622, 90660, 90607, 90621]
# schedule: {90564, 90622, 90607}
# sections enrolled: 3
#
# student2897(SLA2):
# id: 2897
# base_score: 200
# section ranking: [90222, 90276, 90617, 90680, 90267]
# schedule: {90276, 90222, 90267}
# sections enrolled: 3
#
# student2898(LA3):
# id: 2898
# base_score: 300
# section ranking: [90541, 90621, 90820, 90538, 90536]
# schedule: {90621, 90538, 90820, 90541}
# sections enrolled: 4
#
# student2899(CHI4):
# id: 2899
# base_score: 400
# section ranking: [90003, 90673, 90083, 90581, 90108]
# schedule: {90673, 90003, 90083}
# sections enrolled: 3
#
# student2900(GC4):
# id: 2900
# base_score: 400
# section ranking: [90783, 90693, 90199, 90488, 90038]
# schedule: {90488, 90693, 90199, 90783}
# sections enrolled: 4
#
# student2901(PBH1):
# id: 2901
# base_score: 100
# section ranking: [90087, 90276, 90537, 90376, 90107]
# schedule: {90087}
# sections enrolled: 1
#
# student2902(ACC2):
# id: 2902
# base_score: 200
# section ranking: [90584, 90003, 90002, 90764, 90702]
# schedule: {90584, 90002, 90003, 90764}
# sections enrolled: 4
#
# student2903(AT3):
# id: 2903
# base_score: 300
# section ranking: [90059, 90451, 90513, 90520, 90048]
# schedule: {90520, 90513, 90451}
# sections enrolled: 3
#
# student2904(GRK5):
# id: 2904
# base_score: 500
# section ranking: [90305, 90682, 90577, 90580, 90575]
# schedule: {90305, 90577, 90575}
# sections enrolled: 3
#
# student2905(NEU1):
# id: 2905
# base_score: 100
# section ranking: [90308, 90477, 90790, 90535, 90287]
# schedule: {90308, 90477}
# sections enrolled: 2
#
# student2906(ENG2):
# id: 2906
# base_score: 200
# section ranking: [90143, 90663, 90734, 90081, 90793]
# schedule: {90793, 90663, 90143}
# sections enrolled: 3
#
# student2907(CRT1):
# id: 2907
# base_score: 100
# section ranking: [90168, 90183, 90269, 90060, 90226]
# schedule: {90183}
# sections enrolled: 1
#
# student2908(MRC3):
# id: 2908
# base_score: 300
# section ranking: [90205, 90491, 90323, 90525, 90073]
# schedule: {90205, 90323, 90525}
# sections enrolled: 3
#
# student2909(EDU4):
# id: 2909
# base_score: 400
# section ranking: [90242, 90794, 90245, 90681, 90243]
# schedule: {90794, 90681, 90242, 90245}
# sections enrolled: 4
#
# student2910(IS2):
# id: 2910
# base_score: 200
# section ranking: [90279, 90573, 90571, 90569, 90280]
# schedule: {90573}
# sections enrolled: 1
#
# student2911(GIS5):
# id: 2911
# base_score: 500
# section ranking: [90695, 90783, 90548, 90535, 90620]
# schedule: {90783, 90535, 90620, 90695}
# sections enrolled: 4
#
# student2912(SJS4):
# id: 2912
# base_score: 400
# section ranking: [90277, 90573, 90355, 90662, 90734]
# schedule: {90573, 90355, 90277, 90662}
# sections enrolled: 4
#
# student2913(FLM2):
# id: 2913
# base_score: 200
# section ranking: [90811, 90611, 90663, 90338, 90529]
# schedule: {90338, 90811, 90663, 90611}
# sections enrolled: 4
#
# student2914(SOC2):
# id: 2914
# base_score: 200
# section ranking: [90224, 90669, 90630, 90592, 90261]
# schedule: {90224, 90669, 90630}
# sections enrolled: 3
#
# student2915(CRT5):
# id: 2915
# base_score: 500
# section ranking: [90582, 90827, 90181, 90168, 90208]
# schedule: {90168, 90827, 90181, 90582}
# sections enrolled: 4
#
# student2916(GC2):
# id: 2916
# base_score: 200
# section ranking: [90679, 90216, 90585, 90251, 90488]
# schedule: {90216, 90585, 90251, 90679}
# sections enrolled: 4
#
# student2917(MAT5):
# id: 2917
# base_score: 500
# section ranking: [90103, 90836, 90822, 90500, 90206]
# schedule: {90206, 90836, 90822, 90103}
# sections enrolled: 4
#
# student2918(NEU2):
# id: 2918
# base_score: 200
# section ranking: [90308, 90287, 90011, 90697, 90177]
# schedule: {90011, 90308}
# sections enrolled: 2
#
# student2919(BOT3):
# id: 2919
# base_score: 300
# section ranking: [90095, 90097, 90374, 90629, 90265]
# schedule: {90097, 90265, 90095}
# sections enrolled: 3
#
# student2920(ASL1):
# id: 2920
# base_score: 100
# section ranking: [90702, 90778, 90449, 90055, 90325]
# schedule: {90449, 90702}
# sections enrolled: 2
#
# student2921(PHI4):
# id: 2921
# base_score: 400
# section ranking: [90638, 90500, 90599, 90753, 90097]
# schedule: {90753, 90500, 90638, 90599}
# sections enrolled: 4
#
# student2922(PBH1):
# id: 2922
# base_score: 100
# section ranking: [90624, 90099, 90121, 90375, 90376]
# schedule: {90624, 90121, 90099}
# sections enrolled: 3
#
# student2923(GIS1):
# id: 2923
# base_score: 100
# section ranking: [90620, 90583, 90269, 90535, 90819]
# schedule: {90819, 90583}
# sections enrolled: 2
#
# student2924(JPN3):
# id: 2924
# base_score: 300
# section ranking: [90811, 90553, 90554, 90552, 90555]
# schedule: {90552, 90553, 90554, 90811}
# sections enrolled: 4
#
# student2925(PAX3):
# id: 2925
# base_score: 300
# section ranking: [90374, 90192, 90324, 90057, 90349]
# schedule: {90374, 90349, 90192, 90324}
# sections enrolled: 4
#
# student2926(SOC5):
# id: 2926
# base_score: 500
# section ranking: [90767, 90631, 90619, 90271, 90273]
# schedule: {90271, 90619, 90631, 90767}
# sections enrolled: 4
#
# student2927(GEO1):
# id: 2927
# base_score: 100
# section ranking: [90254, 90817, 90244, 90334, 90797]
# schedule: {90817, 90244, 90797, 90334}
# sections enrolled: 4
#
# student2928(PHI4):
# id: 2928
# base_score: 400
# section ranking: [90645, 90348, 90584, 90344, 90342]
# schedule: {90584, 90344, 90645, 90342}
# sections enrolled: 4
#
# student2929(AHI1):
# id: 2929
# base_score: 100
# section ranking: [90279, 90073, 90021, 90494, 90638]
# schedule: {90073, 90638}
# sections enrolled: 2
#
# student2930(MUS2):
# id: 2930
# base_score: 200
# section ranking: [90465, 90449, 90491, 90788, 90390]
# schedule: {90465, 90788, 90449, 90390}
# sections enrolled: 4
#
# student2931(JS4):
# id: 2931
# base_score: 400
# section ranking: [90345, 90102, 90642, 90551, 90818]
# schedule: {90345, 90642, 90102}
# sections enrolled: 3
#
# student2932(GER1):
# id: 2932
# base_score: 100
# section ranking: [90227, 90502, 90494, 90566, 90098]
# schedule: {90227}
# sections enrolled: 1
#
# student2933(CLA1):
# id: 2933
# base_score: 100
# section ranking: [90347, 90095, 90639, 90144, 90137]
# schedule: {90144, 90347, 90095}
# sections enrolled: 3
#
# student2934(HIS5):
# id: 2934
# base_score: 500
# section ranking: [90388, 90626, 90286, 90607, 90598]
# schedule: {90626, 90388, 90286, 90607}
# sections enrolled: 4
#
# student2935(HBR5):
# id: 2935
# base_score: 500
# section ranking: [90637, 90600, 90766, 90235, 90375]
# schedule: {90600, 90235, 90637, 90766}
# sections enrolled: 4
#
# student2936(ENT3):
# id: 2936
# base_score: 300
# section ranking: [90248, 90683, 90104, 90247, 90775]
# schedule: {90248, 90683, 90247}
# sections enrolled: 3
#
# student2937(SLA5):
# id: 2937
# base_score: 500
# section ranking: [90680, 90672, 90617, 90276, 90608]
# schedule: {90680, 90617, 90672, 90276}
# sections enrolled: 4
#
# student2938(BOT2):
# id: 2938
# base_score: 200
# section ranking: [90097, 90103, 90096, 90143, 90102]
# schedule: {90103}
# sections enrolled: 1
#
# student2939(ENG5):
# id: 2939
# base_score: 500
# section ranking: [90667, 90355, 90534, 90664, 90647]
# schedule: {90664, 90667, 90355}
# sections enrolled: 3
#
# student2940(HIS5):
# id: 2940
# base_score: 500
# section ranking: [90052, 90608, 90641, 90626, 90139]
# schedule: {90608, 90641, 90626, 90052}
# sections enrolled: 4
#
# student2941(AT3):
# id: 2941
# base_score: 300
# section ranking: [90149, 90734, 90344, 90817, 90631]
# schedule: {90344, 90817, 90149, 90631}
# sections enrolled: 4
#
# student2942(NEU3):
# id: 2942
# base_score: 300
# section ranking: [90308, 90183, 90287, 90302, 90316]
# schedule: {90316, 90308, 90287}
# sections enrolled: 3
#
# student2943(LAT1):
# id: 2943
# base_score: 100
# section ranking: [90683, 90519, 90638, 90219, 90657]
# schedule: {90683, 90638}
# sections enrolled: 2
#
# student2944(CLA5):
# id: 2944
# base_score: 500
# section ranking: [90534, 90820, 90108, 90796, 90238]
# schedule: {90796, 90238, 90820, 90534}
# sections enrolled: 4
#
# student2945(ACC5):
# id: 2945
# base_score: 500
# section ranking: [90003, 90002, 90288, 90756, 90156]
# schedule: {90288, 90002, 90003, 90756}
# sections enrolled: 4
#
# student2946(SJS2):
# id: 2946
# base_score: 200
# section ranking: [90277, 90092, 90644, 90480, 90090]
# schedule: {90480, 90090, 90092, 90644}
# sections enrolled: 4
#
# student2947(FRH4):
# id: 2947
# base_score: 400
# section ranking: [90477, 90478, 90820, 90308, 90472]
# schedule: {90308, 90820, 90477, 90478}
# sections enrolled: 4
#
# student2948(PAX1):
# id: 2948
# base_score: 100
# section ranking: [90252, 90374, 90607, 90164, 90040]
# schedule: {90252, 90164, 90607}
# sections enrolled: 3
#
# student2949(GER2):
# id: 2949
# base_score: 200
# section ranking: [90566, 90503, 90502, 90494, 90623]
# schedule: {90566}
# sections enrolled: 1
#
# student2950(PSY5):
# id: 2950
# base_score: 500
# section ranking: [90208, 90756, 90317, 90300, 90326]
# schedule: {90208, 90300, 90756}
# sections enrolled: 3
#
# student2951(ACC5):
# id: 2951
# base_score: 500
# section ranking: [90083, 90003, 90002, 90322, 90534]
# schedule: {90002, 90083, 90003}
# sections enrolled: 3
#
# student2952(PKP5):
# id: 2952
# base_score: 500
# section ranking: [90651, 90327, 90536, 90607, 90620]
# schedule: {90536, 90607, 90651, 90327}
# sections enrolled: 4
#
# student2953(HIS3):
# id: 2953
# base_score: 300
# section ranking: [90302, 90450, 90616, 90672, 90641]
# schedule: {90641, 90450, 90302}
# sections enrolled: 3
#
# student2954(LAT2):
# id: 2954
# base_score: 200
# section ranking: [90619, 90518, 90519, 90338, 90166]
# schedule: {90338, 90166, 90518, 90619}
# sections enrolled: 4
#
# student2955(SJS3):
# id: 2955
# base_score: 300
# section ranking: [90277, 90486, 90375, 90575, 90309]
# schedule: {90277, 90486, 90375}
# sections enrolled: 3
#
# student2956(JS4):
# id: 2956
# base_score: 400
# section ranking: [90295, 90642, 90345, 90551, 90112]
# schedule: {90345, 90642, 90551, 90295}
# sections enrolled: 4
#
# student2957(COM2):
# id: 2957
# base_score: 200
# section ranking: [90224, 90476, 90144, 90164, 90134]
# schedule: {90224, 90144, 90164}
# sections enrolled: 3
#
# student2958(MUS4):
# id: 2958
# base_score: 400
# section ranking: [90481, 90450, 90469, 90388, 90660]
# schedule: {90481, 90450, 90388, 90469}
# sections enrolled: 4
#
# student2959(CRE2):
# id: 2959
# base_score: 200
# section ranking: [90037, 90275, 90615, 90635, 90754]
# schedule: {90754, 90275, 90037}
# sections enrolled: 3
#
# student2960(PHY1):
# id: 2960
# base_score: 100
# section ranking: [90329, 90336, 90386, 90694, 90330]
# schedule: {90336, 90386, 90694}
# sections enrolled: 3
#
# student2961(FRH4):
# id: 2961
# base_score: 400
# section ranking: [90241, 90472, 90031, 90474, 90261]
# schedule: {90472, 90241, 90261}
# sections enrolled: 3
#
# student2962(MUS5):
# id: 2962
# base_score: 500
# section ranking: [90038, 90662, 90702, 90342, 90183]
# schedule: {90702, 90038}
# sections enrolled: 2
#
# student2963(ENG2):
# id: 2963
# base_score: 200
# section ranking: [90650, 90648, 90652, 90656, 90668]
# schedule: {90648, 90650, 90656, 90652}
# sections enrolled: 4
#
# student2964(GIS1):
# id: 2964
# base_score: 100
# section ranking: [90269, 90170, 90535, 90620, 90570]
# schedule: {90570, 90170}
# sections enrolled: 2
#
# student2965(FLM5):
# id: 2965
# base_score: 500
# section ranking: [90296, 90593, 90696, 90316, 90337]
# schedule: {90296, 90593, 90696, 90316}
# sections enrolled: 4
#
# student2966(ENG3):
# id: 2966
# base_score: 300
# section ranking: [90656, 90667, 90791, 90664, 90237]
# schedule: {90656, 90664}
# sections enrolled: 2
#
# student2967(GRK4):
# id: 2967
# base_score: 400
# section ranking: [90682, 90653, 90292, 90580, 90575]
# schedule: {90682, 90580, 90292, 90653}
# sections enrolled: 4
#
# student2968(GIS3):
# id: 2968
# base_score: 300
# section ranking: [90143, 90269, 90620, 90535, 90307]
# schedule: {90535, 90620, 90269, 90143}
# sections enrolled: 4
#
# student2969(ARA3):
# id: 2969
# base_score: 300
# section ranking: [90285, 90032, 90033, 90299, 90637]
# schedule: {90032, 90637, 90285}
# sections enrolled: 3
#
# student2970(JS4):
# id: 2970
# base_score: 400
# section ranking: [90642, 90551, 90345, 90198, 90783]
# schedule: {90345, 90642, 90198, 90551}
# sections enrolled: 4
#
# student2971(ES4):
# id: 2971
# base_score: 400
# section ranking: [90100, 90259, 90169, 90117, 90531]
# schedule: {90169, 90259, 90100, 90117}
# sections enrolled: 4
#
# student2972(MUS4):
# id: 2972
# base_score: 400
# section ranking: [90258, 90466, 90390, 90638, 90150]
# schedule: {90258, 90638, 90466, 90390}
# sections enrolled: 4
#
# student2973(DAN1):
# id: 2973
# base_score: 100
# section ranking: [90206, 90789, 90171, 90317, 90227]
# schedule: {90227, 90171, 90789, 90206}
# sections enrolled: 4
#
# student2974(PHY5):
# id: 2974
# base_score: 500
# section ranking: [90328, 90330, 90542, 90333, 90336]
# schedule: {90328, 90330, 90333, 90542}
# sections enrolled: 4
#
# student2975(ARC4):
# id: 2975
# base_score: 400
# section ranking: [90331, 90271, 90016, 90765, 90794]
# schedule: {90794, 90331, 90765, 90271}
# sections enrolled: 4
#
# student2976(AFR5):
# id: 2976
# base_score: 500
# section ranking: [90518, 90288, 90592, 90448, 90186]
# schedule: {90288, 90592, 90448, 90518}
# sections enrolled: 4
#
# student2977(IS4):
# id: 2977
# base_score: 400
# section ranking: [90223, 90038, 90816, 90573, 90571]
# schedule: {90816, 90571, 90573, 90223}
# sections enrolled: 4
#
# student2978(ITL3):
# id: 2978
# base_score: 300
# section ranking: [90625, 90552, 90804, 90184, 90774]
# schedule: {90552, 90625, 90184, 90804}
# sections enrolled: 4
#
# student2979(LIN2):
# id: 2979
# base_score: 200
# section ranking: [90814, 90554, 90684, 90332, 90516]
# schedule: {90332, 90516, 90814}
# sections enrolled: 3
#
# student2980(EDU2):
# id: 2980
# base_score: 200
# section ranking: [90344, 90293, 90652, 90245, 90803]
# schedule: {90344, 90803, 90652, 90293}
# sections enrolled: 4
#
# student2981(LA1):
# id: 2981
# base_score: 100
# section ranking: [90538, 90546, 90820, 90483, 90577]
# schedule: {90546, 90483, 90820}
# sections enrolled: 3
#
# student2982(HBR1):
# id: 2982
# base_score: 100
# section ranking: [90649, 90600, 90221, 90450, 90451]
# schedule: {90649, 90450, 90221}
# sections enrolled: 3
#
# student2983(SLA3):
# id: 2983
# base_score: 300
# section ranking: [90617, 90150, 90680, 90276, 90261]
# schedule: {90680, 90617, 90276, 90150}
# sections enrolled: 4
#
# student2984(AHI4):
# id: 2984
# base_score: 400
# section ranking: [90013, 90634, 90638, 90598, 90017]
# schedule: {90634, 90013, 90638, 90598}
# sections enrolled: 4
#
# student2985(AMS5):
# id: 2985
# base_score: 500
# section ranking: [90617, 90303, 90609, 90855, 90111]
# schedule: {90617, 90855, 90609, 90303}
# sections enrolled: 4
#
# student2986(PBH4):
# id: 2986
# base_score: 400
# section ranking: [90376, 90589, 90134, 90560, 90298]
# schedule: {90376, 90589, 90134, 90560}
# sections enrolled: 4
#
# student2987(SOC1):
# id: 2987
# base_score: 100
# section ranking: [90509, 90184, 90261, 90448, 90656]
# schedule: {90184, 90448, 90509, 90261}
# sections enrolled: 4
#
# student2988(ARA2):
# id: 2988
# base_score: 200
# section ranking: [90033, 90032, 90487, 90326, 90363]
# schedule: {90326, 90487, 90363}
# sections enrolled: 3
#
# student2989(GC4):
# id: 2989
# base_score: 400
# section ranking: [90501, 90166, 90536, 90790, 90196]
# schedule: {90536, 90790, 90501, 90166}
# sections enrolled: 4
#
# student2990(PHY4):
# id: 2990
# base_score: 400
# section ranking: [90331, 90329, 90481, 90332, 90328]
# schedule: {90328, 90329, 90331, 90481}
# sections enrolled: 4
#
# student2991(EAS3):
# id: 2991
# base_score: 300
# section ranking: [90701, 90633, 90219, 90220, 90764]
# schedule: {90633, 90219, 90220, 90701}
# sections enrolled: 4
#
# student2992(ES2):
# id: 2992
# base_score: 200
# section ranking: [90253, 90251, 90147, 90594, 90660]
# schedule: {90594, 90251, 90253}
# sections enrolled: 3
#
# student2993(SLA3):
# id: 2993
# base_score: 300
# section ranking: [90139, 90488, 90680, 90617, 90818]
# schedule: {90488, 90617, 90680, 90139}
# sections enrolled: 4
#
# student2994(BIO1):
# id: 2994
# base_score: 100
# section ranking: [90073, 90675, 90676, 90666, 90306]
# schedule: {90073, 90306, 90675}
# sections enrolled: 3
#
# student2995(GRK3):
# id: 2995
# base_score: 300
# section ranking: [90577, 90575, 90386, 90520, 90682]
# schedule: {90577, 90386, 90682, 90575}
# sections enrolled: 4
#
# student2996(AT5):
# id: 2996
# base_score: 500
# section ranking: [90789, 90060, 90734, 90149, 90660]
# schedule: {90060, 90789, 90734}
# sections enrolled: 3
#
# student2997(BIO4):
# id: 2997
# base_score: 400
# section ranking: [90090, 90092, 90098, 90108, 90609]
# schedule: {90090, 90092, 90098}
# sections enrolled: 3
#
# student2998(HBR2):
# id: 2998
# base_score: 200
# section ranking: [90600, 90286, 90667, 90198, 90208]
# schedule: {90208, 90667, 90286, 90198}
# sections enrolled: 4
#
# student2999(PSY4):
# id: 2999
# base_score: 400
# section ranking: [90645, 90775, 90315, 90311, 90320]
# schedule: {90311, 90315, 90645, 90775}
# sections enrolled: 4

# %%
to_pop = []
for id, section in sections.items():
    if section.dept != "COM":
        to_pop.append(id)
for id in to_pop:
    sections.pop(id)
student_dict = data.generate_students_weighted(sections, 60)
for key in student_dict:
    student_dict[key].find_conflicts(sections)
    print(student_dict[key].conflicts_dict)
# Out:
# {90144: set(), 90166: set(), 90139: set(), 90142: set(), 90163: set()}
# {90165: set(), 90139: {90145}, 90145: {90139}, 90166: set(), 90164: set()}
# {90145: set(), 90142: set(), 90146: set(), 90164: set(), 90148: set()}
# {90145: set(), 90143: set(), 90146: set(), 90334: set(), 90167: set()}
# {90334: set(), 90139: set(), 90163: set(), 90146: set(), 90142: set()}
# {90164: set(), 90146: set(), 90163: set(), 90148: set(), 90139: set()}
# {90145: set(), 90140: set(), 90143: set(), 90146: set(), 90163: set()}
# {90146: set(), 90142: set(), 90754: set(), 90147: set(), 90334: set()}
# {90165: set(), 90140: {90166}, 90146: set(), 90166: {90140}, 90145: set()}
# {90147: {90143}, 90140: set(), 90334: set(), 90143: {90147}, 90167: set()}
# {90165: set(), 90147: {90143}, 90143: {90147}, 90163: set(), 90164: set()}
# {90140: set(), 90147: set(), 90139: {90145}, 90145: {90139}, 90165: set()}
# {90164: set(), 90142: set(), 90139: set(), 90146: set(), 90754: set()}
# {90144: set(), 90147: set(), 90145: set(), 90164: set(), 90334: set()}
# {90164: set(), 90148: set(), 90142: set(), 90145: set(), 90334: set()}
# {90166: set(), 90164: set(), 90146: set(), 90148: set(), 90139: set()}
# {90144: set(), 90145: {90139}, 90139: {90145}, 90147: set(), 90146: set()}
# {90143: {90147}, 90146: set(), 90140: set(), 90164: set(), 90147: {90143}}
# {90163: set(), 90165: set(), 90334: set(), 90754: set(), 90142: set()}
# {90139: set(), 90148: set(), 90166: set(), 90167: set(), 90142: set()}
# {90145: set(), 90166: set(), 90167: set(), 90147: set(), 90148: set()}
# {90166: set(), 90139: {90145}, 90143: set(), 90754: set(), 90145: {90139}}
# {90334: set(), 90165: set(), 90139: set(), 90166: set(), 90146: set()}
# {90334: set(), 90145: set(), 90144: set(), 90164: set(), 90140: set()}
# {90163: set(), 90754: set(), 90143: set(), 90146: set(), 90140: set()}
# {90146: set(), 90754: set(), 90167: set(), 90140: set(), 90148: set()}
# {90139: set(), 90144: set(), 90334: set(), 90165: set(), 90143: set()}
# {90140: set(), 90139: set(), 90143: set(), 90146: set(), 90142: set()}
# {90334: set(), 90146: set(), 90164: set(), 90147: set(), 90167: set()}
# {90147: set(), 90164: set(), 90146: set(), 90148: set(), 90754: set()}
# {90754: set(), 90334: set(), 90145: {90139}, 90139: {90145}, 90167: set()}
# {90140: {90166}, 90166: {90140}, 90148: set(), 90146: set(), 90144: set()}
# {90167: set(), 90163: set(), 90147: set(), 90166: set(), 90334: set()}
# {90147: {90143}, 90146: set(), 90166: set(), 90143: {90147}, 90165: set()}
# {90165: set(), 90144: set(), 90164: set(), 90143: set(), 90146: set()}
# {90146: set(), 90140: set(), 90167: set(), 90165: set(), 90145: set()}
# {90164: set(), 90144: set(), 90163: set(), 90146: set(), 90334: set()}
# {90143: set(), 90148: set(), 90164: set(), 90166: set(), 90145: set()}
# {90163: set(), 90166: set(), 90754: set(), 90146: set(), 90142: set()}
# {90144: set(), 90165: set(), 90143: set(), 90139: set(), 90142: set()}
# {90140: set(), 90165: set(), 90754: set(), 90144: set(), 90334: set()}
# {90139: set(), 90754: set(), 90164: set(), 90144: set(), 90166: set()}
# {90167: set(), 90334: set(), 90163: set(), 90147: set(), 90165: set()}
# {90165: set(), 90143: set(), 90167: set(), 90334: set(), 90166: set()}
# {90165: set(), 90163: set(), 90140: set(), 90147: set(), 90754: set()}
# {90164: set(), 90147: {90143}, 90143: {90147}, 90146: set(), 90148: set()}
# {90139: {90145}, 90146: set(), 90148: set(), 90145: {90139}, 90142: set()}
# {90334: set(), 90146: set(), 90145: set(), 90163: set(), 90165: set()}
# {90163: set(), 90139: {90145}, 90165: set(), 90145: {90139}, 90147: set()}
# {90166: {90140}, 90754: set(), 90140: {90166}, 90144: set(), 90164: set()}
# {90142: set(), 90139: set(), 90334: set(), 90167: set(), 90163: set()}
# {90334: set(), 90164: set(), 90143: set(), 90166: set(), 90165: set()}
# {90142: set(), 90167: set(), 90146: set(), 90164: set(), 90334: set()}
# {90140: {90166}, 90139: set(), 90334: set(), 90166: {90140}, 90754: set()}
# {90164: set(), 90163: set(), 90166: set(), 90165: set(), 90146: set()}
# {90140: set(), 90164: set(), 90145: set(), 90167: set(), 90142: set()}
# {90143: set(), 90754: set(), 90148: set(), 90139: set(), 90164: set()}
# {90143: set(), 90146: set(), 90164: set(), 90148: set(), 90167: set()}
# {90147: {90143}, 90143: {90147}, 90167: set(), 90140: set(), 90144: set()}
# {90166: set(), 90167: set(), 90165: set(), 90145: set(), 90142: set()}

# %%
monte_carlo_gs(student_dict, sections, 10)
# Out:
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# counter: 0
# 0

# %%
gs.gale_shapley_match(student_dict, sections)
for id, student in student_dict.items():
    if len(student.enrolled_in) > 3:
        print(student)
# Out:
# student0(COM3):
# id: 0
# base_score: 300
# section ranking: [90144, 90166, 90139, 90142, 90163]
# schedule: {90144, 90139, 90166, 90142}
# sections enrolled: 4
#
# student2(COM3):
# id: 2
# base_score: 300
# section ranking: [90145, 90142, 90146, 90164, 90148]
# schedule: {90145, 90146, 90148, 90142}
# sections enrolled: 4
#
# student6(COM4):
# id: 6
# base_score: 400
# section ranking: [90145, 90140, 90143, 90146, 90163]
# schedule: {90145, 90146, 90140, 90143}
# sections enrolled: 4
#
# student9(COM5):
# id: 9
# base_score: 500
# section ranking: [90147, 90140, 90334, 90143, 90167]
# schedule: {90147, 90140, 90334, 90167}
# sections enrolled: 4
#
# student10(COM5):
# id: 10
# base_score: 500
# section ranking: [90165, 90147, 90143, 90163, 90164]
# schedule: {90163, 90147, 90164, 90165}
# sections enrolled: 4
#
# student11(COM5):
# id: 11
# base_score: 500
# section ranking: [90140, 90147, 90139, 90145, 90165]
# schedule: {90139, 90147, 90140, 90165}
# sections enrolled: 4
#
# student12(COM5):
# id: 12
# base_score: 500
# section ranking: [90164, 90142, 90139, 90146, 90754]
# schedule: {90146, 90139, 90164, 90142}
# sections enrolled: 4
#
# student13(COM4):
# id: 13
# base_score: 400
# section ranking: [90144, 90147, 90145, 90164, 90334]
# schedule: {90144, 90145, 90147, 90164}
# sections enrolled: 4
#
# student14(COM5):
# id: 14
# base_score: 500
# section ranking: [90164, 90148, 90142, 90145, 90334]
# schedule: {90145, 90164, 90148, 90142}
# sections enrolled: 4
#
# student17(COM5):
# id: 17
# base_score: 500
# section ranking: [90143, 90146, 90140, 90164, 90147]
# schedule: {90146, 90140, 90164, 90143}
# sections enrolled: 4
#
# student18(COM3):
# id: 18
# base_score: 300
# section ranking: [90163, 90165, 90334, 90754, 90142]
# schedule: {90754, 90163, 90165, 90142}
# sections enrolled: 4
#
# student19(COM1):
# id: 19
# base_score: 100
# section ranking: [90139, 90148, 90166, 90167, 90142]
# schedule: {90139, 90148, 90166, 90167}
# sections enrolled: 4
#
# student20(COM3):
# id: 20
# base_score: 300
# section ranking: [90145, 90166, 90167, 90147, 90148]
# schedule: {90145, 90147, 90166, 90167}
# sections enrolled: 4
#
# student21(COM1):
# id: 21
# base_score: 100
# section ranking: [90166, 90139, 90143, 90754, 90145]
# schedule: {90754, 90139, 90166, 90143}
# sections enrolled: 4
#
# student22(COM5):
# id: 22
# base_score: 500
# section ranking: [90334, 90165, 90139, 90166, 90146]
# schedule: {90166, 90139, 90165, 90334}
# sections enrolled: 4
#
# student23(COM3):
# id: 23
# base_score: 300
# section ranking: [90334, 90145, 90144, 90164, 90140]
# schedule: {90144, 90145, 90140, 90334}
# sections enrolled: 4
#
# student24(COM1):
# id: 24
# base_score: 100
# section ranking: [90163, 90754, 90143, 90146, 90140]
# schedule: {90754, 90163, 90140, 90143}
# sections enrolled: 4
#
# student25(COM3):
# id: 25
# base_score: 300
# section ranking: [90146, 90754, 90167, 90140, 90148]
# schedule: {90146, 90140, 90167, 90754}
# sections enrolled: 4
#
# student26(COM4):
# id: 26
# base_score: 400
# section ranking: [90139, 90144, 90334, 90165, 90143]
# schedule: {90144, 90139, 90165, 90334}
# sections enrolled: 4
#
# student27(COM5):
# id: 27
# base_score: 500
# section ranking: [90140, 90139, 90143, 90146, 90142]
# schedule: {90146, 90139, 90140, 90143}
# sections enrolled: 4
#
# student28(COM5):
# id: 28
# base_score: 500
# section ranking: [90334, 90146, 90164, 90147, 90167]
# schedule: {90146, 90147, 90164, 90334}
# sections enrolled: 4
#
# student29(COM5):
# id: 29
# base_score: 500
# section ranking: [90147, 90164, 90146, 90148, 90754]
# schedule: {90146, 90147, 90164, 90148}
# sections enrolled: 4
#
# student30(COM4):
# id: 30
# base_score: 400
# section ranking: [90754, 90334, 90145, 90139, 90167]
# schedule: {90145, 90754, 90334, 90167}
# sections enrolled: 4
#
# student31(COM5):
# id: 31
# base_score: 500
# section ranking: [90140, 90166, 90148, 90146, 90144]
# schedule: {90144, 90146, 90140, 90148}
# sections enrolled: 4
#
# student32(COM4):
# id: 32
# base_score: 400
# section ranking: [90167, 90163, 90147, 90166, 90334]
# schedule: {90147, 90163, 90166, 90167}
# sections enrolled: 4
#
# student33(COM4):
# id: 33
# base_score: 400
# section ranking: [90147, 90146, 90166, 90143, 90165]
# schedule: {90146, 90147, 90165, 90166}
# sections enrolled: 4
#
# student34(COM5):
# id: 34
# base_score: 500
# section ranking: [90165, 90144, 90164, 90143, 90146]
# schedule: {90144, 90164, 90165, 90143}
# sections enrolled: 4
#
# student35(COM2):
# id: 35
# base_score: 200
# section ranking: [90146, 90140, 90167, 90165, 90145]
# schedule: {90146, 90140, 90165, 90167}
# sections enrolled: 4
#
# student37(COM4):
# id: 37
# base_score: 400
# section ranking: [90143, 90148, 90164, 90166, 90145]
# schedule: {90166, 90148, 90164, 90143}
# sections enrolled: 4
#
# student38(COM3):
# id: 38
# base_score: 300
# section ranking: [90163, 90166, 90754, 90146, 90142]
# schedule: {90754, 90163, 90146, 90166}
# sections enrolled: 4
#
# student39(COM3):
# id: 39
# base_score: 300
# section ranking: [90144, 90165, 90143, 90139, 90142]
# schedule: {90144, 90139, 90165, 90143}
# sections enrolled: 4
#
# student41(COM3):
# id: 41
# base_score: 300
# section ranking: [90139, 90754, 90164, 90144, 90166]
# schedule: {90144, 90754, 90166, 90139}
# sections enrolled: 4
#
# student42(COM5):
# id: 42
# base_score: 500
# section ranking: [90167, 90334, 90163, 90147, 90165]
# schedule: {90147, 90163, 90334, 90167}
# sections enrolled: 4
#
# student43(COM3):
# id: 43
# base_score: 300
# section ranking: [90165, 90143, 90167, 90334, 90166]
# schedule: {90167, 90165, 90334, 90143}
# sections enrolled: 4
#
# student44(COM5):
# id: 44
# base_score: 500
# section ranking: [90165, 90163, 90140, 90147, 90754]
# schedule: {90147, 90163, 90140, 90165}
# sections enrolled: 4
#
# student45(COM5):
# id: 45
# base_score: 500
# section ranking: [90164, 90147, 90143, 90146, 90148]
# schedule: {90146, 90147, 90164, 90148}
# sections enrolled: 4
#
# student47(COM2):
# id: 47
# base_score: 200
# section ranking: [90334, 90146, 90145, 90163, 90165]
# schedule: {90145, 90146, 90163, 90165}
# sections enrolled: 4
#
# student48(COM5):
# id: 48
# base_score: 500
# section ranking: [90163, 90139, 90165, 90145, 90147]
# schedule: {90139, 90147, 90163, 90165}
# sections enrolled: 4
#
# student49(COM5):
# id: 49
# base_score: 500
# section ranking: [90166, 90754, 90140, 90144, 90164]
# schedule: {90144, 90754, 90164, 90166}
# sections enrolled: 4
#
# student50(COM4):
# id: 50
# base_score: 400
# section ranking: [90142, 90139, 90334, 90167, 90163]
# schedule: {90139, 90334, 90142, 90167}
# sections enrolled: 4
#
# student51(COM5):
# id: 51
# base_score: 500
# section ranking: [90334, 90164, 90143, 90166, 90165]
# schedule: {90166, 90164, 90334, 90143}
# sections enrolled: 4
#
# student52(COM5):
# id: 52
# base_score: 500
# section ranking: [90142, 90167, 90146, 90164, 90334]
# schedule: {90146, 90164, 90142, 90167}
# sections enrolled: 4
#
# student54(COM2):
# id: 54
# base_score: 200
# section ranking: [90164, 90163, 90166, 90165, 90146]
# schedule: {90146, 90163, 90165, 90166}
# sections enrolled: 4
#
# student55(COM3):
# id: 55
# base_score: 300
# section ranking: [90140, 90164, 90145, 90167, 90142]
# schedule: {90145, 90140, 90164, 90167}
# sections enrolled: 4
#
# student56(COM3):
# id: 56
# base_score: 300
# section ranking: [90143, 90754, 90148, 90139, 90164]
# schedule: {90754, 90139, 90148, 90143}
# sections enrolled: 4
#
# student57(COM5):
# id: 57
# base_score: 500
# section ranking: [90143, 90146, 90164, 90148, 90167]
# schedule: {90146, 90164, 90148, 90143}
# sections enrolled: 4
#
# student58(COM5):
# id: 58
# base_score: 500
# section ranking: [90147, 90143, 90167, 90140, 90144]
# schedule: {90144, 90147, 90140, 90167}
# sections enrolled: 4
#
# student59(COM2):
# id: 59
# base_score: 200
# section ranking: [90166, 90167, 90165, 90145, 90142]
# schedule: {90145, 90165, 90166, 90167}
# sections enrolled: 4
